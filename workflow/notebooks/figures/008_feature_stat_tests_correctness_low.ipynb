# %% [markdown]
# # Feature stat tests
#
# This notebook aims at analyzing the feature differences between high and low entropy transcripts using statistical inference tests.

# %% [markdown]
# ## Section 1: Imports

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Add workflow utilities to path
sys.path.append("/mnt/cbib/LNClassifier/paper/workflow/")
from utils.features import filter_feature_columns, custom_feature_scaling, get_probabilities, remove_constant_features
from utils.parsing import load_tables
from utils.feature_analysis import (
    perform_mann_whitney_tests, perform_f_tests, perform_mutual_info_tests,
    residualize_features, rank_features_by_composite, rank_features_by_score,
    plot_feature_distributions, plot_feature_heatmap, plot_volcano,
    discover_feature_sets, load_feature_set, correlation_and_distance, cluster_features,
    plot_correlation_heatmap, plot_dendrogram
)

# Plotting configuration
sns.set_style('whitegrid')
plt.rcParams['figure.dpi'] = 300
plt.rcParams['pdf.fonttype'] = 42

DATASET = "gencode.v47.common.cdhit.cv"
FIGURE_DIR = f"/mnt/cbib/LNClassifier/paper/results/{DATASET}/features/figures"
os.makedirs(FIGURE_DIR, exist_ok=True)

print("✓ Imports successful")
# Out:
# ✓ Imports successful

# %% [markdown]
# ## Section 2: Configuration

# %%
DATASET_NAME = 'gencode.v47.common.cdhit.cv'
BASEDIR = Path("/mnt/cbib/LNClassifier/paper")

STATISTICAL_METHODS = ['f_test', 'mutual_info', 'mann_whitney']

FDR_METHOD = 'fdr_bh'  # 'fdr_bh' (recommended), 'bonferroni', 'holm', 'fdr_by'
FDR_ALPHA = 0.01

OUTPUT_DIR = BASEDIR / f'results/{DATASET_NAME}/features/simple_analysis/H_pred_th10-90/'
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

VERBOSE = True

print(f"✓ Configuration loaded")
print(f"  Dataset: {DATASET_NAME}")
print(f"  Output: {OUTPUT_DIR}")
print(f"  Methods: {STATISTICAL_METHODS}")
# Out:
# ✓ Configuration loaded
#   Dataset: gencode.v47.common.cdhit.cv
#   Output: /mnt/cbib/LNClassifier/paper/results/gencode.v47.common.cdhit.cv/features/simple_analysis/H_pred_th10-90
#   Methods: ['f_test', 'mutual_info', 'mann_whitney']

# %% [markdown]
# ## Section 3: Load datasets

# %%
def load_dataset(dataset_name, basedir):
    """Load dataset with predictions and labels."""
    tables = load_tables(dataset_name)
    binary = tables['binary'].set_index('seq_ID')
    pc_ids = binary[binary["real"] == True].index.tolist()
    lnc_ids = binary[binary["real"] == False].index.tolist()
    ids_with_class = pc_ids + lnc_ids
    
    features_df = tables['full_table'].set_index('seq_ID')
    features_df = features_df.loc[ids_with_class]
    probs = get_probabilities(features_df)
    probs = probs.dropna()
    
    labels = pd.DataFrame(index=probs.index)
    labels['coding_class'] = labels.index.isin(pc_ids).astype(int)
    labels['biotype'] = labels['coding_class'].map({1: 'coding', 0: 'lncRNA'})
    
    return {
        'probs': probs,
        'labels': labels,
        'features': features_df.loc[probs.index],
        'binary': binary
    }

def load_additional_features(dataset_name, basedir):
    """Load TE and NBD pipeline features if available."""
    additional = {}
    pipelines = {
        'te_pipeline': 'te_pipeline/results/te_analysis_flexible/features/all_transcripts_te_features.corrected.csv',
        'nbd_pipeline': 'nonb-pipeline/results/gencode.v47/extended_analysis/features_nonb_features.corrected.csv',
        'entropy': f"results/{dataset_name}/uncertainty_analysis/{dataset_name}_uncertainty_analysis.tsv"
    }
    
    for key, rel_path in pipelines.items():
        path = basedir / rel_path
        if path.exists():
            ext = path.suffix
            df = pd.read_csv(path, sep='\t' if ext == '.tsv' else ',', index_col=0)
            additional[key] = df
            if VERBOSE:
                print(f"✓ Loaded {key} ({df.shape[0]} samples × {df.shape[1]} features)")
        else:
            if VERBOSE:
                print(f"⚠ {key} not found at {rel_path}")
    
    return additional

# Load main dataset
dataset = load_dataset(DATASET_NAME, BASEDIR)
dataset.update(load_additional_features(DATASET_NAME, BASEDIR))

probs = dataset['probs']
labels = dataset['labels']
features = dataset['features']
features_to_keep = filter_feature_columns(features)
features = features[features_to_keep]
binary = dataset['binary']

# Load additional features if available
if 'te_pipeline' in dataset:
    te_features = dataset['te_pipeline'].loc[probs.index]
    te_features = te_features.fillna(0)
else:
    te_features = None
    print("⚠ TE features not loaded")

if 'nbd_pipeline' in dataset:
    nbd_features = dataset['nbd_pipeline'].loc[probs.index]
    nbd_features.rename(columns={'motif_types_present': 'n_motif_types'}, inplace=True)
else:
    nbd_features = None
    print("⚠ NBD features not loaded")

if 'entropy' in dataset:
    entropy_df = dataset['entropy'].loc[probs.index]
else:
    entropy_df = None
    print("⚠ Entropy metrics not loaded")

print(f"✓ Data loaded: {len(probs)} transcripts with {len(features.columns)} features")
# Out:
# Extracted 8 probability columns.
# Inverting noncoding probabilities...
#   - Inverting column: Noncoding_prob_ss_lncDC
# ✓ Loaded te_pipeline (385659 samples × 173 features)
# ⚠ nbd_pipeline not found at nonb-pipeline/results/gencode.v47/extended_analysis/features_nonb_features.corrected.csv
# ⚠ entropy not found at results/gencode.v47.common.cdhit.cv/uncertainty_analysis/gencode.v47.common.cdhit.cv_uncertainty_analysis.tsv
# Identified length columns to exclude: ['Transcript_length_lncDC', 'length_plncpro'] (keeping RNA_size_feelnc for reference)
# Total number of columns in features table: 172
# Number of kept feature columns: 128
# Feature columns: ['kmerScore_1mer_feelnc', 'kmerScore_2mer_feelnc', 'kmerScore_3mer_feelnc', 'kmerScore_6mer_feelnc', 'kmerScore_9mer_feelnc', 'kmerScore_12mer_feelnc', 'ORF_cover_feelnc', 'RNA_size_feelnc', 'ORF_l_cpat', 'Fickett_l_cpat', 'Hexamer_l_cpat', 'ORF_coverage_l_cpat', 'GC_content_lncDC', 'Fickett_score_lncDC', 'ORF_T0_length_lncDC', 'ORF_T1_length_lncDC', 'ORF_T2_length_lncDC', 'ORF_T0_coverage_lncDC', 'ORF_T1_coverage_lncDC', 'ORF_T3_coverage_lncDC', 'Hexamer_score_ORF_T0_lncDC', 'Hexamer_score_ORF_T1_lncDC', 'Hexamer_score_ORF_T2_lncDC', 'Hexamer_score_ORF_T3_lncDC', 'RCB_T0_lncDC', 'RCB_T1_lncDC', 'ORF_T0_PI_lncDC', 'ORF_T0_MW_lncDC', 'ORF_T0_aromaticity_lncDC', 'ORF_T0_instability_lncDC', 'ORF_T1_MW_lncDC', 'ORF_T1_instability_lncDC', 'ORF_T2_MW_lncDC', 'ORF_T3_MW_lncDC', 'SS_score_k1_lncDC', 'SS_score_k2_lncDC', 'SS_score_k3_lncDC', 'SS_score_k4_lncDC', 'SS_score_k5_lncDC', 'GC_content_paired_ss_lncDC', 'AAT_plncpro', 'ATT_plncpro', 'AAA_plncpro', 'TTT_plncpro', 'CCA_plncpro', 'TGG_plncpro', 'AAC_plncpro', 'GTT_plncpro', 'ACT_plncpro', 'AGT_plncpro', 'CCG_plncpro', 'CGG_plncpro', 'ATC_plncpro', 'GAT_plncpro', 'AAG_plncpro', 'CTT_plncpro', 'CGC_plncpro', 'GCG_plncpro', 'AGG_plncpro', 'CCT_plncpro', 'GAA_plncpro', 'TTC_plncpro', 'ACG_plncpro', 'CGT_plncpro', 'ACC_plncpro', 'GGT_plncpro', 'GAC_plncpro', 'GTC_plncpro', 'CCC_plncpro', 'GGG_plncpro', 'ACA_plncpro', 'TGT_plncpro', 'CGA_plncpro', 'TCG_plncpro', 'GGA_plncpro', 'TCC_plncpro', 'CAA_plncpro', 'TTG_plncpro', 'AGC_plncpro', 'GCT_plncpro', 'GTA_plncpro', 'TAC_plncpro', 'AGA_plncpro', 'TCT_plncpro', 'CTC_plncpro', 'GAG_plncpro', 'CAC_plncpro', 'GTG_plncpro', 'TAA_plncpro', 'TTA_plncpro', 'GCA_plncpro', 'TGC_plncpro', 'CTA_plncpro', 'TAG_plncpro', 'GCC_plncpro', 'GGC_plncpro', 'ATG_plncpro', 'CAT_plncpro', 'CAG_plncpro', 'CTG_plncpro', 'ATA_plncpro', 'TAT_plncpro', 'TCA_plncpro', 'TGA_plncpro', 'orf_coverage_plncpro', 'all_numhits_plncpro', 'all_HitScore_plncpro', 'all_Frame_Entropy_plncpro', 'all_Bitscore_plncpro', 'ORF.Max.Len_lncfinder', 'ORF.Max.Cov_lncfinder', 'Seq.lnc.Dist_lncfinder', 'Seq.pct.Dist_lncfinder', 'Seq.Dist.Ratio_lncfinder', 'Signal.Peak_lncfinder', 'SNR_lncfinder', 'Signal.Min_lncfinder', 'Signal.Q1_lncfinder', 'Signal.Q2_lncfinder', 'Signal.Max_lncfinder', 'Dot_lnc.dist_lncfinder', 'Dot_pct.dist_lncfinder', 'Dot_Dist.Ratio_lncfinder', 'SS.lnc.dist_lncfinder', 'SS.pct.dist_lncfinder', 'SS.Dist.Ratio_lncfinder', 'MFE_lncfinder', 'UP.PCT_lncfinder']
# ⚠ NBD features not loaded
# ⚠ Entropy metrics not loaded
# ✓ Data loaded: 111652 transcripts with 128 features

# %%
probs
# Out:
#                    coding_score_rnasamba  coding_potential_feelnc  \
# seq_ID
# ENST00000000412.8                0.99411                    0.958
# ENST00000002596.6                0.98732                    0.954
# ENST00000002829.8                0.99930                    1.000
# ENST00000005260.9                0.99168                    0.980
# ENST00000005995.8                0.97452                    0.994
# ...                                  ...                      ...
# ENST00000715715.1                0.04422                    0.010
# ENST00000715718.1                0.00632                    0.022
# ENST00000715720.1                0.24308                    0.016
# ENST00000715721.1                0.01188                    0.170
# ENST00000715722.1                0.08294                    0.066
#
#                    Coding_prob_l_cpat  Noncoding_prob_ss_lncDC  \
# seq_ID
# ENST00000000412.8            0.933894                 0.999833
# ENST00000002596.6            0.996628                 0.996186
# ENST00000002829.8            0.998778                 0.998462
# ENST00000005260.9            0.980331                 0.999546
# ENST00000005995.8            0.942528                 0.999394
# ...                               ...                      ...
# ENST00000715715.1            0.171249                 0.000282
# ENST00000715718.1            0.289002                 0.000984
# ENST00000715720.1            0.172799                 0.004180
# ENST00000715721.1            0.498485                 0.000516
# ENST00000715722.1            0.688794                 0.072897
#
#                    coding_prob_mrnn  P(pcRNA)_lncrnabert  prob_coding_plncpro  \
# seq_ID
# ENST00000000412.8          0.978755             0.999992                0.956
# ENST00000002596.6          0.910619             0.999992                0.585
# ENST00000002829.8          0.986240             0.999993                0.998
# ENST00000005260.9          0.978858             0.999992                0.995
# ENST00000005995.8          0.990389             0.999991                0.979
# ...                             ...                  ...                  ...
# ENST00000715715.1          0.353438             0.000003                0.044
# ENST00000715718.1          0.022870             0.000002                0.026
# ENST00000715720.1          0.113424             0.000003                0.083
# ENST00000715721.1          0.068693             0.000003                0.050
# ENST00000715722.1          0.548290             0.000003                0.387
#
#                    Coding.Potential_ss_lncfinder
# seq_ID
# ENST00000000412.8                       0.989447
# ENST00000002596.6                       0.995086
# ENST00000002829.8                       0.970563
# ENST00000005260.9                       0.959779
# ENST00000005995.8                       0.891659
# ...                                          ...
# ENST00000715715.1                       0.059889
# ENST00000715718.1                       0.112075
# ENST00000715720.1                       0.049054
# ENST00000715721.1                       0.041490
# ENST00000715722.1                       0.152033
#
# [111652 rows x 8 columns]

# %% [markdown]
# ### 3.1 Feature pre-processing
# - Combine all feature sets
# - Remove constant features
# - Transform to numeric
# - Separate between categorical and continuous

# %%
original_full = pd.concat([features, te_features, nbd_features], axis=1)
full_feature_set = original_full.copy()
# Since merged df may have duplicate columns:
full_feature_set = full_feature_set.loc[:, ~full_feature_set.columns.duplicated(keep='first')]
# Fill missing values (possible for categorical TE features)
full_feature_set.fillna(0, inplace=True)
# Convert boolean/object columns to numerical (0/1)
full_feature_set = full_feature_set.apply(pd.to_numeric, errors='coerce')

# Keep only numeric features, and report and remove constant features
numeric_cols = full_feature_set.select_dtypes(include=[np.number]).columns
print(f"Full feature set: keeping {len(numeric_cols)} numeric features (out of {full_feature_set.shape[1]} total)")
numeric_df = full_feature_set[numeric_cols]
nunique = numeric_df.nunique()
constant_features = nunique[nunique <= 1].index.tolist()
if constant_features:
    print(f"Full feature set: Removing {len(constant_features)} constant features")
    print(f"  Constant features: {constant_features}")
    full_feature_set = numeric_df.drop(columns=constant_features)
# Out:
# Full feature set: keeping 301 numeric features (out of 301 total)
# Full feature set: Removing 15 constant features
#   Constant features: ['te_has_ervk', 'te_ervk_count', 'te_has_ervl', 'te_ervl_count', 'te_has_ervl-malr', 'te_ervl-malr_count', 'te_has_erv1', 'te_erv1_count', 'pseudo_unique_families', 'te_ervk_count_per_kb', 'te_ervl_count_per_kb', 'te_ervl-malr_count_per_kb', 'te_erv1_count_per_kb', 'transcript_type', 'coding_class']

# %%
# Separate scalar (numeric) from categorical features
categorical_features = []
scalar_features = []

cat_substrings = ['_has_', '_present']
cat_col_names = ["ORF_frame_l_cpat"]

cat_cols = [col for col in full_feature_set.columns if any(sub in col for sub in cat_substrings) or col in cat_col_names]
# Remaining are scalar (numeric)
scalar_cols = full_feature_set.columns.difference(cat_cols).tolist()

if cat_cols:
    categorical_features = full_feature_set[cat_cols]
if scalar_cols:
    scalar_features = full_feature_set[scalar_cols]

if VERBOSE:
    print(f"  Categorical features: {len(cat_cols)} (containing substrings {cat_substrings} or in {cat_col_names})")
    print(f"  Scalar features: {len(scalar_cols)}")
# Out:
#   Categorical features: 15 (containing substrings ['_has_', '_present'] or in ['ORF_frame_l_cpat'])
#   Scalar features: 271

# %% [markdown]
# ### 3.2 Obtain entropy groups

# %%
entropy_df

# %%
# Simple group definition based on H_pred percentiles
low_perc_th = 0.1
low_th = np.percentile(entropy_df['H_pred'], low_perc_th * 100)
low_mask = entropy_df['H_pred'] <= low_th

low_df = entropy_df[low_mask]

grp1 = low_df[low_df["true_label"] == 0].index
grp2 = low_df[low_df["true_label"] == 1].index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Simple group definition based on H_pred percentiles
#       2 low_perc_th = 0.1
# ----> 3 low_th = np.percentile(entropy_df['H_pred'], low_perc_th * 100)
#       4 low_mask = entropy_df['H_pred'] <= low_th
#       6 low_df = entropy_df[low_mask]
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# ## 3.3 Remove any features that became constant only within entropy groups

# %%
scalar_features = remove_constant_features(scalar_features.loc[grp1.union(grp2)], name="Scalar features in entropy groups")
categorical_features = remove_constant_features(categorical_features.loc[grp1.union(grp2)], name="Categorical features in entropy groups")
# Out:
# Scalar features in entropy groups: Removing 3 constant features
#   Constant features: ['pseudo_sum_fragmented', 'te_ple_count', 'te_ple_count_per_kb']
# Categorical features in entropy groups: Removing 2 constant features
#   Constant features: ['te_has_ple', 'any_nonb_present']

# %% [markdown]
# ## Section 4: Statistical tests

# %% [markdown]
# ### 4.1 Due diligence on test choices

# %%
from scipy.stats import shapiro, levene
import warnings

warnings.filterwarnings('ignore')

# Test normality for all scalar features using Shapiro-Wilk test
normality_results = []

for col in scalar_features.columns:
    d1_vals = scalar_features.loc[grp1, col].dropna()
    d2_vals = scalar_features.loc[grp2, col].dropna()
    
    # Shapiro-Wilk test for normality (H0: data is normally distributed)
    stat_d1, p_d1 = shapiro(d1_vals)
    stat_d2, p_d2 = shapiro(d2_vals)
    
    # Levene's test for equality of variances (H0: variances are equal)
    stat_levene, p_levene = levene(d1_vals, d2_vals)
    
    normality_results.append({
        'feature': col,
        'normality_low_p': p_d1,
        'normality_high_p': p_d2,
        'levene_p': p_levene,
        'normal_both': (p_d1 > 0.05) and (p_d2 > 0.05),
        'equal_var': p_levene > 0.05
    })

normality_df = pd.DataFrame(normality_results).set_index('feature')

# Summary
n_normal_both = normality_df['normal_both'].sum()
n_equal_var = normality_df['equal_var'].sum()

print(f"✓ Normality tests completed for {len(normality_df)} scalar features")
print(f"\nSummary:")
print(f"  Features with BOTH groups normally distributed (p > 0.05): {n_normal_both} / {len(normality_df)} ({100*n_normal_both/len(normality_df):.1f}%)")
print(f"  Features with equal variances (Levene p > 0.05): {n_equal_var} / {len(normality_df)} ({100*n_equal_var/len(normality_df):.1f}%)")
print(f"\n  → Mann-Whitney U test (non-parametric) is appropriate for most features")
print(f"  → T-test could be used only for {n_normal_both} features with both normal distributions")
print(f"\nTop features with worst normality (lowest p-values):")
normality_df[['normality_low_p', 'normality_high_p', 'levene_p', 'normal_both', 'equal_var']].sort_values('normality_low_p').head(20)
# Out:
# ✓ Normality tests completed for 433 scalar features
#
# Summary:
#   Features with BOTH groups normally distributed (p > 0.05): 0 / 433 (0.0%)
#   Features with equal variances (Levene p > 0.05): 54 / 433 (12.5%)
#
#   → Mann-Whitney U test (non-parametric) is appropriate for most features
#   → T-test could be used only for 0 features with both normal distributions
#
# Top features with worst normality (lowest p-values):
#                                     normality_low_p  normality_high_p  \
# feature
# pseudo_scrna_count                     3.618063e-69     1.800979e-113
# pseudo_scrna_count_per_kb              3.618063e-69     1.780529e-113
# pseudo_rrna_count_per_kb               3.618063e-69     1.744837e-113
# pseudo_rrna_count                      3.618063e-69     1.800979e-113
# te_rc_count                            3.618063e-69     1.552349e-113
# te_rc_count_per_kb                     3.618063e-69     1.549669e-113
# pseudo_max_perc_del                    4.132785e-69     1.690542e-113
# pseudo_min_perc_del                    4.132785e-69     1.690542e-113
# pseudo_mean_perc_del                   4.132785e-69     1.690542e-113
# pseudo_min_perc_ins                    4.924919e-69     1.741274e-113
# pseudo_mean_perc_ins                   4.924919e-69     1.741274e-113
# pseudo_max_perc_ins                    4.924919e-69     1.741274e-113
# pseudo_ancient_count_per_kb            4.998508e-69     1.688296e-113
# pseudo_ancient_count                   5.875919e-69     1.800979e-113
# pseudo_trna_count_per_kb               6.769980e-69     2.367886e-113
# pseudo_trna_count                      6.875528e-69     2.502364e-113
# pseudo_min_hit_reference_coverage      7.629662e-69     5.155238e-113
# pseudo_mean_hit_reference_coverage     9.108388e-69     5.155238e-113
# pseudo_max_hit_reference_coverage      9.340221e-69     5.155238e-113
# pseudogene_gaps_min                    1.237079e-68     4.873280e-113
#
#                                     levene_p  normal_both  equal_var
# feature
# pseudo_scrna_count                  0.775851        False       True
# pseudo_scrna_count_per_kb           0.084195        False       True
# pseudo_rrna_count_per_kb            0.219161        False       True
# pseudo_rrna_count                   0.775851        False       True
# te_rc_count                         0.389620        False       True
# te_rc_count_per_kb                  0.062474        False       True
# pseudo_max_perc_del                 0.807497        False       True
# pseudo_min_perc_del                 0.807497        False       True
# pseudo_mean_perc_del                0.807497        False       True
# pseudo_min_perc_ins                 0.919276        False       True
# pseudo_mean_perc_ins                0.919276        False       True
# pseudo_max_perc_ins                 0.919276        False       True
# pseudo_ancient_count_per_kb         0.002415        False      False
# pseudo_ancient_count                0.044146        False      False
# pseudo_trna_count_per_kb            0.000133        False      False
# pseudo_trna_count                   0.048809        False      False
# pseudo_min_hit_reference_coverage   0.552590        False       True
# pseudo_mean_hit_reference_coverage  0.372177        False       True
# pseudo_max_hit_reference_coverage   0.243224        False       True
# pseudogene_gaps_min                 0.681020        False       True

# %% [markdown]
# ### 4.2 Tests

# %%
from scipy.cluster import hierarchy
from scipy.spatial.distance import squareform
from scipy.stats import mannwhitneyu, rankdata, chisquare
from sklearn.feature_selection import f_classif, mutual_info_classif
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from statsmodels.stats.multitest import multipletests

# %%
def vargha_delaney_A(d1, d2):
    """
    Vargha-Delaney A statistic: P(X1 > X2) for unequal sample sizes.

    Parameters:
    -----------
    d1, d2 : array-like
        Two samples to compare

    Returns:
    --------
    float: Probability in range [0, 1]
    """
    n1, n2 = len(d1), len(d2)
    U = mannwhitneyu(d1, d2, method="auto").statistic
    return U / (n1 * n2)

# %%
d1 = scalar_features.loc[grp1,]
d2 = scalar_features.loc[grp2]

stat, pval = mannwhitneyu(d2, d1, alternative="two-sided")
vda = vargha_delaney_A(d2.values, d1.values)
interpretation = [f"{val:.3f} probability of being higher in lncRNA group" for val in vda]

mannu_df = pd.DataFrame({
    'statistic': stat,
    'p_value': pval,
    'vda': vda,
    'interpretation': interpretation},
    index=d1.columns)

# %%
n_sign = (mannu_df['p_value'] < 0.05).sum()
print(f"Number of features with significant difference between lncRNA and Coding groups (Mann-Whitney U test, p < 0.05): {n_sign} / {len(mannu_df)}")
print(f"")
mannu_df.sort_values('vda', ascending=False)
# Out:
# Number of features with significant difference between lncRNA and Coding groups (Mann-Whitney U test, p < 0.05): 375 / 433
#                            statistic  p_value       vda  \
# ORF_T0_MW_lncDC           16226924.0      0.0  0.998757
# ORF_T0_length_lncDC       16226840.5      0.0  0.998752
# ORF_l_cpat                16226839.5      0.0  0.998752
# ORF.Max.Len_lncfinder     16226839.5      0.0  0.998752
# Seq.pct.Dist_lncfinder    16226744.0      0.0  0.998746
# ...                              ...      ...       ...
# ir_gaps_mean_pct           1094136.5      0.0  0.067343
# Dot_Dist.Ratio_lncfinder    518214.0      0.0  0.031896
# MFE_lncfinder               383559.0      0.0  0.023608
# SS.Dist.Ratio_lncfinder     349534.0      0.0  0.021514
# RCB_T0_lncDC                 92740.0      0.0  0.005708
#
#                                                              interpretation
# ORF_T0_MW_lncDC           0.999 probability of being higher in lncRNA group
# ORF_T0_length_lncDC       0.999 probability of being higher in lncRNA group
# ORF_l_cpat                0.999 probability of being higher in lncRNA group
# ORF.Max.Len_lncfinder     0.999 probability of being higher in lncRNA group
# Seq.pct.Dist_lncfinder    0.999 probability of being higher in lncRNA group
# ...                                                                     ...
# ir_gaps_mean_pct          0.067 probability of being higher in lncRNA group
# Dot_Dist.Ratio_lncfinder  0.032 probability of being higher in lncRNA group
# MFE_lncfinder             0.024 probability of being higher in lncRNA group
# SS.Dist.Ratio_lncfinder   0.022 probability of being higher in lncRNA group
# RCB_T0_lncDC              0.006 probability of being higher in lncRNA group
#
# [433 rows x 4 columns]

# %%
from scipy.stats import chi2_contingency

c1 = categorical_features.loc[grp1,]
c2 = categorical_features.loc[grp2]
# Perform chi-squared test for each categorical feature
chi2_results = []
for col in c1.columns:
    contingency_table = pd.crosstab(
        pd.concat([c1[col], c2[col]]),
        pd.concat([pd.Series([0]*len(c1), index=c1.index), pd.Series([1]*len(c2), index=c2.index)])
    )

    if col == 'lctr_has_simple_repeat':
        print(f"Contingency table for {col}:")
        print(contingency_table)
    
    chi2_stat, chi2_pval, _, _ = chi2_contingency(contingency_table)

    # Calculate Cramér's V for categorical features
    n = len(c1) + len(c2)
    cramers_v = np.sqrt(chi2_stat / (n * (min(contingency_table.shape) - 1))) if min(contingency_table.shape) > 1 else 0

    # Phi
    phi = np.sqrt(chi2_stat / n) if n > 0 else 0

    # Calculate contingency table odds ratio if it's 2x2
    if contingency_table.shape == (2, 2):
        a = contingency_table.iloc[0, 0]  # No & Low Entropy
        b = contingency_table.iloc[0, 1]  # No & High Entropy
        c = contingency_table.iloc[1, 0]  # Yes & Low Entropy
        d = contingency_table.iloc[1, 1]  # Yes & High Entropy

        # If any of the counts are zero, we can add 0.5 to all cells (Haldane-Anscombe correction) to avoid infinite odds ratios
        if (b * c) == 0 or (a * d) == 0:
            a += 0.5
            b += 0.5
            c += 0.5
            d += 0.5
            print(f"Applied Haldane-Anscombe correction for {col} due to zero counts")

        odds_ratio = (a * d) / (b * c)
        direction = 'positive' if odds_ratio > 1 else 'negative'
    else:
        odds_ratio = np.nan  # Not defined for non-2x2 tables
        direction = 'undef'
    
    interpretation = f"Odds of being protein-coding while having the feature are {odds_ratio:.2f} times the odds without having the feature"

    chi2_results.append({'feature': col, 'statistic': chi2_stat, 'p_value': chi2_pval, 'cramers_v': cramers_v, 'phi': phi, 'odds_ratio': odds_ratio, 'direction': direction, 'interpretation': interpretation})

chi2_df = pd.DataFrame(chi2_results).set_index('feature')
n_sign_chi2 = (chi2_df['p_value'] < 0.05).sum()
print(f"Number of categorical features with significant difference (Chi-squared test, p < 0.05): {n_sign_chi2} / {len(chi2_df)}")
print("")
chi2_df.sort_values('p_value')
# Out:
# Contingency table for lctr_has_simple_repeat:
# col_0                      0     1
# lctr_has_simple_repeat
# 0                       1395  3432
# 1                        325  6014
# Applied Haldane-Anscombe correction for ir_present due to zero counts
# Number of categorical features with significant difference (Chi-squared test, p < 0.05): 16 / 22
#                            statistic        p_value  cramers_v       phi  \
# feature
# te_has_ltr               2673.433497   0.000000e+00   0.489312  0.489312
# gq_present               1366.635288  3.738647e-299   0.349846  0.349846
# lctr_has_simple_repeat   1186.638380  4.888385e-260   0.325995  0.325995
# z_present                 707.181579  8.204154e-156   0.251661  0.251661
# te_has_line               649.096697  3.512060e-143   0.241105  0.241105
# tri_present               377.993042   3.403380e-84   0.183990  0.183990
# dr_present                347.122057   1.794154e-77   0.176316  0.176316
# mr_present                293.133303   1.032406e-65   0.162026  0.162026
# str_present               222.796698   2.220085e-50   0.141256  0.141256
# lctr_has_low_complexity   219.543379   1.137588e-49   0.140220  0.140220
# te_has_sine               159.534018   1.430410e-36   0.119530  0.119530
# lctr_has_satellite         97.229014   6.175507e-23   0.093314  0.093314
# apr_present                84.770532   3.350813e-20   0.087131  0.087131
# ir_present                 54.146354   1.860989e-13   0.069636  0.069636
# te_has_dna                 47.386148   5.829316e-12   0.065144  0.065144
# te_has_srprna               6.810738   9.061131e-03   0.024697  0.024697
# pseudo_has_snrna            2.440378   1.182477e-01   0.014784  0.014784
# pseudo_has_trna             1.325289   2.496450e-01   0.010894  0.010894
# te_has_retroposon           1.167064   2.800053e-01   0.010223  0.010223
# te_has_rc                   0.003672   9.516803e-01   0.000573  0.000573
# pseudo_has_rrna             0.000000   1.000000e+00   0.000000  0.000000
# pseudo_has_scrna            0.000000   1.000000e+00   0.000000  0.000000
#
#                          odds_ratio direction  \
# feature
# te_has_ltr                 0.062830  negative
# gq_present                19.746085  positive
# lctr_has_simple_repeat     7.521544  positive
# z_present                  5.421061  positive
# te_has_line                0.256669  negative
# tri_present                3.368704  positive
# dr_present                 5.779480  positive
# mr_present                 6.900632  positive
# str_present               14.139791  positive
# lctr_has_low_complexity    4.426762  positive
# te_has_sine                0.515630  negative
# lctr_has_satellite         0.112748  negative
# apr_present                1.792263  positive
# ir_present               127.095350  positive
# te_has_dna                 0.642930  negative
# te_has_srprna              0.259341  negative
# pseudo_has_snrna           0.476817  negative
# pseudo_has_trna            0.409134  negative
# te_has_retroposon          0.715623  negative
# te_has_rc                  0.364041  negative
# pseudo_has_rrna            0.728236  negative
# pseudo_has_scrna           0.728236  negative
#
#                                                             interpretation
# feature
# te_has_ltr               Odds of being protein-coding while having the ...
# gq_present               Odds of being protein-coding while having the ...
# lctr_has_simple_repeat   Odds of being protein-coding while having the ...
# z_present                Odds of being protein-coding while having the ...
# te_has_line              Odds of being protein-coding while having the ...
# tri_present              Odds of being protein-coding while having the ...
# dr_present               Odds of being protein-coding while having the ...
# mr_present               Odds of being protein-coding while having the ...
# str_present              Odds of being protein-coding while having the ...
# lctr_has_low_complexity  Odds of being protein-coding while having the ...
# te_has_sine              Odds of being protein-coding while having the ...
# lctr_has_satellite       Odds of being protein-coding while having the ...
# apr_present              Odds of being protein-coding while having the ...
# ir_present               Odds of being protein-coding while having the ...
# te_has_dna               Odds of being protein-coding while having the ...
# te_has_srprna            Odds of being protein-coding while having the ...
# pseudo_has_snrna         Odds of being protein-coding while having the ...
# pseudo_has_trna          Odds of being protein-coding while having the ...
# te_has_retroposon        Odds of being protein-coding while having the ...
# te_has_rc                Odds of being protein-coding while having the ...
# pseudo_has_rrna          Odds of being protein-coding while having the ...
# pseudo_has_scrna         Odds of being protein-coding while having the ...

# %%
# Example: Contingency table, odds ratio, and effect sizes for lctr_has_simple_repeat
feature_name = 'gq_present'

# Create contingency table
contingency_table = pd.crosstab(
    pd.concat([categorical_features.loc[grp1, feature_name], categorical_features.loc[grp2, feature_name]]),
    pd.concat([pd.Series([0]*len(grp1), index=grp1), pd.Series([1]*len(grp2), index=grp2)]),
    rownames=[feature_name],
    colnames=['group']
)
contingency_table.columns = ['lncRNA', 'Coding']
contingency_table.index = ['No', 'Yes']

print(f"Contingency Table for {feature_name}:")
print(contingency_table)
print()

# Calculate odds ratio
a = contingency_table.iloc[0, 0]  # No & lncRNA
b = contingency_table.iloc[0, 1]  # No & Coding
c = contingency_table.iloc[1, 0]  # Yes & lncRNA
d = contingency_table.iloc[1, 1]  # Yes & Coding
n = a + b + c + d

chi2_stat, p_val, dof, expected_freq = chi2_contingency(contingency_table)

# Calculate odds ratio (only for 2×2 tables)
if (b * c) == 0:
    odds_ratio = np.nan
    print(f"Odds Ratio: undefined (zero cell count)")
else:
    odds_ratio = (a * d) / (b * c)
    print(f"Odds Ratio: {odds_ratio:.4f}")
    print(f"Interpretation: Transcripts with GQ have {odds_ratio:.2f} times higher odds of being protein-coding than without the feature")
    print(f"Interpretation: Coding transcript have {odds_ratio:.2f} times higher odds of containing GQ than lncRNA transcripts")

print()

# Calculate Phi coefficient (effect size for 2×2 contingency tables)
phi = np.sqrt(chi2_stat / n) if n > 0 else 0
print(f"Phi coefficient (effect size): {phi:.4f}")
print(f"  Interpretation: 0.0-0.1 (negligible), 0.1-0.3 (small), 0.3-0.5 (medium), >0.5 (large)")
print()

# Calculate Cramér's V (generalizes to larger tables)
min_dim = min(contingency_table.shape) - 1
cramers_v = np.sqrt(chi2_stat / (n * min_dim)) if min_dim > 0 else 0
print(f"Cramér's V (effect size): {cramers_v:.4f}")
print()

# Chi-squared test results
print(f"Chi-squared statistic: {chi2_stat:.4f}")
print(f"P-value: {p_val:.4e}")
print(f"Degrees of freedom: {dof}")
print(f"Significant (p < 0.05): {p_val < 0.05}")
# Out:
# Contingency Table for gq_present:
#      lncRNA  Coding
# No      367     128
# Yes    1353    9318
#
# Odds Ratio: 19.7461
# Interpretation: Transcripts with GQ have 19.75 times higher odds of being protein-coding than without the feature
# Interpretation: Coding transcript have 19.75 times higher odds of containing GQ than lncRNA transcripts
#
# Phi coefficient (effect size): 0.3498
#   Interpretation: 0.0-0.1 (negligible), 0.1-0.3 (small), 0.3-0.5 (medium), >0.5 (large)
#
# Cramér's V (effect size): 0.3498
#
# Chi-squared statistic: 1366.6353
# P-value: 3.7386e-299
# Degrees of freedom: 1
# Significant (p < 0.05): True

# %%
# Calculate ranks for Mann-Whitney U test
mannu_df['abs_vda'] = abs(mannu_df['vda'] - 0.5)
mannu_df['rank'] = rankdata(mannu_df['abs_vda'])
mannu_df["rank_perc"] = mannu_df["rank"] / len(mannu_df) * 100  # Higher is better

# Calculate ranks for Chi-squared test
chi2_df["rank"] = rankdata(chi2_df['cramers_v'])
chi2_df["rank_perc"] = chi2_df["rank"] / len(chi2_df) * 100  # Higher is better

# Combine results and apply FDR correction
mannu_df['test'] = 'Mann-Whitney U'
chi2_df['test'] = 'Chi-squared'
combined_df = pd.concat([mannu_df, chi2_df], axis=0)
combined_df['adjusted_p_value'] = multipletests(combined_df['p_value'], method=FDR_METHOD, alpha=FDR_ALPHA)[1]
combined_df['significant'] = combined_df['adjusted_p_value'] < FDR_ALPHA
n_sign_fdr = combined_df['significant'].sum()
print(f"Number of features with significant difference after FDR correction (adjusted p < {FDR_ALPHA}): {n_sign_fdr} / {len(combined_df)}")
print("")
combined_df.loc[~combined_df["significant"], "interpretation"] = "Result is not statistically significant after FDR correction"
combined_df = combined_df.sort_values('rank_perc', ascending=False)
combined_df[combined_df["significant"]].head(20)
# Out:
# Number of features with significant difference after FDR correction (adjusted p < 0.01): 360 / 455
#                                statistic  p_value       vda  \
# te_has_ltr                  2.673433e+03      0.0       NaN
# ORF_T0_MW_lncDC             1.622692e+07      0.0  0.998757
# ORF_T0_length_lncDC         1.622684e+07      0.0  0.998752
# ORF.Max.Len_lncfinder       1.622684e+07      0.0  0.998752
# ORF_l_cpat                  1.622684e+07      0.0  0.998752
# Seq.pct.Dist_lncfinder      1.622674e+07      0.0  0.998746
# Seq.lnc.Dist_lncfinder      1.622641e+07      0.0  0.998726
# Fickett_l_cpat              1.617740e+07      0.0  0.995709
# Hexamer_l_cpat              1.616785e+07      0.0  0.995121
# Signal.Peak_lncfinder       1.615966e+07      0.0  0.994617
# RCB_T0_lncDC                9.274000e+04      0.0  0.005708
# Hexamer_score_ORF_T0_lncDC  1.614588e+07      0.0  0.993768
# kmerScore_9mer_feelnc       1.614124e+07      0.0  0.993483
# kmerScore_6mer_feelnc       1.600543e+07      0.0  0.985124
# SNR_lncfinder               1.600516e+07      0.0  0.985107
# kmerScore_12mer_feelnc      1.598986e+07      0.0  0.984166
# SS.Dist.Ratio_lncfinder     3.495340e+05      0.0  0.021514
# ORF_T0_coverage_lncDC       1.589408e+07      0.0  0.978271
# ORF.Max.Cov_lncfinder       1.588291e+07      0.0  0.977583
# ORF_coverage_l_cpat         1.588291e+07      0.0  0.977583
#
#                                                                interpretation  \
# te_has_ltr                  Odds of being protein-coding while having the ...
# ORF_T0_MW_lncDC             0.999 probability of being higher in lncRNA group
# ORF_T0_length_lncDC         0.999 probability of being higher in lncRNA group
# ORF.Max.Len_lncfinder       0.999 probability of being higher in lncRNA group
# ORF_l_cpat                  0.999 probability of being higher in lncRNA group
# Seq.pct.Dist_lncfinder      0.999 probability of being higher in lncRNA group
# Seq.lnc.Dist_lncfinder      0.999 probability of being higher in lncRNA group
# Fickett_l_cpat              0.996 probability of being higher in lncRNA group
# Hexamer_l_cpat              0.995 probability of being higher in lncRNA group
# Signal.Peak_lncfinder       0.995 probability of being higher in lncRNA group
# RCB_T0_lncDC                0.006 probability of being higher in lncRNA group
# Hexamer_score_ORF_T0_lncDC  0.994 probability of being higher in lncRNA group
# kmerScore_9mer_feelnc       0.993 probability of being higher in lncRNA group
# kmerScore_6mer_feelnc       0.985 probability of being higher in lncRNA group
# SNR_lncfinder               0.985 probability of being higher in lncRNA group
# kmerScore_12mer_feelnc      0.984 probability of being higher in lncRNA group
# SS.Dist.Ratio_lncfinder     0.022 probability of being higher in lncRNA group
# ORF_T0_coverage_lncDC       0.978 probability of being higher in lncRNA group
# ORF.Max.Cov_lncfinder       0.978 probability of being higher in lncRNA group
# ORF_coverage_l_cpat         0.978 probability of being higher in lncRNA group
#
#                              abs_vda   rank   rank_perc            test  \
# te_has_ltr                       NaN   22.0  100.000000     Chi-squared
# ORF_T0_MW_lncDC             0.498757  433.0  100.000000  Mann-Whitney U
# ORF_T0_length_lncDC         0.498752  432.0   99.769053  Mann-Whitney U
# ORF.Max.Len_lncfinder       0.498752  430.5   99.422633  Mann-Whitney U
# ORF_l_cpat                  0.498752  430.5   99.422633  Mann-Whitney U
# Seq.pct.Dist_lncfinder      0.498746  429.0   99.076212  Mann-Whitney U
# Seq.lnc.Dist_lncfinder      0.498726  428.0   98.845266  Mann-Whitney U
# Fickett_l_cpat              0.495709  427.0   98.614319  Mann-Whitney U
# Hexamer_l_cpat              0.495121  426.0   98.383372  Mann-Whitney U
# Signal.Peak_lncfinder       0.494617  425.0   98.152425  Mann-Whitney U
# RCB_T0_lncDC                0.494292  424.0   97.921478  Mann-Whitney U
# Hexamer_score_ORF_T0_lncDC  0.493768  423.0   97.690531  Mann-Whitney U
# kmerScore_9mer_feelnc       0.493483  422.0   97.459584  Mann-Whitney U
# kmerScore_6mer_feelnc       0.485124  421.0   97.228637  Mann-Whitney U
# SNR_lncfinder               0.485107  420.0   96.997691  Mann-Whitney U
# kmerScore_12mer_feelnc      0.484166  419.0   96.766744  Mann-Whitney U
# SS.Dist.Ratio_lncfinder     0.478486  418.0   96.535797  Mann-Whitney U
# ORF_T0_coverage_lncDC       0.478271  417.0   96.304850  Mann-Whitney U
# ORF.Max.Cov_lncfinder       0.477583  415.5   95.958430  Mann-Whitney U
# ORF_coverage_l_cpat         0.477583  415.5   95.958430  Mann-Whitney U
#
#                             cramers_v       phi  odds_ratio direction  \
# te_has_ltr                   0.489312  0.489312     0.06283  negative
# ORF_T0_MW_lncDC                   NaN       NaN         NaN       NaN
# ORF_T0_length_lncDC               NaN       NaN         NaN       NaN
# ORF.Max.Len_lncfinder             NaN       NaN         NaN       NaN
# ORF_l_cpat                        NaN       NaN         NaN       NaN
# Seq.pct.Dist_lncfinder            NaN       NaN         NaN       NaN
# Seq.lnc.Dist_lncfinder            NaN       NaN         NaN       NaN
# Fickett_l_cpat                    NaN       NaN         NaN       NaN
# Hexamer_l_cpat                    NaN       NaN         NaN       NaN
# Signal.Peak_lncfinder             NaN       NaN         NaN       NaN
# RCB_T0_lncDC                      NaN       NaN         NaN       NaN
# Hexamer_score_ORF_T0_lncDC        NaN       NaN         NaN       NaN
# kmerScore_9mer_feelnc             NaN       NaN         NaN       NaN
# kmerScore_6mer_feelnc             NaN       NaN         NaN       NaN
# SNR_lncfinder                     NaN       NaN         NaN       NaN
# kmerScore_12mer_feelnc            NaN       NaN         NaN       NaN
# SS.Dist.Ratio_lncfinder           NaN       NaN         NaN       NaN
# ORF_T0_coverage_lncDC             NaN       NaN         NaN       NaN
# ORF.Max.Cov_lncfinder             NaN       NaN         NaN       NaN
# ORF_coverage_l_cpat               NaN       NaN         NaN       NaN
#
#                             adjusted_p_value  significant
# te_has_ltr                               0.0         True
# ORF_T0_MW_lncDC                          0.0         True
# ORF_T0_length_lncDC                      0.0         True
# ORF.Max.Len_lncfinder                    0.0         True
# ORF_l_cpat                               0.0         True
# Seq.pct.Dist_lncfinder                   0.0         True
# Seq.lnc.Dist_lncfinder                   0.0         True
# Fickett_l_cpat                           0.0         True
# Hexamer_l_cpat                           0.0         True
# Signal.Peak_lncfinder                    0.0         True
# RCB_T0_lncDC                             0.0         True
# Hexamer_score_ORF_T0_lncDC               0.0         True
# kmerScore_9mer_feelnc                    0.0         True
# kmerScore_6mer_feelnc                    0.0         True
# SNR_lncfinder                            0.0         True
# kmerScore_12mer_feelnc                   0.0         True
# SS.Dist.Ratio_lncfinder                  0.0         True
# ORF_T0_coverage_lncDC                    0.0         True
# ORF.Max.Cov_lncfinder                    0.0         True
# ORF_coverage_l_cpat                      0.0         True

# %%
tidy_results = combined_df[["adjusted_p_value", "rank_perc", "test", "interpretation", "significant"]]
tidy_results.head(20)
# Out:
#                             adjusted_p_value   rank_perc            test  \
# te_has_ltr                               0.0  100.000000     Chi-squared
# ORF_T0_MW_lncDC                          0.0  100.000000  Mann-Whitney U
# ORF_T0_length_lncDC                      0.0   99.769053  Mann-Whitney U
# ORF.Max.Len_lncfinder                    0.0   99.422633  Mann-Whitney U
# ORF_l_cpat                               0.0   99.422633  Mann-Whitney U
# Seq.pct.Dist_lncfinder                   0.0   99.076212  Mann-Whitney U
# Seq.lnc.Dist_lncfinder                   0.0   98.845266  Mann-Whitney U
# Fickett_l_cpat                           0.0   98.614319  Mann-Whitney U
# Hexamer_l_cpat                           0.0   98.383372  Mann-Whitney U
# Signal.Peak_lncfinder                    0.0   98.152425  Mann-Whitney U
# RCB_T0_lncDC                             0.0   97.921478  Mann-Whitney U
# Hexamer_score_ORF_T0_lncDC               0.0   97.690531  Mann-Whitney U
# kmerScore_9mer_feelnc                    0.0   97.459584  Mann-Whitney U
# kmerScore_6mer_feelnc                    0.0   97.228637  Mann-Whitney U
# SNR_lncfinder                            0.0   96.997691  Mann-Whitney U
# kmerScore_12mer_feelnc                   0.0   96.766744  Mann-Whitney U
# SS.Dist.Ratio_lncfinder                  0.0   96.535797  Mann-Whitney U
# ORF_T0_coverage_lncDC                    0.0   96.304850  Mann-Whitney U
# ORF.Max.Cov_lncfinder                    0.0   95.958430  Mann-Whitney U
# ORF_coverage_l_cpat                      0.0   95.958430  Mann-Whitney U
#
#                                                                interpretation  \
# te_has_ltr                  Odds of being protein-coding while having the ...
# ORF_T0_MW_lncDC             0.999 probability of being higher in lncRNA group
# ORF_T0_length_lncDC         0.999 probability of being higher in lncRNA group
# ORF.Max.Len_lncfinder       0.999 probability of being higher in lncRNA group
# ORF_l_cpat                  0.999 probability of being higher in lncRNA group
# Seq.pct.Dist_lncfinder      0.999 probability of being higher in lncRNA group
# Seq.lnc.Dist_lncfinder      0.999 probability of being higher in lncRNA group
# Fickett_l_cpat              0.996 probability of being higher in lncRNA group
# Hexamer_l_cpat              0.995 probability of being higher in lncRNA group
# Signal.Peak_lncfinder       0.995 probability of being higher in lncRNA group
# RCB_T0_lncDC                0.006 probability of being higher in lncRNA group
# Hexamer_score_ORF_T0_lncDC  0.994 probability of being higher in lncRNA group
# kmerScore_9mer_feelnc       0.993 probability of being higher in lncRNA group
# kmerScore_6mer_feelnc       0.985 probability of being higher in lncRNA group
# SNR_lncfinder               0.985 probability of being higher in lncRNA group
# kmerScore_12mer_feelnc      0.984 probability of being higher in lncRNA group
# SS.Dist.Ratio_lncfinder     0.022 probability of being higher in lncRNA group
# ORF_T0_coverage_lncDC       0.978 probability of being higher in lncRNA group
# ORF.Max.Cov_lncfinder       0.978 probability of being higher in lncRNA group
# ORF_coverage_l_cpat         0.978 probability of being higher in lncRNA group
#
#                             significant
# te_has_ltr                         True
# ORF_T0_MW_lncDC                    True
# ORF_T0_length_lncDC                True
# ORF.Max.Len_lncfinder              True
# ORF_l_cpat                         True
# Seq.pct.Dist_lncfinder             True
# Seq.lnc.Dist_lncfinder             True
# Fickett_l_cpat                     True
# Hexamer_l_cpat                     True
# Signal.Peak_lncfinder              True
# RCB_T0_lncDC                       True
# Hexamer_score_ORF_T0_lncDC         True
# kmerScore_9mer_feelnc              True
# kmerScore_6mer_feelnc              True
# SNR_lncfinder                      True
# kmerScore_12mer_feelnc             True
# SS.Dist.Ratio_lncfinder            True
# ORF_T0_coverage_lncDC              True
# ORF.Max.Cov_lncfinder              True
# ORF_coverage_l_cpat                True

# %% [markdown]
# ## 5. Output tables

# %% [markdown]
# ### 5.1 Save output csv for downstream analysis

# %%
combined_df[combined_df["significant"]].to_csv(OUTPUT_DIR / "low_entropy_pc_v_lnc_statistical_tests_results.csv")

# %%
# Set pandas display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Combined table, top 20 raw features

# %%
tidy_columns = ["adjusted_p_value", "rank_perc", "test", "vda", "cramers_v", "odds_ratio", "interpretation", "significant"]
tidy_results = combined_df[tidy_columns]
tidy_results.head(20)
# Out:
#                             adjusted_p_value   rank_perc            test  \
# te_has_ltr                               0.0  100.000000     Chi-squared
# ORF_T0_MW_lncDC                          0.0  100.000000  Mann-Whitney U
# ORF_T0_length_lncDC                      0.0   99.769053  Mann-Whitney U
# ORF.Max.Len_lncfinder                    0.0   99.422633  Mann-Whitney U
# ORF_l_cpat                               0.0   99.422633  Mann-Whitney U
# Seq.pct.Dist_lncfinder                   0.0   99.076212  Mann-Whitney U
# Seq.lnc.Dist_lncfinder                   0.0   98.845266  Mann-Whitney U
# Fickett_l_cpat                           0.0   98.614319  Mann-Whitney U
# Hexamer_l_cpat                           0.0   98.383372  Mann-Whitney U
# Signal.Peak_lncfinder                    0.0   98.152425  Mann-Whitney U
# RCB_T0_lncDC                             0.0   97.921478  Mann-Whitney U
# Hexamer_score_ORF_T0_lncDC               0.0   97.690531  Mann-Whitney U
# kmerScore_9mer_feelnc                    0.0   97.459584  Mann-Whitney U
# kmerScore_6mer_feelnc                    0.0   97.228637  Mann-Whitney U
# SNR_lncfinder                            0.0   96.997691  Mann-Whitney U
# kmerScore_12mer_feelnc                   0.0   96.766744  Mann-Whitney U
# SS.Dist.Ratio_lncfinder                  0.0   96.535797  Mann-Whitney U
# ORF_T0_coverage_lncDC                    0.0   96.304850  Mann-Whitney U
# ORF.Max.Cov_lncfinder                    0.0   95.958430  Mann-Whitney U
# ORF_coverage_l_cpat                      0.0   95.958430  Mann-Whitney U
#
#                                  vda  cramers_v  odds_ratio  \
# te_has_ltr                       NaN   0.489312     0.06283
# ORF_T0_MW_lncDC             0.998757        NaN         NaN
# ORF_T0_length_lncDC         0.998752        NaN         NaN
# ORF.Max.Len_lncfinder       0.998752        NaN         NaN
# ORF_l_cpat                  0.998752        NaN         NaN
# Seq.pct.Dist_lncfinder      0.998746        NaN         NaN
# Seq.lnc.Dist_lncfinder      0.998726        NaN         NaN
# Fickett_l_cpat              0.995709        NaN         NaN
# Hexamer_l_cpat              0.995121        NaN         NaN
# Signal.Peak_lncfinder       0.994617        NaN         NaN
# RCB_T0_lncDC                0.005708        NaN         NaN
# Hexamer_score_ORF_T0_lncDC  0.993768        NaN         NaN
# kmerScore_9mer_feelnc       0.993483        NaN         NaN
# kmerScore_6mer_feelnc       0.985124        NaN         NaN
# SNR_lncfinder               0.985107        NaN         NaN
# kmerScore_12mer_feelnc      0.984166        NaN         NaN
# SS.Dist.Ratio_lncfinder     0.021514        NaN         NaN
# ORF_T0_coverage_lncDC       0.978271        NaN         NaN
# ORF.Max.Cov_lncfinder       0.977583        NaN         NaN
# ORF_coverage_l_cpat         0.977583        NaN         NaN
#
#                                                                                                                       interpretation  \
# te_has_ltr                  Odds of being protein-coding while having the feature are 0.06 times the odds without having the feature
# ORF_T0_MW_lncDC                                                                    0.999 probability of being higher in lncRNA group
# ORF_T0_length_lncDC                                                                0.999 probability of being higher in lncRNA group
# ORF.Max.Len_lncfinder                                                              0.999 probability of being higher in lncRNA group
# ORF_l_cpat                                                                         0.999 probability of being higher in lncRNA group
# Seq.pct.Dist_lncfinder                                                             0.999 probability of being higher in lncRNA group
# Seq.lnc.Dist_lncfinder                                                             0.999 probability of being higher in lncRNA group
# Fickett_l_cpat                                                                     0.996 probability of being higher in lncRNA group
# Hexamer_l_cpat                                                                     0.995 probability of being higher in lncRNA group
# Signal.Peak_lncfinder                                                              0.995 probability of being higher in lncRNA group
# RCB_T0_lncDC                                                                       0.006 probability of being higher in lncRNA group
# Hexamer_score_ORF_T0_lncDC                                                         0.994 probability of being higher in lncRNA group
# kmerScore_9mer_feelnc                                                              0.993 probability of being higher in lncRNA group
# kmerScore_6mer_feelnc                                                              0.985 probability of being higher in lncRNA group
# SNR_lncfinder                                                                      0.985 probability of being higher in lncRNA group
# kmerScore_12mer_feelnc                                                             0.984 probability of being higher in lncRNA group
# SS.Dist.Ratio_lncfinder                                                            0.022 probability of being higher in lncRNA group
# ORF_T0_coverage_lncDC                                                              0.978 probability of being higher in lncRNA group
# ORF.Max.Cov_lncfinder                                                              0.978 probability of being higher in lncRNA group
# ORF_coverage_l_cpat                                                                0.978 probability of being higher in lncRNA group
#
#                             significant
# te_has_ltr                         True
# ORF_T0_MW_lncDC                    True
# ORF_T0_length_lncDC                True
# ORF.Max.Len_lncfinder              True
# ORF_l_cpat                         True
# Seq.pct.Dist_lncfinder             True
# Seq.lnc.Dist_lncfinder             True
# Fickett_l_cpat                     True
# Hexamer_l_cpat                     True
# Signal.Peak_lncfinder              True
# RCB_T0_lncDC                       True
# Hexamer_score_ORF_T0_lncDC         True
# kmerScore_9mer_feelnc              True
# kmerScore_6mer_feelnc              True
# SNR_lncfinder                      True
# kmerScore_12mer_feelnc             True
# SS.Dist.Ratio_lncfinder            True
# ORF_T0_coverage_lncDC              True
# ORF.Max.Cov_lncfinder              True
# ORF_coverage_l_cpat                True

# %% [markdown]
# ### Continuous variable table, top 20 raw significant features

# %%
tidy_results[(tidy_results["test"] == "Mann-Whitney U") & (tidy_results["significant"] == True)].head(20)
# Out:
#                             adjusted_p_value   rank_perc            test  \
# ORF_T0_MW_lncDC                          0.0  100.000000  Mann-Whitney U
# ORF_T0_length_lncDC                      0.0   99.769053  Mann-Whitney U
# ORF.Max.Len_lncfinder                    0.0   99.422633  Mann-Whitney U
# ORF_l_cpat                               0.0   99.422633  Mann-Whitney U
# Seq.pct.Dist_lncfinder                   0.0   99.076212  Mann-Whitney U
# Seq.lnc.Dist_lncfinder                   0.0   98.845266  Mann-Whitney U
# Fickett_l_cpat                           0.0   98.614319  Mann-Whitney U
# Hexamer_l_cpat                           0.0   98.383372  Mann-Whitney U
# Signal.Peak_lncfinder                    0.0   98.152425  Mann-Whitney U
# RCB_T0_lncDC                             0.0   97.921478  Mann-Whitney U
# Hexamer_score_ORF_T0_lncDC               0.0   97.690531  Mann-Whitney U
# kmerScore_9mer_feelnc                    0.0   97.459584  Mann-Whitney U
# kmerScore_6mer_feelnc                    0.0   97.228637  Mann-Whitney U
# SNR_lncfinder                            0.0   96.997691  Mann-Whitney U
# kmerScore_12mer_feelnc                   0.0   96.766744  Mann-Whitney U
# SS.Dist.Ratio_lncfinder                  0.0   96.535797  Mann-Whitney U
# ORF_T0_coverage_lncDC                    0.0   96.304850  Mann-Whitney U
# ORF.Max.Cov_lncfinder                    0.0   95.958430  Mann-Whitney U
# ORF_coverage_l_cpat                      0.0   95.958430  Mann-Whitney U
# MFE_lncfinder                            0.0   95.612009  Mann-Whitney U
#
#                                  vda  cramers_v  odds_ratio  \
# ORF_T0_MW_lncDC             0.998757        NaN         NaN
# ORF_T0_length_lncDC         0.998752        NaN         NaN
# ORF.Max.Len_lncfinder       0.998752        NaN         NaN
# ORF_l_cpat                  0.998752        NaN         NaN
# Seq.pct.Dist_lncfinder      0.998746        NaN         NaN
# Seq.lnc.Dist_lncfinder      0.998726        NaN         NaN
# Fickett_l_cpat              0.995709        NaN         NaN
# Hexamer_l_cpat              0.995121        NaN         NaN
# Signal.Peak_lncfinder       0.994617        NaN         NaN
# RCB_T0_lncDC                0.005708        NaN         NaN
# Hexamer_score_ORF_T0_lncDC  0.993768        NaN         NaN
# kmerScore_9mer_feelnc       0.993483        NaN         NaN
# kmerScore_6mer_feelnc       0.985124        NaN         NaN
# SNR_lncfinder               0.985107        NaN         NaN
# kmerScore_12mer_feelnc      0.984166        NaN         NaN
# SS.Dist.Ratio_lncfinder     0.021514        NaN         NaN
# ORF_T0_coverage_lncDC       0.978271        NaN         NaN
# ORF.Max.Cov_lncfinder       0.977583        NaN         NaN
# ORF_coverage_l_cpat         0.977583        NaN         NaN
# MFE_lncfinder               0.023608        NaN         NaN
#
#                                                                interpretation  \
# ORF_T0_MW_lncDC             0.999 probability of being higher in lncRNA group
# ORF_T0_length_lncDC         0.999 probability of being higher in lncRNA group
# ORF.Max.Len_lncfinder       0.999 probability of being higher in lncRNA group
# ORF_l_cpat                  0.999 probability of being higher in lncRNA group
# Seq.pct.Dist_lncfinder      0.999 probability of being higher in lncRNA group
# Seq.lnc.Dist_lncfinder      0.999 probability of being higher in lncRNA group
# Fickett_l_cpat              0.996 probability of being higher in lncRNA group
# Hexamer_l_cpat              0.995 probability of being higher in lncRNA group
# Signal.Peak_lncfinder       0.995 probability of being higher in lncRNA group
# RCB_T0_lncDC                0.006 probability of being higher in lncRNA group
# Hexamer_score_ORF_T0_lncDC  0.994 probability of being higher in lncRNA group
# kmerScore_9mer_feelnc       0.993 probability of being higher in lncRNA group
# kmerScore_6mer_feelnc       0.985 probability of being higher in lncRNA group
# SNR_lncfinder               0.985 probability of being higher in lncRNA group
# kmerScore_12mer_feelnc      0.984 probability of being higher in lncRNA group
# SS.Dist.Ratio_lncfinder     0.022 probability of being higher in lncRNA group
# ORF_T0_coverage_lncDC       0.978 probability of being higher in lncRNA group
# ORF.Max.Cov_lncfinder       0.978 probability of being higher in lncRNA group
# ORF_coverage_l_cpat         0.978 probability of being higher in lncRNA group
# MFE_lncfinder               0.024 probability of being higher in lncRNA group
#
#                             significant
# ORF_T0_MW_lncDC                    True
# ORF_T0_length_lncDC                True
# ORF.Max.Len_lncfinder              True
# ORF_l_cpat                         True
# Seq.pct.Dist_lncfinder             True
# Seq.lnc.Dist_lncfinder             True
# Fickett_l_cpat                     True
# Hexamer_l_cpat                     True
# Signal.Peak_lncfinder              True
# RCB_T0_lncDC                       True
# Hexamer_score_ORF_T0_lncDC         True
# kmerScore_9mer_feelnc              True
# kmerScore_6mer_feelnc              True
# SNR_lncfinder                      True
# kmerScore_12mer_feelnc             True
# SS.Dist.Ratio_lncfinder            True
# ORF_T0_coverage_lncDC              True
# ORF.Max.Cov_lncfinder              True
# ORF_coverage_l_cpat                True
# MFE_lncfinder                      True

# %% [markdown]
# ### Categorical variable table, top 20 raw features

# %%
tidy_results[(tidy_results["test"] == 'Chi-squared') & (tidy_results["significant"] == True)].head(20)
# Out:
#                          adjusted_p_value   rank_perc         test  vda  \
# te_has_ltr                   0.000000e+00  100.000000  Chi-squared  NaN
# gq_present                  1.829123e-298   95.454545  Chi-squared  NaN
# lctr_has_simple_repeat      2.022014e-259   90.909091  Chi-squared  NaN
# z_present                   2.276152e-155   86.363636  Chi-squared  NaN
# te_has_line                 9.290625e-143   81.818182  Chi-squared  NaN
# tri_present                  7.136120e-84   77.272727  Chi-squared  NaN
# dr_present                   3.628179e-77   72.727273  Chi-squared  NaN
# mr_present                   1.949148e-65   68.181818  Chi-squared  NaN
# str_present                  3.840831e-50   63.636364  Chi-squared  NaN
# lctr_has_low_complexity      1.945873e-49   59.090909  Chi-squared  NaN
# te_has_sine                  2.299776e-36   54.545455  Chi-squared  NaN
# lctr_has_satellite           9.212641e-23   50.000000  Chi-squared  NaN
# apr_present                  4.902315e-20   45.454545  Chi-squared  NaN
# ir_present                   2.597392e-13   40.909091  Chi-squared  NaN
# te_has_dna                   8.061820e-12   36.363636  Chi-squared  NaN
#
#                          cramers_v  odds_ratio  \
# te_has_ltr                0.489312    0.062830
# gq_present                0.349846   19.746085
# lctr_has_simple_repeat    0.325995    7.521544
# z_present                 0.251661    5.421061
# te_has_line               0.241105    0.256669
# tri_present               0.183990    3.368704
# dr_present                0.176316    5.779480
# mr_present                0.162026    6.900632
# str_present               0.141256   14.139791
# lctr_has_low_complexity   0.140220    4.426762
# te_has_sine               0.119530    0.515630
# lctr_has_satellite        0.093314    0.112748
# apr_present               0.087131    1.792263
# ir_present                0.069636  127.095350
# te_has_dna                0.065144    0.642930
#
#                                                                                                                      interpretation  \
# te_has_ltr                 Odds of being protein-coding while having the feature are 0.06 times the odds without having the feature
# gq_present                Odds of being protein-coding while having the feature are 19.75 times the odds without having the feature
# lctr_has_simple_repeat     Odds of being protein-coding while having the feature are 7.52 times the odds without having the feature
# z_present                  Odds of being protein-coding while having the feature are 5.42 times the odds without having the feature
# te_has_line                Odds of being protein-coding while having the feature are 0.26 times the odds without having the feature
# tri_present                Odds of being protein-coding while having the feature are 3.37 times the odds without having the feature
# dr_present                 Odds of being protein-coding while having the feature are 5.78 times the odds without having the feature
# mr_present                 Odds of being protein-coding while having the feature are 6.90 times the odds without having the feature
# str_present               Odds of being protein-coding while having the feature are 14.14 times the odds without having the feature
# lctr_has_low_complexity    Odds of being protein-coding while having the feature are 4.43 times the odds without having the feature
# te_has_sine                Odds of being protein-coding while having the feature are 0.52 times the odds without having the feature
# lctr_has_satellite         Odds of being protein-coding while having the feature are 0.11 times the odds without having the feature
# apr_present                Odds of being protein-coding while having the feature are 1.79 times the odds without having the feature
# ir_present               Odds of being protein-coding while having the feature are 127.10 times the odds without having the feature
# te_has_dna                 Odds of being protein-coding while having the feature are 0.64 times the odds without having the feature
#
#                          significant
# te_has_ltr                      True
# gq_present                      True
# lctr_has_simple_repeat          True
# z_present                       True
# te_has_line                     True
# tri_present                     True
# dr_present                      True
# mr_present                      True
# str_present                     True
# lctr_has_low_complexity         True
# te_has_sine                     True
# lctr_has_satellite              True
# apr_present                     True
# ir_present                      True
# te_has_dna                      True

# %% [markdown]
# ### Categorical variable table, all raw features

# %%
mann_tidy_columns = ["adjusted_p_value", "rank_perc", "test", "vda", "interpretation", "significant"]
combined_df.loc[(combined_df["test"] == 'Mann-Whitney U'), mann_tidy_columns]
# Out:
#                                     adjusted_p_value   rank_perc  \
# ORF_T0_MW_lncDC                         0.000000e+00  100.000000
# ORF_T0_length_lncDC                     0.000000e+00   99.769053
# ORF.Max.Len_lncfinder                   0.000000e+00   99.422633
# ORF_l_cpat                              0.000000e+00   99.422633
# Seq.pct.Dist_lncfinder                  0.000000e+00   99.076212
# Seq.lnc.Dist_lncfinder                  0.000000e+00   98.845266
# Fickett_l_cpat                          0.000000e+00   98.614319
# Hexamer_l_cpat                          0.000000e+00   98.383372
# Signal.Peak_lncfinder                   0.000000e+00   98.152425
# RCB_T0_lncDC                            0.000000e+00   97.921478
# Hexamer_score_ORF_T0_lncDC              0.000000e+00   97.690531
# kmerScore_9mer_feelnc                   0.000000e+00   97.459584
# kmerScore_6mer_feelnc                   0.000000e+00   97.228637
# SNR_lncfinder                           0.000000e+00   96.997691
# kmerScore_12mer_feelnc                  0.000000e+00   96.766744
# SS.Dist.Ratio_lncfinder                 0.000000e+00   96.535797
# ORF_T0_coverage_lncDC                   0.000000e+00   96.304850
# ORF.Max.Cov_lncfinder                   0.000000e+00   95.958430
# ORF_coverage_l_cpat                     0.000000e+00   95.958430
# MFE_lncfinder                           0.000000e+00   95.612009
# ORF_cover_feelnc                        0.000000e+00   95.381062
# kmerScore_3mer_feelnc                   0.000000e+00   95.150115
# orf_coverage_plncpro                    0.000000e+00   94.919169
# Signal.Q1_lncfinder                     0.000000e+00   94.688222
# Signal.Min_lncfinder                    0.000000e+00   94.457275
# Signal.Q2_lncfinder                     0.000000e+00   94.226328
# Signal.Max_lncfinder                    0.000000e+00   93.995381
# Dot_Dist.Ratio_lncfinder                0.000000e+00   93.764434
# ORF_T2_length_lncDC                     0.000000e+00   93.533487
# ORF_T2_MW_lncDC                         0.000000e+00   93.302540
# SS.lnc.dist_lncfinder                   0.000000e+00   93.071594
# Dot_lnc.dist_lncfinder                  0.000000e+00   92.840647
# SS.pct.dist_lncfinder                   0.000000e+00   92.609700
# RNA_size_feelnc                         0.000000e+00   92.263279
# transcript_length                       0.000000e+00   92.263279
# ORF_T1_length_lncDC                     0.000000e+00   91.916859
# SS_score_k5_lncDC                       0.000000e+00   91.685912
# Hexamer_score_ORF_T2_lncDC              0.000000e+00   91.454965
# Dot_pct.dist_lncfinder                  0.000000e+00   91.224018
# ir_gaps_mean_pct                        0.000000e+00   90.993072
# ir_mean_length_pct                      0.000000e+00   90.762125
# ir_gaps_median_pct                      0.000000e+00   90.531178
# str_mean_length_pct                     0.000000e+00   90.300231
# te_count_per_kb                         0.000000e+00   90.069284
# SS_score_k4_lncDC                       0.000000e+00   89.838337
# str_gaps_mean_pct                       0.000000e+00   89.607390
# te_mean_hit_length_pct                  0.000000e+00   89.376443
# te_max_hit_length_pct                   0.000000e+00   89.145497
# te_sum_hit_length_pct                   0.000000e+00   88.914550
# str_gaps_median_pct                     0.000000e+00   88.683603
# global_rm_total_length_pct              0.000000e+00   88.452656
# GCG_plncpro                             0.000000e+00   88.221709
# global_rm_count_per_kb                  0.000000e+00   87.990762
# CGA_plncpro                             0.000000e+00   87.759815
# CGG_plncpro                             0.000000e+00   87.528868
# TCG_plncpro                             0.000000e+00   87.297921
# mr_mean_length_pct                      0.000000e+00   87.066975
# SS_score_k3_lncDC                       0.000000e+00   86.836028
# CCG_plncpro                             0.000000e+00   86.605081
# te_min_hit_length_pct                   0.000000e+00   86.374134
# ir_gaps_max_pct                         0.000000e+00   86.143187
# CGC_plncpro                             0.000000e+00   85.912240
# dr_mean_length_pct                      0.000000e+00   85.681293
# global_gaps_max                         0.000000e+00   85.450346
# mr_gaps_mean_pct                        0.000000e+00   85.219400
# Fickett_score_lncDC                     0.000000e+00   84.988453
# mr_gaps_median_pct                      0.000000e+00   84.757506
# global_gaps_mean                        0.000000e+00   84.526559
# str_max_length_pct                      0.000000e+00   84.295612
# SS_score_k2_lncDC                       0.000000e+00   84.064665
# gq_total_length                         0.000000e+00   83.833718
# gq_hit_count                            0.000000e+00   83.602771
# mr_max_length_pct                       0.000000e+00   83.371824
# te_ancient_count_per_kb                 0.000000e+00   83.140878
# CGT_plncpro                             0.000000e+00   82.909931
# kmerScore_2mer_feelnc                   0.000000e+00   82.678984
# dr_gaps_mean_pct                        0.000000e+00   82.448037
# str_std_length_pct                      0.000000e+00   82.217090
# str_gaps_max_pct                        0.000000e+00   81.986143
# ir_max_length_pct                       0.000000e+00   81.755196
# lctr_gaps_max                           0.000000e+00   81.524249
# ACG_plncpro                             0.000000e+00   81.293303
# dr_gaps_median_pct                      0.000000e+00   81.062356
# gq_unique_length                       2.478510e-303   80.831409
# kmerScore_1mer_feelnc                  3.528066e-299   80.600462
# lctr_gaps_mean                          0.000000e+00   80.369515
# TCT_plncpro                            3.238980e-292   80.138568
# ORF_T0_PI_lncDC                        1.473836e-285   79.907621
# ir_std_length_pct                      1.581881e-283   79.676674
# te_unique_families                      0.000000e+00   79.445727
# te_unique_subfamilies                  8.551287e-307   79.214781
# RCB_T1_lncDC                           3.773864e-270   78.983834
# Hexamer_score_ORF_T3_lncDC             1.262389e-269   78.752887
# Hexamer_score_ORF_T1_lncDC             1.540230e-269   78.521940
# te_sum_num_fragments                   3.489350e-298   78.290993
# te_unique_classes                      4.665470e-301   78.060046
# apr_mean_length_pct                    2.065717e-262   77.829099
# te_count                               2.817649e-289   77.598152
# te_max_divergence                      2.573159e-281   77.367206
# apr_max_length_pct                     4.398834e-252   77.136259
# lctr_count                             1.749380e-271   76.905312
# lctr_gaps_median                       5.476159e-264   76.674365
# te_ltr_count_per_kb                     0.000000e+00   76.443418
# lctr_sum_num_fragments                 8.072540e-268   76.212471
# gq_max_length                          3.094455e-238   75.981524
# te_sum_hit_length                      6.095393e-264   75.750577
# lctr_total_length                      5.493782e-250   75.519630
# ORF_T0_aromaticity_lncDC               3.405461e-234   75.288684
# lctr_simple_repeat_count               3.854207e-259   75.057737
# gq_mean_length_pct                     8.266539e-229   74.826790
# te_mean_divergence                     1.535967e-254   74.595843
# te_ltr_count                            0.000000e+00   74.364896
# te_max_hit_length                      4.695685e-246   74.133949
# mr_std_length_pct                      1.008797e-218   73.903002
# total_nonb_count                       2.867041e-217   73.672055
# mr_gaps_max_pct                        5.215014e-214   73.441109
# te_mean_num_fragments                  3.400692e-264   73.210162
# total_nonb_coverage                    1.135749e-213   72.979215
# SS_score_k1_lncDC                      1.331478e-212   72.748268
# te_max_num_fragments                   1.196709e-261   72.517321
# str_hit_count                          1.228764e-203   72.286374
# global_gaps_median                     3.585454e-201   72.055427
# TCA_plncpro                            3.381125e-200   71.824480
# lctr_mean_length                       4.491589e-209   71.593533
# ACA_plncpro                            6.187778e-198   71.362587
# str_total_length                       1.637897e-195   71.131640
# ir_total_length                        2.032317e-193   70.900693
# te_max_perc_del                        1.292029e-223   70.669746
# tri_mean_length_pct                    1.671252e-190   70.438799
# ir_hit_count                           2.333779e-189   70.207852
# lctr_mean_num_fragments                3.012859e-256   69.976905
# te_min_divergence                      4.427961e-205   69.745958
# gq_max_length_pct                      9.270110e-181   69.515012
# CAA_plncpro                            1.164127e-180   69.284065
# te_ancient_count                       3.742471e-244   69.053118
# te_mean_perc_del                       4.298978e-209   68.822171
# ORF_T3_MW_lncDC                        6.636978e-175   68.591224
# te_max_perc_ins                        1.103594e-211   68.360277
# ORF_T1_MW_lncDC                        2.981947e-174   68.129330
# te_mean_hit_length                     4.025601e-194   67.898383
# te_max_sw_score                        1.270785e-186   67.667436
# ACT_plncpro                            2.801953e-167   67.436490
# mr_hit_count                           4.496256e-166   67.205543
# lctr_gaps_min                          1.322741e-179   66.974596
# gq_std_length                          1.598176e-165   66.743649
# dr_max_length_pct                      3.693935e-164   66.512702
# z_mean_length_pct                      2.114175e-163   66.281755
# mr_total_length                        5.479662e-161   66.050808
# str_unique_length                      2.663786e-160   65.819861
# dr_gaps_max_pct                        1.830113e-158   65.588915
# global_rm_total_length                 7.599321e-158   65.357968
# CAT_plncpro                            8.773998e-157   65.127021
# te_mean_perc_ins                       1.419890e-189   64.896074
# dr_hit_count                           5.553229e-156   64.665127
# z_hit_count                            6.429993e-153   64.434180
# dr_total_length                        7.129054e-149   64.203233
# te_mean_sw_score                       2.088968e-163   63.972286
# lctr_simple_repeat_count_per_kb        3.417063e-157   63.741339
# te_min_sw_score                        7.204812e-161   63.510393
# CTA_plncpro                            6.510131e-144   63.279446
# tri_max_length_pct                     1.639233e-143   63.048499
# ir_unique_length                       3.735742e-143   62.817552
# lctr_total_length_pct                  3.400661e-147   62.586605
# dr_unique_length                       3.325141e-135   62.355658
# te_max_hit_reference_coverage          3.058337e-178   62.124711
# ir_max_length                          8.654979e-134   61.893764
# te_min_hit_length                      6.526786e-148   61.662818
# tri_hit_count                          2.625471e-132   61.431871
# apr_gaps_mean                          2.560492e-131   61.200924
# mr_unique_length                       4.626517e-130   60.969977
# te_mean_hit_reference_coverage         3.176232e-171   60.739030
# z_total_length                         2.032438e-129   60.508083
# lctr_count_per_kb                      3.423179e-133   60.277136
# tri_total_length                       3.929508e-125   60.046189
# GGC_plncpro                            7.418803e-124   59.815242
# z_gaps_max                             3.487415e-122   59.584296
# apr_gaps_max                           2.917854e-122   59.353349
# AAC_plncpro                            2.146147e-121   59.122402
# ir_gaps_min_pct                        4.175449e-124   58.891455
# tri_unique_length                      4.670872e-120   58.660508
# TTC_plncpro                            2.219642e-115   58.429561
# te_line_count_per_kb                   2.795050e-215   58.198614
# z_unique_length                        4.305042e-106   57.967667
# gq_gaps_median_pct                     1.417661e-105   57.736721
# GCC_plncpro                            4.915545e-105   57.505774
# gq_gaps_mean_pct                       1.499966e-104   57.274827
# ir_gaps_max                            2.387047e-104   57.043880
# GTG_plncpro                            2.565528e-102   56.812933
# lctr_mean_length_pct                   2.194273e-104   56.581986
# z_gaps_mean                             5.527337e-98   56.351039
# tri_gaps_max                            4.858292e-93   56.120092
# CTT_plncpro                             2.177143e-92   55.889145
# AGA_plncpro                             2.354445e-92   55.658199
# apr_gaps_median                         1.098882e-91   55.427252
# TAA_plncpro                             3.076840e-91   55.196305
# apr_gaps_mean_pct                       2.714828e-91   54.965358
# AAT_plncpro                             9.806259e-89   54.734411
# global_gaps_min                         4.754294e-92   54.503464
# all_nonb_gaps_min                       4.801052e-88   54.272517
# gq_gaps_max                             1.725555e-87   54.041570
# all_nonb_gaps_mean                      9.164266e-87   53.810624
# AAA_plncpro                             1.671132e-86   53.579677
# gq_gaps_min_pct                         1.265861e-85   53.348730
# mr_max_length                           1.421876e-84   53.117783
# mr_gaps_max                             2.525587e-84   52.886836
# te_sine_count_per_kb                   1.011831e-112   52.655889
# tri_gaps_mean_pct                       5.417736e-84   52.424942
# z_max_length_pct                        7.143404e-82   52.193995
# dr_max_length                           3.876540e-81   51.963048
# dr_gaps_max                             2.386202e-80   51.732102
# UP.PCT_lncfinder                        6.361749e-80   51.501155
# GC_content_lncDC                        8.461362e-80   51.270208
# ATC_plncpro                             1.427595e-79   51.039261
# tri_gaps_median_pct                     4.108010e-77   50.808314
# apr_gaps_median_pct                     3.100245e-76   50.577367
# GGG_plncpro                             1.239184e-75   50.346420
# z_max_length                            3.475967e-75   50.115473
# te_gaps_median_pct                      8.882297e-84   49.884527
# gq_mean_length                          2.019261e-73   49.653580
# te_line_count                          7.124812e-142   49.422633
# TGA_plncpro                             2.771490e-69   49.191686
# n_motif_types                          2.814379e-120   48.960739
# tri_max_length                          1.557057e-68   48.729792
# TGG_plncpro                             4.279691e-67   48.498845
# z_gaps_median                           4.036505e-67   48.267898
# ATA_plncpro                             9.141814e-67   48.036952
# AGC_plncpro                             5.693477e-66   47.806005
# mr_gaps_min_pct                         1.410568e-65   47.575058
# dr_std_length_pct                       1.616394e-65   47.344111
# TAG_plncpro                             1.229519e-64   47.113164
# GGT_plncpro                             2.108182e-64   46.882217
# GCT_plncpro                             2.310339e-64   46.651270
# tri_std_length                          4.460542e-64   46.420323
# gq_total_length_pct                     2.013550e-62   46.189376
# GC_content_paired_ss_lncDC              3.331312e-62   45.958430
# AAG_plncpro                             3.080293e-61   45.727483
# z_gaps_mean_pct                         1.455772e-60   45.496536
# gq_hit_count_per_kb                     2.009598e-60   45.265589
# apr_hit_count                           1.067094e-60   45.034642
# apr_total_length                        1.623405e-60   44.803695
# ir_gaps_min                             4.855000e-61   44.572748
# str_max_length                          8.713319e-59   44.341801
# str_gaps_min_pct                        6.777797e-69   44.110855
# apr_gaps_max_pct                        2.714597e-52   43.879908
# motif_diversity                         1.563277e-51   43.648961
# dr_std_length                           2.472602e-51   43.418014
# tri_gaps_mean                           3.202673e-51   43.187067
# te_gaps_mean_pct                        8.513120e-57   42.956120
# global_gaps_mean_pct                    4.871505e-51   42.725173
# ir_std_length                           9.546201e-51   42.494226
# TGC_plncpro                             4.835872e-50   42.263279
# apr_unique_length                       4.147267e-50   42.032333
# CCC_plncpro                             1.099265e-46   41.801386
# z_std_length                            4.515307e-47   41.570439
# te_min_perc_del                         2.760247e-69   41.339492
# GAA_plncpro                             1.402271e-45   41.108545
# dr_gaps_min_pct                         1.464526e-44   40.877598
# str_gaps_max                            2.263688e-44   40.646651
# CAG_plncpro                             1.170181e-40   40.415704
# gq_unique_length_pct                    1.704554e-40   40.184758
# all_nonb_gaps_median                    2.571529e-40   39.953811
# str_gaps_min                            8.239647e-48   39.722864
# apr_max_length                          1.433363e-39   39.491917
# GGA_plncpro                             1.189468e-38   39.260970
# z_gaps_median_pct                       2.727494e-38   39.030023
# apr_std_length                          2.404090e-38   38.799076
# ORF_T3_coverage_lncDC                   1.907816e-36   38.568129
# ORF_T1_coverage_lncDC                   5.137931e-36   38.337182
# gq_gaps_max_pct                         8.133965e-36   38.106236
# tri_gaps_median                         3.779639e-35   37.875289
# gq_gaps_min                             4.553840e-35   37.644342
# GCA_plncpro                             6.453749e-35   37.413395
# te_gaps_max_pct                         2.417251e-38   37.182448
# mr_std_length                           4.365807e-33   36.951501
# ATT_plncpro                             8.181436e-33   36.720554
# ir_mean_length                          1.277596e-32   36.489607
# tri_gaps_max_pct                        2.287128e-32   36.258661
# all_nonb_gaps_max                       5.657498e-29   36.027714
# GAC_plncpro                             1.718710e-26   35.796767
# z_gaps_max_pct                          5.226966e-26   35.565820
# ACC_plncpro                             2.452904e-24   35.334873
# tri_mean_length                         2.368335e-24   35.103926
# GTC_plncpro                             6.480309e-24   34.872979
# lctr_low_complexity_count               2.372213e-50   34.642032
# ATG_plncpro                             4.877266e-23   34.411085
# te_fragmented_ratio                     4.114677e-93   34.180139
# dr_gaps_mean                            2.421376e-22   33.949192
# te_sum_fragmented                       3.594418e-89   33.718245
# te_sine_count                           4.124613e-29   33.487298
# CAC_plncpro                             6.935444e-21   33.256351
# lctr_low_complexity_count_per_kb        2.425759e-43   33.025404
# te_gaps_median                          1.347408e-22   32.794457
# global_gaps_median_pct                  3.273946e-20   32.563510
# global_rm_count                         1.660585e-20   32.332564
# CTC_plncpro                             6.407014e-20   32.101617
# apr_mean_length                         4.488019e-19   31.870670
# gq_std_length_pct                       2.119633e-18   31.639723
# apr_std_length_pct                      1.180166e-18   31.408776
# apr_gaps_min_pct                        1.203641e-17   31.177829
# z_mean_length                           9.313369e-17   30.946882
# TTA_plncpro                             3.962531e-15   30.715935
# Seq.Dist.Ratio_lncfinder                5.012847e-15   30.484988
# TAT_plncpro                             5.129904e-15   30.254042
# mr_gaps_mean                            1.449670e-14   30.023095
# te_gaps_min_pct                         8.897491e-18   29.792148
# ORF_T1_instability_lncDC                7.943894e-14   29.561201
# mr_gaps_min                             2.018812e-13   29.330254
# gq_gaps_mean                            4.047413e-13   29.099307
# str_gaps_median                         7.847945e-12   28.868360
# GAG_plncpro                             5.176297e-11   28.637413
# dr_gaps_median                          5.635271e-11   28.406467
# te_dna_count_per_kb                     1.031056e-23   28.175520
# te_min_perc_ins                         2.988348e-19   27.944573
# tri_gaps_min_pct                        1.067772e-10   27.713626
# dr_mean_length                          2.709863e-10   27.482679
# te_min_hit_reference_coverage           3.301479e-25   27.251732
# z_std_length_pct                        7.269360e-10   27.020785
# TTT_plncpro                             1.618001e-08   26.789838
# apr_gaps_min                            1.664923e-08   26.558891
# ORF_T0_instability_lncDC                2.433511e-08   26.327945
# apr_unique_length_pct                   2.737083e-08   26.096998
# apr_hit_count_per_kb                    1.703232e-07   25.866051
# tri_gaps_min                            2.410955e-07   25.635104
# apr_total_length_pct                    3.700455e-07   25.404157
# z_gaps_min                              5.092145e-07   25.173210
# str_gaps_mean                           1.073988e-06   24.942263
# TTG_plncpro                             2.468528e-06   24.711316
# total_nonb_coverage_pct                 2.764797e-06   24.480370
# mr_mean_length                          4.568129e-06   24.249423
# CTG_plncpro                             5.237903e-06   24.018476
# dr_gaps_min                             6.825087e-06   23.787529
# str_std_length                          1.740577e-05   23.556582
# te_dna_count                            6.178985e-11   23.325635
# tri_std_length_pct                      8.072235e-05   23.094688
# mr_gaps_median                          2.007626e-04   22.863741
# str_hit_count_per_kb                    4.032624e-04   22.632794
# te_gaps_min                             9.115647e-05   22.401848
# str_total_length_pct                    1.020824e-03   22.170901
# ir_total_length_pct                     1.304817e-03   21.939954
# te_gaps_mean                            2.224189e-03   21.709007
# TGT_plncpro                             1.260352e-02   21.478060
# ir_hit_count_per_kb                     1.261038e-02   21.247113
# ir_gaps_mean                            2.041629e-02   21.016166
# z_hit_count_per_kb                      2.459724e-02   20.785219
# str_mean_length                         2.682611e-02   20.554273
# mr_total_length_pct                     3.557042e-02   20.323326
# GTT_plncpro                             6.570123e-02   20.092379
# mr_hit_count_per_kb                     6.675891e-02   19.861432
# TCC_plncpro                             7.683792e-02   19.630485
# tri_total_length_pct                    7.741303e-02   19.399538
# str_unique_length_pct                   7.795321e-02   19.168591
# tri_hit_count_per_kb                    9.350809e-02   18.937644
# dr_total_length_pct                     9.391453e-02   18.706697
# te_gaps_max                             9.619460e-02   18.475751
# z_total_length_pct                      1.164377e-01   18.244804
# dr_hit_count_per_kb                     1.248608e-01   18.013857
# CCT_plncpro                             1.345382e-01   17.782910
# tri_unique_length_pct                   1.358524e-01   17.551963
# lctr_satellite_count_per_kb             1.212845e-23   17.321016
# lctr_satellite_count                    1.411543e-23   17.090069
# CCA_plncpro                             2.251676e-01   16.859122
# ir_gaps_median                          2.548547e-01   16.628176
# AGG_plncpro                             2.548547e-01   16.397229
# AGT_plncpro                             2.679376e-01   16.166282
# te_young_count_per_kb                   3.914495e-03   15.935335
# GAT_plncpro                             3.000182e-01   15.704388
# te_young_count                          1.812680e-02   15.473441
# dr_unique_length_pct                    3.901648e-01   15.242494
# gq_gaps_median                          4.451722e-01   15.011547
# z_unique_length_pct                     5.939029e-01   14.780600
# z_gaps_min_pct                          7.684222e-01   14.549654
# ir_unique_length_pct                    7.763642e-01   14.318707
# pseudo_count_per_kb                     2.502668e-02   14.087760
# pseudo_count                            2.548042e-02   13.625866
# pseudo_sum_num_fragments                2.548042e-02   13.625866
# pseudo_unique_subfamilies               2.548042e-02   13.625866
# pseudo_sum_hit_length                   2.548042e-02   13.163972
# pseudo_unique_classes                   2.548042e-02   12.702079
# pseudo_mean_num_fragments               2.548042e-02   12.702079
# pseudo_max_num_fragments                2.548042e-02   12.702079
# pseudo_max_hit_length                   2.548042e-02   12.240185
# pseudo_mean_hit_length                  2.548042e-02   12.009238
# pseudo_min_hit_length                   2.548042e-02   11.778291
# pseudo_max_sw_score                     2.549230e-02   11.547344
# pseudo_mean_sw_score                    2.549230e-02   11.316397
# pseudo_min_sw_score                     2.549230e-02   11.085450
# pseudogene_gaps_median                  2.618696e-02   10.739030
# pseudogene_gaps_mean                    2.618696e-02   10.739030
# pseudogene_gaps_max                     2.618696e-02   10.392610
# pseudo_max_divergence                   4.338454e-02   10.161663
# pseudo_mean_divergence                  4.338454e-02    9.930716
# pseudo_min_divergence                   4.338454e-02    9.699769
# pseudogene_gaps_min                     4.455228e-02    9.468822
# GTA_plncpro                             8.428358e-01    9.237875
# te_srprna_count_per_kb                  4.028128e-03    9.006928
# te_srprna_count                         4.072066e-03    8.775982
# te_retroposon_count_per_kb              2.306671e-01    8.545035
# te_retroposon_count                     2.413137e-01    8.314088
# mr_unique_length_pct                    8.616883e-01    8.083141
# pseudo_snrna_count_per_kb               7.795321e-02    7.852194
# pseudo_snrna_count                      7.867890e-02    7.621247
# TAC_plncpro                             8.912763e-01    7.390300
# unknown_count_per_kb                    5.152775e-01    7.159353
# unknown_mean_length_pct                 5.152775e-01    6.928406
# unknown_total_length_pct                5.152775e-01    6.697460
# unknown_mean_length                     5.282833e-01    6.466513
# unknown_total_length                    5.282833e-01    6.235566
# unknown_mean_num_fragments              5.431308e-01    5.889145
# unknown_count                           5.431308e-01    5.889145
# unknown_sum_num_fragments               5.436107e-01    5.542725
# unknown_gaps_median                     5.698523e-01    5.311778
# unknown_gaps_max                        5.698523e-01    5.080831
# unknown_gaps_mean                       5.698523e-01    4.849885
# pseudo_trna_count_per_kb                1.386969e-01    4.618938
# pseudo_trna_count                       1.388645e-01    4.387991
# pseudo_ancient_count_per_kb             5.138951e-02    4.157044
# pseudo_ancient_count                    5.138951e-02    3.926097
# pseudo_max_hit_reference_coverage       5.152775e-01    3.695150
# pseudo_mean_hit_reference_coverage      5.152775e-01    3.464203
# pseudo_mean_perc_ins                    3.869502e-01    3.002309
# pseudo_max_perc_ins                     3.869502e-01    3.002309
# pseudo_min_perc_ins                     3.869502e-01    3.002309
# unknown_gaps_min                        8.154764e-01    2.540416
# pseudo_min_perc_del                     6.414064e-01    2.078522
# pseudo_mean_perc_del                    6.414064e-01    2.078522
# pseudo_max_perc_del                     6.414064e-01    2.078522
# te_rc_count_per_kb                      4.191538e-01    1.616628
# te_rc_count                             4.191538e-01    1.385681
# pseudo_min_hit_reference_coverage       7.946476e-01    1.154734
# pseudo_scrna_count_per_kb               7.898087e-01    0.808314
# pseudo_rrna_count_per_kb                7.898087e-01    0.808314
# pseudo_rrna_count                       7.898087e-01    0.346420
# pseudo_scrna_count                      7.898087e-01    0.346420
#
#                                               test       vda  \
# ORF_T0_MW_lncDC                     Mann-Whitney U  0.998757
# ORF_T0_length_lncDC                 Mann-Whitney U  0.998752
# ORF.Max.Len_lncfinder               Mann-Whitney U  0.998752
# ORF_l_cpat                          Mann-Whitney U  0.998752
# Seq.pct.Dist_lncfinder              Mann-Whitney U  0.998746
# Seq.lnc.Dist_lncfinder              Mann-Whitney U  0.998726
# Fickett_l_cpat                      Mann-Whitney U  0.995709
# Hexamer_l_cpat                      Mann-Whitney U  0.995121
# Signal.Peak_lncfinder               Mann-Whitney U  0.994617
# RCB_T0_lncDC                        Mann-Whitney U  0.005708
# Hexamer_score_ORF_T0_lncDC          Mann-Whitney U  0.993768
# kmerScore_9mer_feelnc               Mann-Whitney U  0.993483
# kmerScore_6mer_feelnc               Mann-Whitney U  0.985124
# SNR_lncfinder                       Mann-Whitney U  0.985107
# kmerScore_12mer_feelnc              Mann-Whitney U  0.984166
# SS.Dist.Ratio_lncfinder             Mann-Whitney U  0.021514
# ORF_T0_coverage_lncDC               Mann-Whitney U  0.978271
# ORF.Max.Cov_lncfinder               Mann-Whitney U  0.977583
# ORF_coverage_l_cpat                 Mann-Whitney U  0.977583
# MFE_lncfinder                       Mann-Whitney U  0.023608
# ORF_cover_feelnc                    Mann-Whitney U  0.976027
# kmerScore_3mer_feelnc               Mann-Whitney U  0.975873
# orf_coverage_plncpro                Mann-Whitney U  0.975399
# Signal.Q1_lncfinder                 Mann-Whitney U  0.972933
# Signal.Min_lncfinder                Mann-Whitney U  0.972898
# Signal.Q2_lncfinder                 Mann-Whitney U  0.972863
# Signal.Max_lncfinder                Mann-Whitney U  0.972589
# Dot_Dist.Ratio_lncfinder            Mann-Whitney U  0.031896
# ORF_T2_length_lncDC                 Mann-Whitney U  0.968074
# ORF_T2_MW_lncDC                     Mann-Whitney U  0.966597
# SS.lnc.dist_lncfinder               Mann-Whitney U  0.965904
# Dot_lnc.dist_lncfinder              Mann-Whitney U  0.958451
# SS.pct.dist_lncfinder               Mann-Whitney U  0.956148
# RNA_size_feelnc                     Mann-Whitney U  0.956021
# transcript_length                   Mann-Whitney U  0.956021
# ORF_T1_length_lncDC                 Mann-Whitney U  0.953306
# SS_score_k5_lncDC                   Mann-Whitney U  0.942354
# Hexamer_score_ORF_T2_lncDC          Mann-Whitney U  0.940513
# Dot_pct.dist_lncfinder              Mann-Whitney U  0.937998
# ir_gaps_mean_pct                    Mann-Whitney U  0.067343
# ir_mean_length_pct                  Mann-Whitney U  0.075813
# ir_gaps_median_pct                  Mann-Whitney U  0.080077
# str_mean_length_pct                 Mann-Whitney U  0.084949
# te_count_per_kb                     Mann-Whitney U  0.100807
# SS_score_k4_lncDC                   Mann-Whitney U  0.899014
# str_gaps_mean_pct                   Mann-Whitney U  0.103614
# te_mean_hit_length_pct              Mann-Whitney U  0.107836
# te_max_hit_length_pct               Mann-Whitney U  0.109121
# te_sum_hit_length_pct               Mann-Whitney U  0.124538
# str_gaps_median_pct                 Mann-Whitney U  0.128779
# global_rm_total_length_pct          Mann-Whitney U  0.129253
# GCG_plncpro                         Mann-Whitney U  0.868756
# global_rm_count_per_kb              Mann-Whitney U  0.132577
# CGA_plncpro                         Mann-Whitney U  0.866688
# CGG_plncpro                         Mann-Whitney U  0.861745
# TCG_plncpro                         Mann-Whitney U  0.858140
# mr_mean_length_pct                  Mann-Whitney U  0.145321
# SS_score_k3_lncDC                   Mann-Whitney U  0.852617
# CCG_plncpro                         Mann-Whitney U  0.852295
# te_min_hit_length_pct               Mann-Whitney U  0.149504
# ir_gaps_max_pct                     Mann-Whitney U  0.156294
# CGC_plncpro                         Mann-Whitney U  0.841760
# dr_mean_length_pct                  Mann-Whitney U  0.163738
# global_gaps_max                     Mann-Whitney U  0.835603
# mr_gaps_mean_pct                    Mann-Whitney U  0.164668
# Fickett_score_lncDC                 Mann-Whitney U  0.831488
# mr_gaps_median_pct                  Mann-Whitney U  0.173742
# global_gaps_mean                    Mann-Whitney U  0.819360
# str_max_length_pct                  Mann-Whitney U  0.181701
# SS_score_k2_lncDC                   Mann-Whitney U  0.813923
# gq_total_length                     Mann-Whitney U  0.809942
# gq_hit_count                        Mann-Whitney U  0.809794
# mr_max_length_pct                   Mann-Whitney U  0.192133
# te_ancient_count_per_kb             Mann-Whitney U  0.202811
# CGT_plncpro                         Mann-Whitney U  0.795870
# kmerScore_2mer_feelnc               Mann-Whitney U  0.795686
# dr_gaps_mean_pct                    Mann-Whitney U  0.204501
# str_std_length_pct                  Mann-Whitney U  0.205338
# str_gaps_max_pct                    Mann-Whitney U  0.206986
# ir_max_length_pct                   Mann-Whitney U  0.207833
# lctr_gaps_max                       Mann-Whitney U  0.791491
# ACG_plncpro                         Mann-Whitney U  0.789625
# dr_gaps_median_pct                  Mann-Whitney U  0.214225
# gq_unique_length                    Mann-Whitney U  0.782057
# kmerScore_1mer_feelnc               Mann-Whitney U  0.780118
# lctr_gaps_mean                      Mann-Whitney U  0.779714
# TCT_plncpro                         Mann-Whitney U  0.223184
# ORF_T0_PI_lncDC                     Mann-Whitney U  0.226376
# ir_std_length_pct                   Mann-Whitney U  0.227358
# te_unique_families                  Mann-Whitney U  0.230820
# te_unique_subfamilies               Mann-Whitney U  0.233245
# RCB_T1_lncDC                        Mann-Whitney U  0.233909
# Hexamer_score_ORF_T3_lncDC          Mann-Whitney U  0.765829
# Hexamer_score_ORF_T1_lncDC          Mann-Whitney U  0.765784
# te_sum_num_fragments                Mann-Whitney U  0.236642
# te_unique_classes                   Mann-Whitney U  0.237771
# apr_mean_length_pct                 Mann-Whitney U  0.238329
# te_count                            Mann-Whitney U  0.240776
# te_max_divergence                   Mann-Whitney U  0.242873
# apr_max_length_pct                  Mann-Whitney U  0.243573
# lctr_count                          Mann-Whitney U  0.756130
# lctr_gaps_median                    Mann-Whitney U  0.755907
# te_ltr_count_per_kb                 Mann-Whitney U  0.244582
# lctr_sum_num_fragments              Mann-Whitney U  0.754419
# gq_max_length                       Mann-Whitney U  0.749554
# te_sum_hit_length                   Mann-Whitney U  0.250999
# lctr_total_length                   Mann-Whitney U  0.748973
# ORF_T0_aromaticity_lncDC            Mann-Whitney U  0.252392
# lctr_simple_repeat_count            Mann-Whitney U  0.746635
# gq_mean_length_pct                  Mann-Whitney U  0.255287
# te_mean_divergence                  Mann-Whitney U  0.255511
# te_ltr_count                        Mann-Whitney U  0.257932
# te_max_hit_length                   Mann-Whitney U  0.259652
# mr_std_length_pct                   Mann-Whitney U  0.260788
# total_nonb_count                    Mann-Whitney U  0.738424
# mr_gaps_max_pct                     Mann-Whitney U  0.263390
# te_mean_num_fragments               Mann-Whitney U  0.263509
# total_nonb_coverage                 Mann-Whitney U  0.736422
# SS_score_k1_lncDC                   Mann-Whitney U  0.735823
# te_max_num_fragments                Mann-Whitney U  0.264711
# str_hit_count                       Mann-Whitney U  0.730746
# global_gaps_median                  Mann-Whitney U  0.728957
# TCA_plncpro                         Mann-Whitney U  0.271225
# lctr_mean_length                    Mann-Whitney U  0.727522
# ACA_plncpro                         Mann-Whitney U  0.272534
# str_total_length                    Mann-Whitney U  0.726057
# ir_total_length                     Mann-Whitney U  0.724830
# te_max_perc_del                     Mann-Whitney U  0.276402
# tri_mean_length_pct                 Mann-Whitney U  0.277083
# ir_hit_count                        Mann-Whitney U  0.722432
# lctr_mean_num_fragments             Mann-Whitney U  0.719261
# te_min_divergence                   Mann-Whitney U  0.280769
# gq_max_length_pct                   Mann-Whitney U  0.282733
# CAA_plncpro                         Mann-Whitney U  0.282785
# te_ancient_count                    Mann-Whitney U  0.283822
# te_mean_perc_del                    Mann-Whitney U  0.283850
# ORF_T3_MW_lncDC                     Mann-Whitney U  0.713687
# te_max_perc_ins                     Mann-Whitney U  0.286617
# ORF_T1_MW_lncDC                     Mann-Whitney U  0.713283
# te_mean_hit_length                  Mann-Whitney U  0.286734
# te_max_sw_score                     Mann-Whitney U  0.290937
# ACT_plncpro                         Mann-Whitney U  0.291068
# mr_hit_count                        Mann-Whitney U  0.708156
# lctr_gaps_min                       Mann-Whitney U  0.708047
# gq_std_length                       Mann-Whitney U  0.707748
# dr_max_length_pct                   Mann-Whitney U  0.293054
# z_mean_length_pct                   Mann-Whitney U  0.293624
# mr_total_length                     Mann-Whitney U  0.704915
# str_unique_length                   Mann-Whitney U  0.704471
# dr_gaps_max_pct                     Mann-Whitney U  0.296722
# global_rm_total_length              Mann-Whitney U  0.297417
# CAT_plncpro                         Mann-Whitney U  0.297815
# te_mean_perc_ins                    Mann-Whitney U  0.298174
# dr_hit_count                        Mann-Whitney U  0.701637
# z_hit_count                         Mann-Whitney U  0.699415
# dr_total_length                     Mann-Whitney U  0.696955
# te_mean_sw_score                    Mann-Whitney U  0.304510
# lctr_simple_repeat_count_per_kb     Mann-Whitney U  0.694104
# te_min_sw_score                     Mann-Whitney U  0.306054
# CTA_plncpro                         Mann-Whitney U  0.306391
# tri_max_length_pct                  Mann-Whitney U  0.306837
# ir_unique_length                    Mann-Whitney U  0.693088
# lctr_total_length_pct               Mann-Whitney U  0.690544
# dr_unique_length                    Mann-Whitney U  0.687579
# te_max_hit_reference_coverage       Mann-Whitney U  0.312455
# ir_max_length                       Mann-Whitney U  0.686473
# te_min_hit_length                   Mann-Whitney U  0.314127
# tri_hit_count                       Mann-Whitney U  0.685246
# apr_gaps_mean                       Mann-Whitney U  0.684444
# mr_unique_length                    Mann-Whitney U  0.683928
# te_mean_hit_reference_coverage      Mann-Whitney U  0.316219
# z_total_length                      Mann-Whitney U  0.683387
# lctr_count_per_kb                   Mann-Whitney U  0.681137
# tri_total_length                    Mann-Whitney U  0.680203
# GGC_plncpro                         Mann-Whitney U  0.679425
# z_gaps_max                          Mann-Whitney U  0.678115
# apr_gaps_max                        Mann-Whitney U  0.677879
# AAC_plncpro                         Mann-Whitney U  0.322395
# ir_gaps_min_pct                     Mann-Whitney U  0.322676
# tri_unique_length                   Mann-Whitney U  0.676451
# TTC_plncpro                         Mann-Whitney U  0.326916
# te_line_count_per_kb                Mann-Whitney U  0.330965
# z_unique_length                     Mann-Whitney U  0.665793
# gq_gaps_median_pct                  Mann-Whitney U  0.334553
# GCC_plncpro                         Mann-Whitney U  0.665023
# gq_gaps_mean_pct                    Mann-Whitney U  0.335373
# ir_gaps_max                         Mann-Whitney U  0.664469
# GTG_plncpro                         Mann-Whitney U  0.662834
# lctr_mean_length_pct                Mann-Whitney U  0.660060
# z_gaps_mean                         Mann-Whitney U  0.659224
# tri_gaps_max                        Mann-Whitney U  0.655013
# CTT_plncpro                         Mann-Whitney U  0.345405
# AGA_plncpro                         Mann-Whitney U  0.345436
# apr_gaps_median                     Mann-Whitney U  0.653670
# TAA_plncpro                         Mann-Whitney U  0.346396
# apr_gaps_mean_pct                   Mann-Whitney U  0.346668
# AAT_plncpro                         Mann-Whitney U  0.348559
# global_gaps_min                     Mann-Whitney U  0.651292
# all_nonb_gaps_min                   Mann-Whitney U  0.349163
# gq_gaps_max                         Mann-Whitney U  0.650345
# all_nonb_gaps_mean                  Mann-Whitney U  0.350286
# AAA_plncpro                         Mann-Whitney U  0.350518
# gq_gaps_min_pct                     Mann-Whitney U  0.351410
# mr_max_length                       Mann-Whitney U  0.647683
# mr_gaps_max                         Mann-Whitney U  0.647546
# te_sine_count_per_kb                Mann-Whitney U  0.352807
# tri_gaps_mean_pct                   Mann-Whitney U  0.352881
# z_max_length_pct                    Mann-Whitney U  0.354724
# dr_max_length                       Mann-Whitney U  0.644658
# dr_gaps_max                         Mann-Whitney U  0.643945
# UP.PCT_lncfinder                    Mann-Whitney U  0.643557
# GC_content_lncDC                    Mann-Whitney U  0.643441
# ATC_plncpro                         Mann-Whitney U  0.356769
# tri_gaps_median_pct                 Mann-Whitney U  0.359173
# apr_gaps_median_pct                 Mann-Whitney U  0.360163
# GGG_plncpro                         Mann-Whitney U  0.639561
# z_max_length                        Mann-Whitney U  0.639038
# te_gaps_median_pct                  Mann-Whitney U  0.361084
# gq_mean_length                      Mann-Whitney U  0.637450
# te_line_count                       Mann-Whitney U  0.363523
# TGA_plncpro                         Mann-Whitney U  0.366563
# n_motif_types                       Mann-Whitney U  0.632863
# tri_max_length                      Mann-Whitney U  0.632516
# TGG_plncpro                         Mann-Whitney U  0.631256
# z_gaps_median                       Mann-Whitney U  0.631228
# ATA_plncpro                         Mann-Whitney U  0.369076
# AGC_plncpro                         Mann-Whitney U  0.630122
# mr_gaps_min_pct                     Mann-Whitney U  0.370352
# dr_std_length_pct                   Mann-Whitney U  0.370372
# TAG_plncpro                         Mann-Whitney U  0.371241
# GGT_plncpro                         Mann-Whitney U  0.628518
# GCT_plncpro                         Mann-Whitney U  0.628476
# tri_std_length                      Mann-Whitney U  0.627529
# gq_total_length_pct                 Mann-Whitney U  0.626466
# GC_content_paired_ss_lncDC          Mann-Whitney U  0.626243
# AAG_plncpro                         Mann-Whitney U  0.374769
# z_gaps_mean_pct                     Mann-Whitney U  0.375537
# gq_hit_count_per_kb                 Mann-Whitney U  0.624359
# apr_hit_count                       Mann-Whitney U  0.624322
# apr_total_length                    Mann-Whitney U  0.624203
# ir_gaps_min                         Mann-Whitney U  0.376718
# str_max_length                      Mann-Whitney U  0.622597
# str_gaps_min_pct                    Mann-Whitney U  0.379387
# apr_gaps_max_pct                    Mann-Whitney U  0.384789
# motif_diversity                     Mann-Whitney U  0.614581
# dr_std_length                       Mann-Whitney U  0.614323
# tri_gaps_mean                       Mann-Whitney U  0.614119
# te_gaps_mean_pct                    Mann-Whitney U  0.385942
# global_gaps_mean_pct                Mann-Whitney U  0.613841
# ir_std_length                       Mann-Whitney U  0.613669
# TGC_plncpro                         Mann-Whitney U  0.612845
# apr_unique_length                   Mann-Whitney U  0.612686
# CCC_plncpro                         Mann-Whitney U  0.608862
# z_std_length                        Mann-Whitney U  0.608854
# te_min_perc_del                     Mann-Whitney U  0.391355
# GAA_plncpro                         Mann-Whitney U  0.392481
# dr_gaps_min_pct                     Mann-Whitney U  0.393961
# str_gaps_max                        Mann-Whitney U  0.606030
# CAG_plncpro                         Mann-Whitney U  0.601327
# gq_unique_length_pct                Mann-Whitney U  0.601109
# all_nonb_gaps_median                Mann-Whitney U  0.399123
# str_gaps_min                        Mann-Whitney U  0.400104
# apr_max_length                      Mann-Whitney U  0.599523
# GGA_plncpro                         Mann-Whitney U  0.598687
# z_gaps_median_pct                   Mann-Whitney U  0.401841
# apr_std_length                      Mann-Whitney U  0.597206
# ORF_T3_coverage_lncDC               Mann-Whitney U  0.595703
# ORF_T1_coverage_lncDC               Mann-Whitney U  0.595108
# gq_gaps_max_pct                     Mann-Whitney U  0.405173
# tri_gaps_median                     Mann-Whitney U  0.593820
# gq_gaps_min                         Mann-Whitney U  0.406289
# GCA_plncpro                         Mann-Whitney U  0.593574
# te_gaps_max_pct                     Mann-Whitney U  0.406956
# mr_std_length                       Mann-Whitney U  0.590967
# ATT_plncpro                         Mann-Whitney U  0.409423
# ir_mean_length                      Mann-Whitney U  0.590295
# tri_gaps_max_pct                    Mann-Whitney U  0.410154
# all_nonb_gaps_max                   Mann-Whitney U  0.584836
# GAC_plncpro                         Mann-Whitney U  0.580916
# z_gaps_max_pct                      Mann-Whitney U  0.419905
# ACC_plncpro                         Mann-Whitney U  0.577347
# tri_mean_length                     Mann-Whitney U  0.577305
# GTC_plncpro                         Mann-Whitney U  0.576629
# lctr_low_complexity_count           Mann-Whitney U  0.575946
# ATG_plncpro                         Mann-Whitney U  0.424890
# te_fragmented_ratio                 Mann-Whitney U  0.425079
# dr_gaps_mean                        Mann-Whitney U  0.573881
# ...
# mr_std_length_pct                          True
# total_nonb_count                           True
# mr_gaps_max_pct                            True
# te_mean_num_fragments                      True
# total_nonb_coverage                        True
# SS_score_k1_lncDC                          True
# te_max_num_fragments                       True
# str_hit_count                              True
# global_gaps_median                         True
# TCA_plncpro                                True
# lctr_mean_length                           True
# ACA_plncpro                                True
# str_total_length                           True
# ir_total_length                            True
# te_max_perc_del                            True
# tri_mean_length_pct                        True
# ir_hit_count                               True
# lctr_mean_num_fragments                    True
# te_min_divergence                          True
# gq_max_length_pct                          True
# CAA_plncpro                                True
# te_ancient_count                           True
# te_mean_perc_del                           True
# ORF_T3_MW_lncDC                            True
# te_max_perc_ins                            True
# ORF_T1_MW_lncDC                            True
# te_mean_hit_length                         True
# te_max_sw_score                            True
# ACT_plncpro                                True
# mr_hit_count                               True
# lctr_gaps_min                              True
# gq_std_length                              True
# dr_max_length_pct                          True
# z_mean_length_pct                          True
# mr_total_length                            True
# str_unique_length                          True
# dr_gaps_max_pct                            True
# global_rm_total_length                     True
# CAT_plncpro                                True
# te_mean_perc_ins                           True
# dr_hit_count                               True
# z_hit_count                                True
# dr_total_length                            True
# te_mean_sw_score                           True
# lctr_simple_repeat_count_per_kb            True
# te_min_sw_score                            True
# CTA_plncpro                                True
# tri_max_length_pct                         True
# ir_unique_length                           True
# lctr_total_length_pct                      True
# dr_unique_length                           True
# te_max_hit_reference_coverage              True
# ir_max_length                              True
# te_min_hit_length                          True
# tri_hit_count                              True
# apr_gaps_mean                              True
# mr_unique_length                           True
# te_mean_hit_reference_coverage             True
# z_total_length                             True
# lctr_count_per_kb                          True
# tri_total_length                           True
# GGC_plncpro                                True
# z_gaps_max                                 True
# apr_gaps_max                               True
# AAC_plncpro                                True
# ir_gaps_min_pct                            True
# tri_unique_length                          True
# TTC_plncpro                                True
# te_line_count_per_kb                       True
# z_unique_length                            True
# gq_gaps_median_pct                         True
# GCC_plncpro                                True
# gq_gaps_mean_pct                           True
# ir_gaps_max                                True
# GTG_plncpro                                True
# lctr_mean_length_pct                       True
# z_gaps_mean                                True
# tri_gaps_max                               True
# CTT_plncpro                                True
# AGA_plncpro                                True
# apr_gaps_median                            True
# TAA_plncpro                                True
# apr_gaps_mean_pct                          True
# AAT_plncpro                                True
# global_gaps_min                            True
# all_nonb_gaps_min                          True
# gq_gaps_max                                True
# all_nonb_gaps_mean                         True
# AAA_plncpro                                True
# gq_gaps_min_pct                            True
# mr_max_length                              True
# mr_gaps_max                                True
# te_sine_count_per_kb                       True
# tri_gaps_mean_pct                          True
# z_max_length_pct                           True
# dr_max_length                              True
# dr_gaps_max                                True
# UP.PCT_lncfinder                           True
# GC_content_lncDC                           True
# ATC_plncpro                                True
# tri_gaps_median_pct                        True
# apr_gaps_median_pct                        True
# GGG_plncpro                                True
# z_max_length                               True
# te_gaps_median_pct                         True
# gq_mean_length                             True
# te_line_count                              True
# TGA_plncpro                                True
# n_motif_types                              True
# tri_max_length                             True
# TGG_plncpro                                True
# z_gaps_median                              True
# ATA_plncpro                                True
# AGC_plncpro                                True
# mr_gaps_min_pct                            True
# dr_std_length_pct                          True
# TAG_plncpro                                True
# GGT_plncpro                                True
# GCT_plncpro                                True
# tri_std_length                             True
# gq_total_length_pct                        True
# GC_content_paired_ss_lncDC                 True
# AAG_plncpro                                True
# z_gaps_mean_pct                            True
# gq_hit_count_per_kb                        True
# apr_hit_count                              True
# apr_total_length                           True
# ir_gaps_min                                True
# str_max_length                             True
# str_gaps_min_pct                           True
# apr_gaps_max_pct                           True
# motif_diversity                            True
# dr_std_length                              True
# tri_gaps_mean                              True
# te_gaps_mean_pct                           True
# global_gaps_mean_pct                       True
# ir_std_length                              True
# TGC_plncpro                                True
# apr_unique_length                          True
# CCC_plncpro                                True
# z_std_length                               True
# te_min_perc_del                            True
# GAA_plncpro                                True
# dr_gaps_min_pct                            True
# str_gaps_max                               True
# CAG_plncpro                                True
# gq_unique_length_pct                       True
# all_nonb_gaps_median                       True
# str_gaps_min                               True
# apr_max_length                             True
# GGA_plncpro                                True
# z_gaps_median_pct                          True
# apr_std_length                             True
# ORF_T3_coverage_lncDC                      True
# ORF_T1_coverage_lncDC                      True
# gq_gaps_max_pct                            True
# tri_gaps_median                            True
# gq_gaps_min                                True
# GCA_plncpro                                True
# te_gaps_max_pct                            True
# mr_std_length                              True
# ATT_plncpro                                True
# ir_mean_length                             True
# tri_gaps_max_pct                           True
# all_nonb_gaps_max                          True
# GAC_plncpro                                True
# z_gaps_max_pct                             True
# ACC_plncpro                                True
# tri_mean_length                            True
# GTC_plncpro                                True
# lctr_low_complexity_count                  True
# ATG_plncpro                                True
# te_fragmented_ratio                        True
# dr_gaps_mean                               True
# te_sum_fragmented                          True
# te_sine_count                              True
# CAC_plncpro                                True
# lctr_low_complexity_count_per_kb           True
# te_gaps_median                             True
# global_gaps_median_pct                     True
# global_rm_count                            True
# CTC_plncpro                                True
# apr_mean_length                            True
# gq_std_length_pct                          True
# apr_std_length_pct                         True
# apr_gaps_min_pct                           True
# z_mean_length                              True
# TTA_plncpro                                True
# Seq.Dist.Ratio_lncfinder                   True
# TAT_plncpro                                True
# mr_gaps_mean                               True
# te_gaps_min_pct                            True
# ORF_T1_instability_lncDC                   True
# mr_gaps_min                                True
# gq_gaps_mean                               True
# str_gaps_median                            True
# GAG_plncpro                                True
# dr_gaps_median                             True
# te_dna_count_per_kb                        True
# te_min_perc_ins                            True
# tri_gaps_min_pct                           True
# dr_mean_length                             True
# te_min_hit_reference_coverage              True
# z_std_length_pct                           True
# TTT_plncpro                                True
# apr_gaps_min                               True
# ORF_T0_instability_lncDC                   True
# apr_unique_length_pct                      True
# apr_hit_count_per_kb                       True
# tri_gaps_min                               True
# apr_total_length_pct                       True
# z_gaps_min                                 True
# str_gaps_mean                              True
# TTG_plncpro                                True
# total_nonb_coverage_pct                    True
# mr_mean_length                             True
# CTG_plncpro                                True
# dr_gaps_min                                True
# str_std_length                             True
# te_dna_count                               True
# tri_std_length_pct                         True
# mr_gaps_median                             True
# str_hit_count_per_kb                       True
# te_gaps_min                                True
# str_total_length_pct                       True
# ir_total_length_pct                        True
# te_gaps_mean                               True
# TGT_plncpro                               False
# ir_hit_count_per_kb                       False
# ir_gaps_mean                              False
# z_hit_count_per_kb                        False
# str_mean_length                           False
# mr_total_length_pct                       False
# GTT_plncpro                               False
# mr_hit_count_per_kb                       False
# TCC_plncpro                               False
# tri_total_length_pct                      False
# str_unique_length_pct                     False
# tri_hit_count_per_kb                      False
# dr_total_length_pct                       False
# te_gaps_max                               False
# z_total_length_pct                        False
# dr_hit_count_per_kb                       False
# CCT_plncpro                               False
# tri_unique_length_pct                     False
# lctr_satellite_count_per_kb                True
# lctr_satellite_count                       True
# CCA_plncpro                               False
# ir_gaps_median                            False
# AGG_plncpro                               False
# AGT_plncpro                               False
# te_young_count_per_kb                      True
# GAT_plncpro                               False
# te_young_count                            False
# dr_unique_length_pct                      False
# gq_gaps_median                            False
# z_unique_length_pct                       False
# z_gaps_min_pct                            False
# ir_unique_length_pct                      False
# pseudo_count_per_kb                       False
# pseudo_count                              False
# pseudo_sum_num_fragments                  False
# pseudo_unique_subfamilies                 False
# pseudo_sum_hit_length                     False
# pseudo_unique_classes                     False
# pseudo_mean_num_fragments                 False
# pseudo_max_num_fragments                  False
# pseudo_max_hit_length                     False
# pseudo_mean_hit_length                    False
# pseudo_min_hit_length                     False
# pseudo_max_sw_score                       False
# pseudo_mean_sw_score                      False
# pseudo_min_sw_score                       False
# pseudogene_gaps_median                    False
# pseudogene_gaps_mean                      False
# pseudogene_gaps_max                       False
# pseudo_max_divergence                     False
# pseudo_mean_divergence                    False
# pseudo_min_divergence                     False
# pseudogene_gaps_min                       False
# GTA_plncpro                               False
# te_srprna_count_per_kb                     True
# te_srprna_count                            True
# te_retroposon_count_per_kb                False
# te_retroposon_count                       False
# mr_unique_length_pct                      False
# pseudo_snrna_count_per_kb                 False
# pseudo_snrna_count                        False
# TAC_plncpro                               False
# unknown_count_per_kb                      False
# unknown_mean_length_pct                   False
# unknown_total_length_pct                  False
# unknown_mean_length                       False
# unknown_total_length                      False
# unknown_mean_num_fragments                False
# unknown_count                             False
# unknown_sum_num_fragments                 False
# unknown_gaps_median                       False
# unknown_gaps_max                          False
# unknown_gaps_mean                         False
# pseudo_trna_count_per_kb                  False
# pseudo_trna_count                         False
# pseudo_ancient_count_per_kb               False
# pseudo_ancient_count                      False
# pseudo_max_hit_reference_coverage         False
# pseudo_mean_hit_reference_coverage        False
# pseudo_mean_perc_ins                      False
# pseudo_max_perc_ins                       False
# pseudo_min_perc_ins                       False
# unknown_gaps_min                          False
# pseudo_min_perc_del                       False
# pseudo_mean_perc_del                      False
# pseudo_max_perc_del                       False
# te_rc_count_per_kb                        False
# te_rc_count                               False
# pseudo_min_hit_reference_coverage         False
# pseudo_scrna_count_per_kb                 False
# pseudo_rrna_count_per_kb                  False
# pseudo_rrna_count                         False
# pseudo_scrna_count                        False

# %%
chi_tidy_columns = ["adjusted_p_value", "rank_perc", "test", "cramers_v", "odds_ratio", "interpretation", "significant"]
combined_df.loc[combined_df["test"] == "Chi-squared", chi_tidy_columns]
# Out:
#                          adjusted_p_value   rank_perc         test  cramers_v  \
# te_has_ltr                   0.000000e+00  100.000000  Chi-squared   0.489312
# gq_present                  1.829123e-298   95.454545  Chi-squared   0.349846
# lctr_has_simple_repeat      2.022014e-259   90.909091  Chi-squared   0.325995
# z_present                   2.276152e-155   86.363636  Chi-squared   0.251661
# te_has_line                 9.290625e-143   81.818182  Chi-squared   0.241105
# tri_present                  7.136120e-84   77.272727  Chi-squared   0.183990
# dr_present                   3.628179e-77   72.727273  Chi-squared   0.176316
# mr_present                   1.949148e-65   68.181818  Chi-squared   0.162026
# str_present                  3.840831e-50   63.636364  Chi-squared   0.141256
# lctr_has_low_complexity      1.945873e-49   59.090909  Chi-squared   0.140220
# te_has_sine                  2.299776e-36   54.545455  Chi-squared   0.119530
# lctr_has_satellite           9.212641e-23   50.000000  Chi-squared   0.093314
# apr_present                  4.902315e-20   45.454545  Chi-squared   0.087131
# ir_present                   2.597392e-13   40.909091  Chi-squared   0.069636
# te_has_dna                   8.061820e-12   36.363636  Chi-squared   0.065144
# te_has_srprna                1.142054e-02   31.818182  Chi-squared   0.024697
# pseudo_has_snrna             1.331750e-01   27.272727  Chi-squared   0.014784
# pseudo_has_trna              2.737072e-01   22.727273  Chi-squared   0.010894
# te_has_retroposon            3.055214e-01   18.181818  Chi-squared   0.010223
# te_has_rc                    9.558820e-01   13.636364  Chi-squared   0.000573
# pseudo_has_scrna             1.000000e+00    6.818182  Chi-squared   0.000000
# pseudo_has_rrna              1.000000e+00    6.818182  Chi-squared   0.000000
#
#                          odds_ratio  \
# te_has_ltr                 0.062830
# gq_present                19.746085
# lctr_has_simple_repeat     7.521544
# z_present                  5.421061
# te_has_line                0.256669
# tri_present                3.368704
# dr_present                 5.779480
# mr_present                 6.900632
# str_present               14.139791
# lctr_has_low_complexity    4.426762
# te_has_sine                0.515630
# lctr_has_satellite         0.112748
# apr_present                1.792263
# ir_present               127.095350
# te_has_dna                 0.642930
# te_has_srprna              0.259341
# pseudo_has_snrna           0.476817
# pseudo_has_trna            0.409134
# te_has_retroposon          0.715623
# te_has_rc                  0.364041
# pseudo_has_scrna           0.728236
# pseudo_has_rrna            0.728236
#
#                                                                                                                      interpretation  \
# te_has_ltr                 Odds of being protein-coding while having the feature are 0.06 times the odds without having the feature
# gq_present                Odds of being protein-coding while having the feature are 19.75 times the odds without having the feature
# lctr_has_simple_repeat     Odds of being protein-coding while having the feature are 7.52 times the odds without having the feature
# z_present                  Odds of being protein-coding while having the feature are 5.42 times the odds without having the feature
# te_has_line                Odds of being protein-coding while having the feature are 0.26 times the odds without having the feature
# tri_present                Odds of being protein-coding while having the feature are 3.37 times the odds without having the feature
# dr_present                 Odds of being protein-coding while having the feature are 5.78 times the odds without having the feature
# mr_present                 Odds of being protein-coding while having the feature are 6.90 times the odds without having the feature
# str_present               Odds of being protein-coding while having the feature are 14.14 times the odds without having the feature
# lctr_has_low_complexity    Odds of being protein-coding while having the feature are 4.43 times the odds without having the feature
# te_has_sine                Odds of being protein-coding while having the feature are 0.52 times the odds without having the feature
# lctr_has_satellite         Odds of being protein-coding while having the feature are 0.11 times the odds without having the feature
# apr_present                Odds of being protein-coding while having the feature are 1.79 times the odds without having the feature
# ir_present               Odds of being protein-coding while having the feature are 127.10 times the odds without having the feature
# te_has_dna                 Odds of being protein-coding while having the feature are 0.64 times the odds without having the feature
# te_has_srprna                                                          Result is not statistically significant after FDR correction
# pseudo_has_snrna                                                       Result is not statistically significant after FDR correction
# pseudo_has_trna                                                        Result is not statistically significant after FDR correction
# te_has_retroposon                                                      Result is not statistically significant after FDR correction
# te_has_rc                                                              Result is not statistically significant after FDR correction
# pseudo_has_scrna                                                       Result is not statistically significant after FDR correction
# pseudo_has_rrna                                                        Result is not statistically significant after FDR correction
#
#                          significant
# te_has_ltr                      True
# gq_present                      True
# lctr_has_simple_repeat          True
# z_present                       True
# te_has_line                     True
# tri_present                     True
# dr_present                      True
# mr_present                      True
# str_present                     True
# lctr_has_low_complexity         True
# te_has_sine                     True
# lctr_has_satellite              True
# apr_present                     True
# ir_present                      True
# te_has_dna                      True
# te_has_srprna                  False
# pseudo_has_snrna               False
# pseudo_has_trna                False
# te_has_retroposon              False
# te_has_rc                      False
# pseudo_has_scrna               False
# pseudo_has_rrna                False

# %%
chi2_label_dict = {'te_has_ltr': 'LTR',
 'gq_present': 'G-Quadruplex',
 'lctr_has_simple_repeat': 'Simple Repeat',
 'z_present': 'Z-DNA',
 'te_has_line': 'LINE',
 'tri_present': 'Triplex DNA',
 'dr_present': 'Direct Repeat',
 'mr_present': 'Mirror Repeat',
 'str_present': 'Short Tandem Repeat',
 'lctr_has_low_complexity': 'Low Complexity Region'}

# %%
from matplotlib.colors import TwoSlopeNorm

# Select top 10 categorical features by Cramér's V
top10 = chi2_df.sort_values('cramers_v', ascending=False).head(10).copy()

# Prepare color values (odds_ratio): replace inf and NaN with 1 (neutral)
#top10['odds_ratio_clean'] = top10['odds_ratio'].replace([np.inf, -np.inf], np.nan).fillna(1.0)

top10["log10_odds_ratio"] = np.log10(top10["odds_ratio"].replace(0, np.nan))

# Normalizer centered at 1 (neutral odds)
vmin = top10['log10_odds_ratio'].min()
vmax = top10['log10_odds_ratio'].max()
if vmin == vmax:
    vmin *= 0.9
    vmax *= 1.1
norm = TwoSlopeNorm(vmin=vmin, vcenter=1.0, vmax=vmax)

# Plot
y_pos = np.arange(len(top10))[::-1]  # highest rank at top
fig, ax = plt.subplots(figsize=(7, 4.5))
sc = ax.scatter(top10['cramers_v'], y_pos, c=top10['log10_odds_ratio'],
                cmap='RdYlBu_r', s=120, edgecolor='k')

ax.set_yticks(y_pos)
ax.set_yticklabels(top10.index[::-1])
ax.set_xlabel("Effect Size (Cramér's V)")
ax.set_title("Top 10 Categorical Features with association to\ncoding vs lncRNA in low entropy group")

cbar = plt.colorbar(sc, ax=ax)
cbar.set_label("log10 odds ratio\n(direction and magnitude)")

plt.tight_layout()
plt.show()

# %%
# Select top 10 categorical features by Cramér's V
top10 = chi2_df.sort_values('cramers_v', ascending=False).head(10).copy()

# Prepare color values (odds_ratio): replace inf and NaN with 1 (neutral)
#top10['odds_ratio_clean'] = top10['odds_ratio'].replace([np.inf, -np.inf], np.nan).fillna(1.0)

top10["log10_odds_ratio"] = np.log10(top10["odds_ratio"].replace(0, np.nan))

# Colors
norm = plt.Normalize(0, 0.75)
#cmap = sns.color_palette('RdYlBu_r', as_cmap=True)
#cmap = plt.cm.Blues
cmap = sns.color_palette("crest", as_cmap=True)

# Plot
y_pos = np.arange(len(top10))[::-1]  # highest rank at top
fig, ax = plt.subplots(figsize=(7, 4.5))
sc = sns.barplot(x=top10['log10_odds_ratio'], y=top10.index[::-1], hue=top10['cramers_v'], palette=cmap, hue_norm=norm, ax=ax)


ax.set_yticks(y_pos)
ax.set_yticklabels(top10.index[::-1])
ax.set_xlabel("log10 odds ratio\n(direction and magnitude)")
ax.set_title("Top 10 Categorical Features with association to\ncoding vs lncRNA in low entropy group")

# cbar = plt.colorbar(sc, ax=ax)
# cbar.set_label("Effect Size (Cramér's V)")


sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
# Use seaborn RdYlBy_r colormap instead of matplotlib's default


ax.get_legend().remove()
ax.figure.colorbar(sm, ax=ax).set_label("Effect Size (Cramér's V)")

plt.tight_layout()
plt.show()

# %%
# plt.rcParams["axes.titlesize"] = 3
# plt.rcParams["axes.labelsize"] = 3
# plt.rcParams["xtick.labelsize"] = 3
# plt.rcParams["ytick.labelsize"] = 3

# ## Legends and annotations text
# plt.rcParams["font.size"] = 3
# plt.rcParams["legend.fontsize"] = 3

# sns.set_context("paper",
#                 font_scale=0.5,
#                 rc={
#                     "lines.linewidth": 0.5,
#                     "axes.linewidth": 0.5,
#                     "patch.linewidth": 0.5,
#                     "font.family" : "Arial"
#                 },

# )

# sns.set_context("paper",
#                 font_scale=0.5,
#                 rc={
#                     "axes.linewidth": 0.5,
#                     # Color of lines
#                     "axes.edgecolor": "black",
#                     "font.family" : "Arial",
#                     "grid.color": "black",
#                     "grid.linewidth": 0.5,
#                     "figure.edgecolor": "black",
#                     "figure.linewidth": 0.5,
#                     # Opacity of lines
#                     # "axes.edgecolor": "black",
#                     # "axes.linewidth": 0.5,
                
#                 })

# %%
sns.set_theme(style="whitegrid",
              font="Arial",
              rc={
                  "figure.dpi": 300,
                    "axes.titlesize": 6,
                    "axes.labelsize": 6,
                    "xtick.labelsize": 6,
                    "ytick.labelsize": 6,
                    "font.size": 6,
                    "legend.fontsize": 6,
                    "lines.linewidth": 0.5,
                    "axes.linewidth": 0.5,
                    "patch.linewidth": 0.5,
                    "axes.edgecolor": "black",
                    "grid.linewidth": 0.5,
                    "figure.edgecolor": "black",
                    "xtick.major.width": 0.5,
                    "ytick.major.width": 0.5,
                    "xtick.major.size": 3,
                    "ytick.major.size": 3
                  }
              )

# %%
# Select top 10 categorical features by Cramér's V
top10 = chi2_df.sort_values('cramers_v', ascending=False).head(10).copy()
top10['label'] = top10.index.map(chi2_label_dict)
top10["log10_odds_ratio"] = np.log10(top10["odds_ratio"].replace(0, np.nan))

# Colors
norm = plt.Normalize(0, 0.6)
cmap = sns.color_palette("crest", as_cmap=True)
#cmap = sns.color_palette('RdYlBu_r', as_cmap=True)
#cmap = plt.cm.Blues

fig_h_cm = 5
fig_w_cm = 9

# Plot
fig, ax = plt.subplots(figsize=(fig_w_cm / 2.54 , fig_h_cm/2.54), dpi=300)
bar = sns.barplot(x=top10['log10_odds_ratio'], y=top10.index[::-1], hue=top10['cramers_v'], palette=cmap, hue_norm=norm, ax=ax)

# Ticks and labels
y_pos = np.arange(len(top10))[::-1]  # highest rank at top
ax.set_yticks(y_pos)
ax.set_yticklabels(top10['label'][::-1])
ax.set_ylabel("Presence of feature")
#ax.set_xlabel(r'$\log_{10}$' + " odds ratio\n(direction and magnitude)")
ax.set_xlabel(r'$\log_{10}$' + " odds ratio")
#ax.set_title("Top 10 Categorical Features with association to\ncoding vs lncRNA in low entropy group", pad=15)
ax.set_xlim(-1.3, 1.3)

# Add annotation on top of graph with direction
# Right is pc, left is lncRNA, 0 shows no association
ax.text(1.2, 1.02, 'coding →', ha='right', va='bottom', transform=ax.get_xaxis_transform())
ax.text(-1.2, 1.02, '← lncRNA', ha='left', va='bottom', transform=ax.get_xaxis_transform())
ax.text(0, 1.02, 'No association', ha='center', va='bottom', transform=ax.get_xaxis_transform())

# Colorbar
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
ax.get_legend().remove()
cbar = ax.figure.colorbar(sm, ax=ax)
cbar.set_label("Effect Size (Cramér's V)")
cbar.set_ticks([0, 0.2, 0.4, 0.6])
#cbar.set_ticklabels(['0', '0.2 (mild)', '0.4 (medium)', '0.6 (strong)'])
cbar.set_ticklabels(['0', '0.2', '0.4', '0.6'])


plt.tight_layout()
plt.show()

# %% [markdown]
# #### Frequencies

# %%
# Calculate frequencies for categorical features by entropy group
feature_frequencies = []

for feature in top10.index:
    # Low entropy group
    lncRNA = categorical_features.loc[grp1, feature]
    
    # High entropy group
    coding = categorical_features.loc[grp2, feature]
    
    feature_frequencies.append({
        'feature': feature,
        'lncRNA_freq': lncRNA.sum() / len(lncRNA) * 100,
        'coding_freq': coding.sum() / len(coding) * 100,
        'lncRNA_n': len(grp1),
        'coding_n': len(grp2)
    })
    
    freq_df = pd.DataFrame(feature_frequencies).set_index('feature')

# Add labels
freq_df['label'] = freq_df.index.map(chi2_label_dict)

# Reorder by top10 order (highest Cramér's V first)
freq_df = freq_df.loc[top10.index]

print("Feature frequencies by class and entropy group:")
print(freq_df[['label', 'lncRNA_freq', 'coding_freq']].round(1))
# Out:
# Feature frequencies by class and entropy group:
#                                          label  lncRNA_freq  coding_freq
# feature
# te_has_ltr                                 LTR         54.5          7.0
# gq_present                        G-Quadruplex         78.7         98.6
# lctr_has_simple_repeat           Simple Repeat         18.9         63.7
# z_present                                Z-DNA         73.3         93.7
# te_has_line                               LINE         44.1         16.8
# tri_present                        Triplex DNA         73.8         90.5
# dr_present                       Direct Repeat         88.8         97.9
# mr_present                       Mirror Repeat         92.0         98.8
# str_present                Short Tandem Repeat         96.1         99.7
# lctr_has_low_complexity  Low Complexity Region          5.5         20.6

# %%
freq_df
# Out:
#                          lncRNA_freq  coding_freq  lncRNA_n  coding_n  \
# feature
# te_has_ltr                 54.534884     7.008257      1720      9446
# gq_present                 78.662791    98.644929      1720      9446
# lctr_has_simple_repeat     18.895349    63.667161      1720      9446
# z_present                  73.255814    93.690451      1720      9446
# te_has_line                44.069767    16.821935      1720      9446
# tri_present                73.837209    90.482744      1720      9446
# dr_present                 88.837209    97.872115      1720      9446
# mr_present                 92.034884    98.761380      1720      9446
# str_present                96.104651    99.714165      1720      9446
# lctr_has_low_complexity     5.523256    20.558967      1720      9446
#
#                                          label
# feature
# te_has_ltr                                 LTR
# gq_present                        G-Quadruplex
# lctr_has_simple_repeat           Simple Repeat
# z_present                                Z-DNA
# te_has_line                               LINE
# tri_present                        Triplex DNA
# dr_present                       Direct Repeat
# mr_present                       Mirror Repeat
# str_present                Short Tandem Repeat
# lctr_has_low_complexity  Low Complexity Region

# %%
freq_df
# Out:
#                          lncRNA_freq  coding_freq  lncRNA_n  coding_n  \
# feature
# te_has_ltr                 54.534884     7.008257      1720      9446
# gq_present                 78.662791    98.644929      1720      9446
# lctr_has_simple_repeat     18.895349    63.667161      1720      9446
# z_present                  73.255814    93.690451      1720      9446
# te_has_line                44.069767    16.821935      1720      9446
# tri_present                73.837209    90.482744      1720      9446
# dr_present                 88.837209    97.872115      1720      9446
# mr_present                 92.034884    98.761380      1720      9446
# str_present                96.104651    99.714165      1720      9446
# lctr_has_low_complexity     5.523256    20.558967      1720      9446
#
#                                          label
# feature
# te_has_ltr                                 LTR
# gq_present                        G-Quadruplex
# lctr_has_simple_repeat           Simple Repeat
# z_present                                Z-DNA
# te_has_line                               LINE
# tri_present                        Triplex DNA
# dr_present                       Direct Repeat
# mr_present                       Mirror Repeat
# str_present                Short Tandem Repeat
# lctr_has_low_complexity  Low Complexity Region

# %%
fig_h_cm = 5
fig_w_cm = 8

freq_df = freq_df.rename(columns={'lncRNA_freq': 'lncRNA', 'coding_freq': 'Coding'})

fig, ax = plt.subplots(figsize=(fig_w_cm/2.54, fig_h_cm/2.54), dpi=300)
freq_df.plot.barh(x='label', y=['lncRNA', 'Coding'], ax=ax, color=['#9467bd', '#d95f02'])

ax.invert_yaxis()  # Highest rank at top

ax.set_xlabel("Transcripts with feature (%)")
ax.set_ylabel("Presence of feature")

ax.legend(title="", loc='upper center', bbox_to_anchor=(0.5, 1.12), ncol=2, frameon=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6.2 Continuous variables

# %%
mannu_to_plot = combined_df.loc[(combined_df["test"] == 'Mann-Whitney U'), mann_tidy_columns + ["abs_vda"]].sort_values('abs_vda', ascending=False).head(10)
mannu_to_plot.index.tolist()
# Out:
# ['ORF_T0_MW_lncDC',
#  'ORF_T0_length_lncDC',
#  'ORF.Max.Len_lncfinder',
#  'ORF_l_cpat',
#  'Seq.pct.Dist_lncfinder',
#  'Seq.lnc.Dist_lncfinder',
#  'Fickett_l_cpat',
#  'Hexamer_l_cpat',
#  'Signal.Peak_lncfinder',
#  'RCB_T0_lncDC']

# %%
mannu_dict = {
'ORF_T1_length_lncDC': 'ORF length (type 1)',
 'RNA_size_feelnc': 'Transcript length',
 'Signal.Min_lncfinder': 'Minimum frame signal',
 'SS.pct.dist_lncfinder': 'Log. distance to coding SS',
 'Signal.Q1_lncfinder': 'Q1 of frame signal',
 'Signal.Q2_lncfinder': 'Q2 of frame signal',
 'SS.lnc.dist_lncfinder': 'Log. distance to lncRNA SS',
 'MFE_lncfinder': 'Minimum free energy',
 'Signal.Max_lncfinder': 'Maximum frame signal',
 'Dot_pct.dist_lncfinder': 'Distance to coding SS (dot format)',
 'ORF_T0_MW_lncDC': 'ORF Mol. Weight (type 1)',
 'ORF_T0_length_lncDC': 'ORF length (type 0)',
 'ORF_l_cpat': 'ORF length (CPAT)',
 'ORF.Max.Len_lncfinder': 'Max. ORF length',
 'Seq.pct.Dist_lncfinder': 'Log. distance to coding seqs.',
 'Seq.lnc.Dist_lncfinder': 'Log. distance to lncRNA seqs.',
 'Fickett_l_cpat': 'Fickett score (CPAT)',
 'Hexamer_l_cpat': 'Hexamer score (CPAT)',
 'Signal.Peak_lncfinder': 'Peak frame signal',
 'RCB_T0_lncDC': 'ORF relative codon bias (type 0)',
 'global_gaps_max': 'Max gap length between rep. elements',
 'SS.Dist.Ratio_lncfinder': 'Ratio of Distance coding vs lncRNA SS',
 'total_nonb_count': 'Total non-B DNA motifs',
 'ORF_T0_coverage_lncDC': 'ORF coverage (type 0)',
 'RCB_T1_lncDC': 'ORF relative codon bias (type 1)',
 'ORF_T2_MW_lncDC': 'ORF Mol. Weight (type 2)',
 'Hexamer_score_ORF_T0_lncDC': 'Hexamer score (ORF type 0)',
}

# %%
# Select top 10 categorical features by Cramér's V
top10 = mannu_to_plot
top10["vda_to_plot"] = top10["vda"] - 0.5  # Center around 0 for better color mapping

top10['label'] = top10.index.map(mannu_dict)
#top10['label'] = top10.index

# Colors
norm = plt.Normalize(0, 0.6)
cmap = sns.color_palette("crest")
#cmap = sns.color_palette('RdYlBu_r', as_cmap=True)
#cmap = plt.cm.Blues

fig_h_cm = 5
fig_w_cm = 9

# Plot
fig, ax = plt.subplots(figsize=(fig_w_cm / 2.54 , fig_h_cm/2.54), dpi=300)
bar = sns.barplot(x=top10['vda_to_plot'], y=top10.index[::-1], ax=ax, color=sns.color_palette("crest")[-2])

y_pos = np.arange(len(top10))[::-1]  # highest rank at top
ax.set_yticks(y_pos)
ax.set_yticklabels(top10['label'][::-1])
ax.set_ylabel("Continuous features", labelpad=5)
ax.set_xlabel("Effect size (VDA) - 0.5")
#ax.set_title("Top 10 Categorical Features with association to\ncoding vs lncRNA in low entropy group", pad=30)
ax.set_xlim(-0.55, 0.55)
ax.set_xticks([-0.5, -0.25, 0, 0.25, 0.5])
#ax.set_xticklabels(['0.0', '0.25', '0.5', '0.75', '1.0'])

#Add annotation on top of graph with direction
#Right is pc, left is lncRNA, 0 shows no association
ax.text(0.5, 1.02, 'coding →', ha='right', va='bottom', transform=ax.get_xaxis_transform())
ax.text(-0.5, 1.02, '← lncRNA', ha='left', va='bottom', transform=ax.get_xaxis_transform())
ax.text(0, 1.02, 'No association', ha='center', va='bottom', transform=ax.get_xaxis_transform())

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6.3 Selected continuous variables after clustering

# %%
cluster_df = pd.read_csv("/mnt/cbib/LNClassifier/paper/results/gencode.v47.common.cdhit.cv/features/clustering/feature_clusters_at_distances.csv", index_col=0)
cluster_df
# Out:
#                                     cluster_0.05  cluster_0.10  cluster_0.15  \
# feature
# AAA_plncpro                                  220           188           168
# AAC_plncpro                                  196           164           146
# AAG_plncpro                                  193           161           143
# AAT_plncpro                                  218           186           167
# ACA_plncpro                                  198           166           148
# ACC_plncpro                                  202           170           152
# ACG_plncpro                                  272           236           213
# ACT_plncpro                                  255           221           201
# AGA_plncpro                                  195           163           145
# AGC_plncpro                                  228           195           175
# AGG_plncpro                                  250           216           196
# AGT_plncpro                                  236           203           183
# ATA_plncpro                                  213           181           163
# ATC_plncpro                                  244           210           190
# ATG_plncpro                                  199           167           149
# ATT_plncpro                                  215           183           165
# CAA_plncpro                                  197           165           147
# CAC_plncpro                                  204           172           154
# CAG_plncpro                                  229           196           176
# CAT_plncpro                                  245           211           191
# CCA_plncpro                                  203           171           153
# CCC_plncpro                                  226           193           173
# CCG_plncpro                                  267           231           210
# CCT_plncpro                                  205           173           155
# CGA_plncpro                                  273           237           214
# CGC_plncpro                                  268           232           210
# CGG_plncpro                                  270           234           212
# CGT_plncpro                                  274           238           215
# CTA_plncpro                                  253           219           199
# CTC_plncpro                                  207           175           157
# CTG_plncpro                                  209           177           159
# CTT_plncpro                                  247           213           193
# Dot_Dist.Ratio_lncfinder                     263           228           207
# Dot_lnc.dist_lncfinder                       113            93            80
# Dot_pct.dist_lncfinder                       113            93            80
# Fickett_l_cpat                               261           226           205
# Fickett_score_lncDC                          243           209           189
# GAA_plncpro                                  194           162           144
# GAC_plncpro                                  237           204           184
# GAG_plncpro                                  252           218           198
# GAT_plncpro                                  200           168           150
# GCA_plncpro                                  230           197           177
# GCC_plncpro                                  224           191           171
# GCG_plncpro                                  271           235           212
# GCT_plncpro                                  210           178           160
# GC_content_lncDC                             221           189           169
# GC_content_paired_ss_lncDC                   221           189           169
# GGA_plncpro                                  251           217           197
# GGC_plncpro                                  223           190           170
# GGG_plncpro                                  225           192           172
# GGT_plncpro                                  190           158           140
# GTA_plncpro                                  234           201           181
# GTC_plncpro                                  208           176           158
# GTG_plncpro                                  192           160           142
# GTT_plncpro                                  231           198           178
# Hexamer_l_cpat                               258           223           202
# Hexamer_score_ORF_T0_lncDC                   259           224           203
# Hexamer_score_ORF_T1_lncDC                   212           180           162
# Hexamer_score_ORF_T2_lncDC                   265           229           208
# Hexamer_score_ORF_T3_lncDC                   212           180           162
# MFE_lncfinder                                114            93            80
# ORF.Max.Cov_lncfinder                        239           206           186
# ORF.Max.Len_lncfinder                        103            84            73
# ORF_T0_MW_lncDC                              104            85            74
# ORF_T0_PI_lncDC                              147           120           106
# ORF_T0_aromaticity_lncDC                     144           117           103
# ORF_T0_coverage_lncDC                        242           208           188
# ORF_T0_instability_lncDC                     145           118           104
# ORF_T0_length_lncDC                          104            85            74
# ORF_T1_MW_lncDC                              238           205           185
# ORF_T1_coverage_lncDC                        106            87            75
# ORF_T1_instability_lncDC                     146           119           105
# ORF_T1_length_lncDC                          114            93            80
# ORF_T2_MW_lncDC                              102            83            72
# ORF_T2_length_lncDC                          102            83            72
# ORF_T3_MW_lncDC                              238           205           185
# ORF_T3_coverage_lncDC                        106            87            75
# ORF_cover_feelnc                             240           206           186
# ORF_coverage_l_cpat                          239           206           186
# ORF_l_cpat                                   103            84            73
# RCB_T0_lncDC                                 105            86            74
# RCB_T1_lncDC                                 116            94            81
# RNA_size_feelnc                              114            93            80
# SNR_lncfinder                                100            81            70
# SS.Dist.Ratio_lncfinder                      264           228           207
# SS.lnc.dist_lncfinder                        113            93            80
# SS.pct.dist_lncfinder                        113            93            80
# SS_score_k1_lncDC                            222           189           169
# SS_score_k2_lncDC                            269           233           211
# SS_score_k3_lncDC                            269           233           211
# SS_score_k4_lncDC                            269           233           211
# SS_score_k5_lncDC                            269           233           211
# Seq.Dist.Ratio_lncfinder                     262           227           206
# Seq.lnc.Dist_lncfinder                       103            84            73
# Seq.pct.Dist_lncfinder                       103            84            73
# Signal.Max_lncfinder                         115            93            80
# Signal.Min_lncfinder                         114            93            80
# Signal.Peak_lncfinder                        101            82            71
# Signal.Q1_lncfinder                          114            93            80
# Signal.Q2_lncfinder                          114            93            80
# TAA_plncpro                                  219           187           167
# TAC_plncpro                                  254           220           200
# TAG_plncpro                                  235           202           182
# TAT_plncpro                                  214           182           164
# TCA_plncpro                                  246           212           192
# TCC_plncpro                                  206           174           156
# TCG_plncpro                                  275           239           216
# TCT_plncpro                                  249           215           195
# TGA_plncpro                                  201           169           151
# TGC_plncpro                                  211           179           161
# TGG_plncpro                                  191           159           141
# TGT_plncpro                                  233           200           180
# TTA_plncpro                                  216           184           165
# TTC_plncpro                                  248           214           194
# TTG_plncpro                                  232           199           179
# TTT_plncpro                                  217           185           166
# UP.PCT_lncfinder                             227           194           174
# all_nonb_gaps_max                             56            46            38
# all_nonb_gaps_mean                           155           128           114
# all_nonb_gaps_median                         156           129           115
# all_nonb_gaps_min                             49            39            33
# apr_gaps_max                                   9             6             5
# apr_gaps_max_pct                              13             9             7
# apr_gaps_mean                                  7             5             4
# apr_gaps_mean_pct                             12             9             7
# apr_gaps_median                                8             5             4
# apr_gaps_median_pct                           12             9             7
# apr_gaps_min                                  10             7             6
# apr_gaps_min_pct                              10             7             6
# apr_hit_count                                  2             2             1
# apr_hit_count_per_kb                           1             1             1
# apr_max_length                                 5             4             3
# apr_max_length_pct                            11             8             7
# apr_mean_length                                6             4             3
# apr_mean_length_pct                           11             8             7
# apr_std_length                                 3             3             2
# apr_std_length_pct                             4             3             2
# apr_total_length                               2             2             1
# apr_total_length_pct                           1             1             1
# apr_unique_length                              2             2             1
# apr_unique_length_pct                          1             1             1
# dr_gaps_max                                   53            43            36
# dr_gaps_max_pct                               76            61            53
# dr_gaps_mean                                 159           132           118
# dr_gaps_mean_pct                              75            60            52
# dr_gaps_median                               160           133           118
# dr_gaps_median_pct                            75            60            52
# dr_gaps_min                                  153           126           112
# dr_gaps_min_pct                              153           126           112
# dr_hit_count                                  43            33            29
# dr_hit_count_per_kb                           21            16            13
# dr_max_length                                 14            10             8
# dr_max_length_pct                             66            54            46
# dr_mean_length                                16            11             9
# dr_mean_length_pct                            67            54            46
# dr_std_length                                 15            10             8
# dr_std_length_pct                             68            55            47
# dr_total_length                               43            33            29
# dr_total_length_pct                           21            16            13
# dr_unique_length                              43            33            29
# dr_unique_length_pct                          21            16            13
# global_gaps_max                              117            95            82
# global_gaps_mean                             117            95            82
# global_gaps_mean_pct                         118            96            83
# global_gaps_median                           119            96            83
# global_gaps_median_pct                       118            96            83
# global_gaps_min                              120            97            84
# global_rm_count                              176           148           132
# global_rm_count_per_kb                       178           149           133
# global_rm_total_length                       177           148           132
# global_rm_total_length_pct                   179           149           133
# gq_gaps_max                                   90            73            62
# gq_gaps_max_pct                               88            72            61
# gq_gaps_mean                                  91            73            62
# gq_gaps_mean_pct                              89            72            61
# gq_gaps_median                                86            70            60
# gq_gaps_median_pct                            87            71            60
# gq_gaps_min                                   85            69            59
# gq_gaps_min_pct                               85            69            59
# gq_hit_count                                 148           121           107
# gq_hit_count_per_kb                          149           122           108
# gq_max_length                                150           123           109
# gq_max_length_pct                             62            51            43
# gq_mean_length                               152           125           111
# gq_mean_length_pct                            62            51            43
# gq_std_length                                151           124           110
# gq_std_length_pct                             63            52            44
# gq_total_length                              148           121           107
# gq_total_length_pct                          149           122           108
# gq_unique_length                             148           121           107
# gq_unique_length_pct                         149           122           108
# ir_gaps_max                                   57            47            39
# ir_gaps_max_pct                              112            92            79
# ir_gaps_mean                                 142           115           101
# ir_gaps_mean_pct                             110            90            78
# ir_gaps_median                               143           116           102
# ir_gaps_median_pct                           110            90            78
# ir_gaps_min                                   42            32            28
# ir_gaps_min_pct                               42            32            28
# ir_hit_count                                  46            36            30
# ir_hit_count_per_kb                           22            17            14
# ir_max_length                                 50            40            34
# ir_max_length_pct                             69            56            48
# ir_mean_length                               140           114           100
# ir_mean_length_pct                           111            91            78
# ir_std_length                                141           114           100
# ir_std_length_pct                             70            56            48
# ir_total_length                               46            36            30
# ir_total_length_pct                           22            17            14
# ir_unique_length                              46            36            30
# ir_unique_length_pct                          22            17            14
# kmerScore_12mer_feelnc                       260           225           204
# kmerScore_1mer_feelnc                        266           230           209
# kmerScore_2mer_feelnc                        266           230           209
# kmerScore_3mer_feelnc                        256           222           202
# kmerScore_6mer_feelnc                        256           222           202
# kmerScore_9mer_feelnc                        257           222           202
# lctr_count                                   124           100            87
# lctr_count_per_kb                            123           100            87
# lctr_gaps_max                                125           101            87
# lctr_gaps_mean                               125           101            87
# lctr_gaps_median                             125           101            87
# lctr_gaps_min                                126           101            87
# lctr_low_complexity_count                    121            98            85
# lctr_low_complexity_count_per_kb             121            98            85
# lctr_mean_length                             124           100            87
# lctr_mean_length_pct                         123           100            87
# lctr_mean_num_fragments                      124           100            87
# lctr_satellite_count                         139           113            99
# lctr_satellite_count_per_kb                  139           113            99
# lctr_simple_repeat_count                     122            99            86
# lctr_simple_repeat_count_per_kb              122            99            86
# lctr_sum_num_fragments                       124           100            87
# lctr_total_length                            124           100            87
# lctr_total_length_pct                        123           100            87
# motif_diversity                               20            15            12
# mr_gaps_max                                   54            44            36
# mr_gaps_max_pct                               77            62            53
# mr_gaps_mean                                 161           134           119
# mr_gaps_mean_pct                              74            59            51
# mr_gaps_median                               162           135           120
# mr_gaps_median_pct                            74            59            51
# mr_gaps_min                                  154           127           113
# mr_gaps_min_pct                              154           127           113
# mr_hit_count                                  44            34            30
# mr_hit_count_per_kb                           24            19            15
# mr_max_length                                 32            24            20
# mr_max_length_pct                             71            57            49
# mr_mean_length                                34            26            22
# mr_mean_length_pct                            72            57            49
# mr_std_length                                 33            25            21
# mr_std_length_pct                             73            58            50
# mr_total_length                               44            34            30
# mr_total_length_pct                           24            19            15
# mr_unique_length                              44            34            30
# mr_unique_length_pct                          24            19            15
# n_motif_types                                 47            37            31
# orf_coverage_plncpro                         241           207           187
# pseudo_ancient_count                          93            75            64
# pseudo_ancient_count_per_kb                   93            75            64
# pseudo_count                                  99            80            69
# pseudo_count_per_kb                           99            80            69
# pseudo_max_divergence                         98            80            69
# pseudo_max_hit_length                         99            80            69
# pseudo_max_hit_reference_coverage             96            78            67
# pseudo_max_num_fragments                      99            80            69
# pseudo_max_perc_del                           94            76            65
# pseudo_max_perc_ins                           92            74            63
# pseudo_max_sw_score                           99            80            69
# pseudo_mean_divergence                        98            80            69
# pseudo_mean_hit_length                        99            80            69
# pseudo_mean_hit_reference_coverage            96            78            67
# pseudo_mean_num_fragments                     99            80            69
# pseudo_mean_perc_del                          94            76            65
# pseudo_mean_perc_ins                          92            74            63
# pseudo_mean_sw_score                          99            80            69
# pseudo_min_divergence                         98            80            69
# pseudo_min_hit_length                         99            80            69
# pseudo_min_hit_reference_coverage             96            78            67
# pseudo_min_perc_del                           94            76            65
# pseudo_min_perc_ins                           92            74            63
# pseudo_min_sw_score                           99            80            69
# pseudo_rrna_count                            134           108            94
# pseudo_rrna_count_per_kb                     134           108            94
# pseudo_scrna_count                           133           107            93
# pseudo_scrna_count_per_kb                    133           107            93
# pseudo_snrna_count                            97            79            68
# pseudo_snrna_count_per_kb                     97            79            68
# pseudo_sum_fragmented                        135           109            95
# pseudo_sum_hit_length                         99            80            69
# pseudo_sum_num_fragments                      99            80            69
# pseudo_trna_count                             95            77            66
# pseudo_trna_count_per_kb                      95            77            66
# pseudo_unique_classes                         99            80            69
# pseudo_unique_subfamilies                     99            80            69
# pseudogene_gaps_max                           99            80            69
# pseudogene_gaps_mean                          99            80            69
# pseudogene_gaps_median                        99            80            69
# pseudogene_gaps_min                           99            80            69
# str_gaps_max                                  55            45            37
# str_gaps_max_pct                              78            63            54
# str_gaps_mean                                157           130           116
# str_gaps_mean_pct                            107            88            76
# str_gaps_median                              158           131           117
# str_gaps_median_pct                          108            88            76
# str_gaps_min                                  41            31            27
# str_gaps_min_pct                              41            31            27
# str_hit_count                                 45            35            30
# str_hit_count_per_kb                          23            18            15
# str_max_length                                17            12            10
# str_max_length_pct                            64            53            45
# str_mean_length                               19            14            11
# str_mean_length_pct                          109            89            77
# str_std_length                                18            13            10
# str_std_length_pct                            65            53            45
# str_total_length                              45            35            30
# str_total_length_pct                          23            18            15
# str_unique_length                             45            35            30
# str_unique_length_pct                         23            18            15
# te_ancient_count                             175           147           131
# te_ancient_count_per_kb                      175           147           131
# te_count                                     189           157           139
# te_count_per_kb                              180           150           134
# te_dna_count                                 130           104            90
# te_dna_count_per_kb                          130           104            90
# te_fragmented_ratio                          129           103            89
# te_gaps_max                                  165           138           122
# te_gaps_max_pct                              166           138           122
# te_gaps_mean                                 165           138           122
# te_gaps_mean_pct                             164           137           122
# te_gaps_median                               164           137           122
# te_gaps_median_pct                           164           137           122
# te_gaps_min                                  163           136           121
# te_gaps_min_pct                              163           136           121
# te_line_count                                171           143           127
# te_line_count_per_kb                         171           143           127
# te_ltr_count                                 168           140           124
# te_ltr_count_per_kb                          168           140           124
# te_max_divergence                            186           155           138
# te_max_hit_length                            184           153           136
# te_max_hit_length_pct                        181           151           134
# te_max_hit_reference_coverage                169           141           125
# te_max_num_fragments                         188           156           139
# te_max_perc_del                              185           154           137
# te_max_perc_ins                              173           145           129
# te_max_sw_score                              183           153           136
# te_mean_divergence                           186           155           138
# te_mean_hit_length                           184           153           136
# te_mean_hit_length_pct                       181           151           134
# te_mean_hit_reference_coverage               169           141           125
# te_mean_num_fragments                        188           156           139
# te_mean_perc_del                             185           154           137
# te_mean_perc_ins                             173           145           129
# te_mean_sw_score                             183           153           136
# te_min_divergence                            187           155           138
# te_min_hit_length                            182           152           135
# te_min_hit_length_pct                        181           151           134
# te_min_hit_reference_coverage                170           142           126
# te_min_perc_del                              167           139           123
# te_min_perc_ins                              174           146           130
# te_min_sw_score                              182           152           135
# te_ple_count                                 136           110            96
# te_ple_count_per_kb                          136           110            96
# te_rc_count                                  137           111            97
# te_rc_count_per_kb                           137           111            97
# te_retroposon_count                          131           105            91
# te_retroposon_count_per_kb                   131           105            91
# te_sine_count                                172           144           128
# te_sine_count_per_kb                         172           144           128
# te_srprna_count                              138           112            98
# te_srprna_count_per_kb                       138           112            98
# te_sum_fragmented                            129           103            89
# te_sum_hit_length                            184           153           136
# te_sum_hit_length_pct                        180           150           134
# te_sum_num_fragments                         189           157           139
# te_unique_classes                            189           157           139
# te_unique_families                           189           157           139
# te_unique_subfamilies                        189           157           139
# te_young_count                               132           106            92
# te_young_count_per_kb                        132           106            92
# total_nonb_count                              46            36            30
# total_nonb_coverage                           46            36            30
# total_nonb_coverage_pct                       25            19            15
# tri_gaps_max                                  52            42            35
# tri_gaps_max_pct                              61            50            42
# tri_gaps_mean                                 51            41            35
# tri_gaps_mean_pct                             60            50            42
# tri_gaps_median                               51            41            35
# tri_gaps_median_pct                           60            50            42
# tri_gaps_min                                  58            48            40
# tri_gaps_min_pct                              58            48            40
# tri_hit_count                                 27            21            17
# tri_hit_count_per_kb                          26            20            16
# tri_max_length                                28            22            18
# tri_max_length_pct                            59            49            41
# tri_mean_length                               29            22            18
# tri_mean_length_pct                           59            49            41
# tri_std_length                                30            23            19
# tri_std_length_pct                            31            23            19
# tri_total_length                              27            21            17
# tri_total_length_pct                          26            20            16
# tri_unique_length                             27            21            17
# tri_unique_length_pct                         26            20            16
# unknown_count                                127           102            88
# unknown_count_per_kb                         127           102            88
# unknown_gaps_max                             127           102            88
# unknown_gaps_mean                            127           102            88
# unknown_gaps_median                          127           102            88
# unknown_gaps_min                             128           102            88
# unknown_mean_length                          127           102            88
# unknown_mean_length_pct                      127           102            88
# unknown_mean_num_fragments                   127           102            88
# unknown_sum_num_fragments                    127           102            88
# unknown_total_length                         127           102            88
# unknown_total_length_pct                     127           102            88
# z_gaps_max                                    48            38            32
# z_gaps_max_pct                                84            68            58
# z_gaps_mean                                   80            65            56
# z_gaps_mean_pct                               83            67            58
# z_gaps_median                                 81            65            56
# z_gaps_median_pct                             83            67            58
# z_gaps_min                                    79            64            55
# z_gaps_min_pct                                79            64            55
# z_hit_count                                   36            28            24
# z_hit_count_per_kb                            35            27            23
# z_max_length                                  39            30            26
# z_max_length_pct                              82            66            57
# z_mean_length                                 40            30            26
# z_mean_length_pct                             82            66            57
# z_std_length                                  37            29            25
# z_std_length_pct                              38            29            25
# z_total_length                                36            28            24
# z_total_length_pct                            35            27            23
# z_unique_length                               36            28            24
# z_unique_length_pct                           35            27            23
#
#                                     cluster_0.20  cluster_0.25  cluster_0.30  \
# feature
# AAA_plncpro                                  152           136           123
# AAC_plncpro                                  131           117           105
# AAG_plncpro                                  128           115           103
# AAT_plncpro                                  151           136           123
# ACA_plncpro                                  133           119           107
# ACC_plncpro                                  137           123           111
# ACG_plncpro                                  193           176           163
# ACT_plncpro                                  182           166           153
# AGA_plncpro                                  130           116           104
# AGC_plncpro                                  157           141           128
# AGG_plncpro                                  177           161           148
# AGT_plncpro                                  165           149           136
# ATA_plncpro                                  148           134           121
# ATC_plncpro                                  171           155           142
# ATG_plncpro                                  134           120           108
# ATT_plncpro                                  149           135           122
# CAA_plncpro                                  132           118           106
# CAC_plncpro                                  139           125           113
# CAG_plncpro                                  158           142           129
# CAT_plncpro                                  172           156           143
# CCA_plncpro                                  138           124           112
# CCC_plncpro                                  155           139           126
# CCG_plncpro                                  191           175           162
# CCT_plncpro                                  140           126           114
# CGA_plncpro                                  194           177           164
# CGC_plncpro                                  191           175           162
# CGG_plncpro                                  192           175           162
# CGT_plncpro                                  195           178           165
# CTA_plncpro                                  180           164           151
# CTC_plncpro                                  142           128           115
# CTG_plncpro                                  144           130           117
# CTT_plncpro                                  174           158           145
# Dot_Dist.Ratio_lncfinder                     188           172           159
# Dot_lnc.dist_lncfinder                        69            60            53
# Dot_pct.dist_lncfinder                        69            60            53
# Fickett_l_cpat                               186           170           157
# Fickett_score_lncDC                          170           154           141
# GAA_plncpro                                  129           115           103
# GAC_plncpro                                  166           150           137
# GAG_plncpro                                  179           163           150
# GAT_plncpro                                  135           121           109
# GCA_plncpro                                  159           143           130
# GCC_plncpro                                  153           137           124
# GCG_plncpro                                  192           175           162
# GCT_plncpro                                  145           131           118
# GC_content_lncDC                             153           137           124
# GC_content_paired_ss_lncDC                   153           137           124
# GGA_plncpro                                  178           162           149
# GGC_plncpro                                  153           137           124
# GGG_plncpro                                  154           138           125
# GGT_plncpro                                  125           112           100
# GTA_plncpro                                  163           147           134
# GTC_plncpro                                  143           129           116
# GTG_plncpro                                  127           114           102
# GTT_plncpro                                  160           144           131
# Hexamer_l_cpat                               183           167           154
# Hexamer_score_ORF_T0_lncDC                   184           168           155
# Hexamer_score_ORF_T1_lncDC                   147           133           120
# Hexamer_score_ORF_T2_lncDC                   189           173           160
# Hexamer_score_ORF_T3_lncDC                   147           133           120
# MFE_lncfinder                                 69            60            53
# ORF.Max.Cov_lncfinder                        168           152           139
# ORF.Max.Len_lncfinder                         63            56            49
# ORF_T0_MW_lncDC                               64            56            49
# ORF_T0_PI_lncDC                               95            84            75
# ORF_T0_aromaticity_lncDC                      92            81            72
# ORF_T0_coverage_lncDC                        169           153           140
# ORF_T0_instability_lncDC                      93            82            73
# ORF_T0_length_lncDC                           64            56            49
# ORF_T1_MW_lncDC                              167           151           138
# ORF_T1_coverage_lncDC                         65            57            50
# ORF_T1_instability_lncDC                      94            83            74
# ORF_T1_length_lncDC                           69            60            53
# ORF_T2_MW_lncDC                               62            55            48
# ORF_T2_length_lncDC                           62            55            48
# ORF_T3_MW_lncDC                              167           151           138
# ORF_T3_coverage_lncDC                         65            57            50
# ORF_cover_feelnc                             168           152           139
# ORF_coverage_l_cpat                          168           152           139
# ORF_l_cpat                                    63            56            49
# RCB_T0_lncDC                                  64            56            49
# RCB_T1_lncDC                                  70            61            53
# RNA_size_feelnc                               69            60            53
# SNR_lncfinder                                 61            54            47
# SS.Dist.Ratio_lncfinder                      188           172           159
# SS.lnc.dist_lncfinder                         69            60            53
# SS.pct.dist_lncfinder                         69            60            53
# SS_score_k1_lncDC                            153           137           124
# SS_score_k2_lncDC                            192           175           162
# SS_score_k3_lncDC                            192           175           162
# SS_score_k4_lncDC                            192           175           162
# SS_score_k5_lncDC                            192           175           162
# Seq.Dist.Ratio_lncfinder                     187           171           158
# Seq.lnc.Dist_lncfinder                        63            56            49
# Seq.pct.Dist_lncfinder                        63            56            49
# Signal.Max_lncfinder                          69            60            53
# Signal.Min_lncfinder                          69            60            53
# Signal.Peak_lncfinder                         61            54            47
# Signal.Q1_lncfinder                           69            60            53
# Signal.Q2_lncfinder                           69            60            53
# TAA_plncpro                                  151           136           123
# TAC_plncpro                                  181           165           152
# TAG_plncpro                                  164           148           135
# TAT_plncpro                                  148           134           121
# TCA_plncpro                                  173           157           144
# TCC_plncpro                                  141           127           114
# TCG_plncpro                                  196           179           166
# TCT_plncpro                                  176           160           147
# TGA_plncpro                                  136           122           110
# TGC_plncpro                                  146           132           119
# TGG_plncpro                                  126           113           101
# TGT_plncpro                                  162           146           133
# TTA_plncpro                                  149           135           122
# TTC_plncpro                                  175           159           146
# TTG_plncpro                                  161           145           132
# TTT_plncpro                                  150           135           122
# UP.PCT_lncfinder                             156           140           127
# all_nonb_gaps_max                             31            27            22
# all_nonb_gaps_mean                           102            91            81
# all_nonb_gaps_median                         103            91            81
# all_nonb_gaps_min                             26            23            18
# apr_gaps_max                                   4             4             2
# apr_gaps_max_pct                               6             6             4
# apr_gaps_mean                                  4             4             2
# apr_gaps_mean_pct                              6             6             4
# apr_gaps_median                                4             4             2
# apr_gaps_median_pct                            6             6             4
# apr_gaps_min                                   5             5             3
# apr_gaps_min_pct                               5             5             3
# apr_hit_count                                  1             1             1
# apr_hit_count_per_kb                           1             1             1
# apr_max_length                                 3             3             1
# apr_max_length_pct                             6             6             4
# apr_mean_length                                3             3             1
# apr_mean_length_pct                            6             6             4
# apr_std_length                                 2             2             1
# apr_std_length_pct                             2             2             1
# apr_total_length                               1             1             1
# apr_total_length_pct                           1             1             1
# apr_unique_length                              1             1             1
# apr_unique_length_pct                          1             1             1
# dr_gaps_max                                   29            26            21
# dr_gaps_max_pct                               45            39            33
# dr_gaps_mean                                 105            93            83
# dr_gaps_mean_pct                              44            38            32
# dr_gaps_median                               105            93            83
# dr_gaps_median_pct                            44            38            32
# dr_gaps_min                                  100            89            79
# dr_gaps_min_pct                              100            89            79
# dr_hit_count                                  24            21            18
# dr_hit_count_per_kb                           11            11             9
# dr_max_length                                  7             7             5
# dr_max_length_pct                             38            33            28
# dr_mean_length                                 7             7             5
# dr_mean_length_pct                            38            33            28
# dr_std_length                                  7             7             5
# dr_std_length_pct                             39            34            28
# dr_total_length                               24            21            18
# dr_total_length_pct                           11            11             9
# dr_unique_length                              24            21            18
# ...
# gq_unique_length                              19            13
# gq_unique_length_pct                          19            13
# ir_gaps_max                                    2             2
# ir_gaps_max_pct                                8             7
# ir_gaps_mean                                  18            12
# ir_gaps_mean_pct                               8             7
# ir_gaps_median                                18            12
# ir_gaps_median_pct                             8             7
# ir_gaps_min                                    2             2
# ir_gaps_min_pct                                2             2
# ir_hit_count                                   2             2
# ir_hit_count_per_kb                            2             2
# ir_max_length                                  2             2
# ir_max_length_pct                              4             3
# ir_mean_length                                18            12
# ir_mean_length_pct                             8             7
# ir_std_length                                 18            12
# ir_std_length_pct                              4             3
# ir_total_length                                2             2
# ir_total_length_pct                            2             2
# ir_unique_length                               2             2
# ir_unique_length_pct                           2             2
# kmerScore_12mer_feelnc                        27            21
# kmerScore_1mer_feelnc                         27            21
# kmerScore_2mer_feelnc                         27            21
# kmerScore_3mer_feelnc                         27            21
# kmerScore_6mer_feelnc                         27            21
# kmerScore_9mer_feelnc                         27            21
# lctr_count                                    10             9
# lctr_count_per_kb                             10             9
# lctr_gaps_max                                 10             9
# lctr_gaps_mean                                10             9
# lctr_gaps_median                              10             9
# lctr_gaps_min                                 10             9
# lctr_low_complexity_count                     10             9
# lctr_low_complexity_count_per_kb              10             9
# lctr_mean_length                              10             9
# lctr_mean_length_pct                          10             9
# lctr_mean_num_fragments                       10             9
# lctr_satellite_count                          18            12
# lctr_satellite_count_per_kb                   18            12
# lctr_simple_repeat_count                      10             9
# lctr_simple_repeat_count_per_kb               10             9
# lctr_sum_num_fragments                        10             9
# lctr_total_length                             10             9
# lctr_total_length_pct                         10             9
# motif_diversity                                2             2
# mr_gaps_max                                    2             2
# mr_gaps_max_pct                                4             3
# mr_gaps_mean                                  21            15
# mr_gaps_mean_pct                               4             3
# mr_gaps_median                                21            15
# mr_gaps_median_pct                             4             3
# mr_gaps_min                                   20            14
# mr_gaps_min_pct                               20            14
# mr_hit_count                                   2             2
# mr_hit_count_per_kb                            2             2
# mr_max_length                                  2             2
# mr_max_length_pct                              4             3
# mr_mean_length                                 2             2
# mr_mean_length_pct                             4             3
# mr_std_length                                  2             2
# mr_std_length_pct                              4             3
# mr_total_length                                2             2
# mr_total_length_pct                            2             2
# mr_unique_length                               2             2
# mr_unique_length_pct                           2             2
# n_motif_types                                  2             2
# orf_coverage_plncpro                          25            19
# pseudo_ancient_count                           7             6
# pseudo_ancient_count_per_kb                    7             6
# pseudo_count                                   7             6
# pseudo_count_per_kb                            7             6
# pseudo_max_divergence                          7             6
# pseudo_max_hit_length                          7             6
# pseudo_max_hit_reference_coverage              7             6
# pseudo_max_num_fragments                       7             6
# pseudo_max_perc_del                            7             6
# pseudo_max_perc_ins                            7             6
# pseudo_max_sw_score                            7             6
# pseudo_mean_divergence                         7             6
# pseudo_mean_hit_length                         7             6
# pseudo_mean_hit_reference_coverage             7             6
# pseudo_mean_num_fragments                      7             6
# pseudo_mean_perc_del                           7             6
# pseudo_mean_perc_ins                           7             6
# pseudo_mean_sw_score                           7             6
# pseudo_min_divergence                          7             6
# pseudo_min_hit_length                          7             6
# pseudo_min_hit_reference_coverage              7             6
# pseudo_min_perc_del                            7             6
# pseudo_min_perc_ins                            7             6
# pseudo_min_sw_score                            7             6
# pseudo_rrna_count                             14            12
# pseudo_rrna_count_per_kb                      14            12
# pseudo_scrna_count                            14            12
# pseudo_scrna_count_per_kb                     14            12
# pseudo_snrna_count                             7             6
# pseudo_snrna_count_per_kb                      7             6
# pseudo_sum_fragmented                         14            12
# pseudo_sum_hit_length                          7             6
# pseudo_sum_num_fragments                       7             6
# pseudo_trna_count                              7             6
# pseudo_trna_count_per_kb                       7             6
# pseudo_unique_classes                          7             6
# pseudo_unique_subfamilies                      7             6
# pseudogene_gaps_max                            7             6
# pseudogene_gaps_mean                           7             6
# pseudogene_gaps_median                         7             6
# pseudogene_gaps_min                            7             6
# str_gaps_max                                   2             2
# str_gaps_max_pct                               4             3
# str_gaps_mean                                 21            15
# str_gaps_mean_pct                              8             7
# str_gaps_median                               21            15
# str_gaps_median_pct                            8             7
# str_gaps_min                                   2             2
# str_gaps_min_pct                               2             2
# str_hit_count                                  2             2
# str_hit_count_per_kb                           2             2
# str_max_length                                 2             2
# str_max_length_pct                             4             3
# str_mean_length                                2             2
# str_mean_length_pct                            8             7
# str_std_length                                 2             2
# str_std_length_pct                             4             3
# str_total_length                               2             2
# str_total_length_pct                           2             2
# str_unique_length                              2             2
# str_unique_length_pct                          2             2
# te_ancient_count                              22            16
# te_ancient_count_per_kb                       22            16
# te_count                                      22            16
# te_count_per_kb                               22            16
# te_dna_count                                  12            11
# te_dna_count_per_kb                           12            11
# te_fragmented_ratio                           12            11
# te_gaps_max                                   22            16
# te_gaps_max_pct                               22            16
# te_gaps_mean                                  22            16
# te_gaps_mean_pct                              22            16
# te_gaps_median                                22            16
# te_gaps_median_pct                            22            16
# te_gaps_min                                   22            16
# te_gaps_min_pct                               22            16
# te_line_count                                 22            16
# te_line_count_per_kb                          22            16
# te_ltr_count                                  22            16
# te_ltr_count_per_kb                           22            16
# te_max_divergence                             22            16
# te_max_hit_length                             22            16
# te_max_hit_length_pct                         22            16
# te_max_hit_reference_coverage                 22            16
# te_max_num_fragments                          22            16
# te_max_perc_del                               22            16
# te_max_perc_ins                               22            16
# te_max_sw_score                               22            16
# te_mean_divergence                            22            16
# te_mean_hit_length                            22            16
# te_mean_hit_length_pct                        22            16
# te_mean_hit_reference_coverage                22            16
# te_mean_num_fragments                         22            16
# te_mean_perc_del                              22            16
# te_mean_perc_ins                              22            16
# te_mean_sw_score                              22            16
# te_min_divergence                             22            16
# te_min_hit_length                             22            16
# te_min_hit_length_pct                         22            16
# te_min_hit_reference_coverage                 22            16
# te_min_perc_del                               22            16
# te_min_perc_ins                               22            16
# te_min_sw_score                               22            16
# te_ple_count                                  15            12
# te_ple_count_per_kb                           15            12
# te_rc_count                                   16            12
# te_rc_count_per_kb                            16            12
# te_retroposon_count                           13            11
# te_retroposon_count_per_kb                    13            11
# te_sine_count                                 22            16
# te_sine_count_per_kb                          22            16
# te_srprna_count                               17            12
# te_srprna_count_per_kb                        17            12
# te_sum_fragmented                             12            11
# te_sum_hit_length                             22            16
# te_sum_hit_length_pct                         22            16
# te_sum_num_fragments                          22            16
# te_unique_classes                             22            16
# te_unique_families                            22            16
# te_unique_subfamilies                         22            16
# te_young_count                                13            11
# te_young_count_per_kb                         13            11
# total_nonb_count                               2             2
# total_nonb_coverage                            2             2
# total_nonb_coverage_pct                        2             2
# tri_gaps_max                                   2             2
# tri_gaps_max_pct                               3             3
# tri_gaps_mean                                  2             2
# tri_gaps_mean_pct                              3             3
# tri_gaps_median                                2             2
# tri_gaps_median_pct                            3             3
# tri_gaps_min                                   3             3
# tri_gaps_min_pct                               3             3
# tri_hit_count                                  2             2
# tri_hit_count_per_kb                           2             2
# tri_max_length                                 2             2
# tri_max_length_pct                             3             3
# tri_mean_length                                2             2
# tri_mean_length_pct                            3             3
# tri_std_length                                 2             2
# tri_std_length_pct                             2             2
# tri_total_length                               2             2
# tri_total_length_pct                           2             2
# tri_unique_length                              2             2
# tri_unique_length_pct                          2             2
# unknown_count                                 11            10
# unknown_count_per_kb                          11            10
# unknown_gaps_max                              11            10
# unknown_gaps_mean                             11            10
# unknown_gaps_median                           11            10
# unknown_gaps_min                              11            10
# unknown_mean_length                           11            10
# unknown_mean_length_pct                       11            10
# unknown_mean_num_fragments                    11            10
# unknown_sum_num_fragments                     11            10
# unknown_total_length                          11            10
# unknown_total_length_pct                      11            10
# z_gaps_max                                     2             2
# z_gaps_max_pct                                 5             4
# z_gaps_mean                                    5             4
# z_gaps_mean_pct                                5             4
# z_gaps_median                                  5             4
# z_gaps_median_pct                              5             4
# z_gaps_min                                     5             4
# z_gaps_min_pct                                 5             4
# z_hit_count                                    2             2
# z_hit_count_per_kb                             2             2
# z_max_length                                   2             2
# z_max_length_pct                               5             4
# z_mean_length                                  2             2
# z_mean_length_pct                              5             4
# z_std_length                                   2             2
# z_std_length_pct                               2             2
# z_total_length                                 2             2
# z_total_length_pct                             2             2
# z_unique_length                                2             2
# z_unique_length_pct                            2             2

# %%
clustered_mannu = combined_df.loc[(combined_df["test"] == 'Mann-Whitney U'), mann_tidy_columns + ["abs_vda"]].sort_values('abs_vda', ascending=False)
clustered_mannu = clustered_mannu.merge(cluster_df["cluster_0.25"], left_index=True, right_index=True, how='left')

# Given the importance of sequence length in our analyses, I want to cherry pick it here
# Let's do it in a quick and dirty way: remove other features in its group
length_cluster = clustered_mannu[clustered_mannu.index == 'RNA_size_feelnc']['cluster_0.25'].values
if length_cluster.size > 0:
    print(f"RNA_size_feelnc is in cluster {length_cluster}")

# Remove all features in the same cluster except RNA_size_feelnc
if length_cluster is not None:
    features_to_remove = clustered_mannu[clustered_mannu['cluster_0.25'] == length_cluster[0]].index.difference(['RNA_size_feelnc'])
    print(f"Removing features in the same cluster as RNA_size_feelnc: {features_to_remove.tolist()}")
    clustered_mannu = clustered_mannu.drop(index=features_to_remove)
else:
    print("RNA_size_feelnc not found in any cluster, no features removed")

# Re-sort by VDA effect size
clustered_mannu = clustered_mannu.sort_values('abs_vda', ascending=False).groupby('cluster_0.25').head(1)
clustered_mannu
# Out:
# RNA_size_feelnc is in cluster [60.]
# Removing features in the same cluster as RNA_size_feelnc: ['Dot_lnc.dist_lncfinder', 'Dot_pct.dist_lncfinder', 'MFE_lncfinder', 'ORF_T1_length_lncDC', 'SS.lnc.dist_lncfinder', 'SS.pct.dist_lncfinder', 'Signal.Max_lncfinder', 'Signal.Min_lncfinder', 'Signal.Q1_lncfinder', 'Signal.Q2_lncfinder']
#                                    adjusted_p_value   rank_perc  \
# ORF_T0_MW_lncDC                        0.000000e+00  100.000000
# Fickett_l_cpat                         0.000000e+00   98.614319
# Hexamer_l_cpat                         0.000000e+00   98.383372
# Signal.Peak_lncfinder                  0.000000e+00   98.152425
# Hexamer_score_ORF_T0_lncDC             0.000000e+00   97.690531
# kmerScore_12mer_feelnc                 0.000000e+00   96.766744
# SS.Dist.Ratio_lncfinder                0.000000e+00   96.535797
# ORF_T0_coverage_lncDC                  0.000000e+00   96.304850
# ORF.Max.Cov_lncfinder                  0.000000e+00   95.958430
# ORF_T2_length_lncDC                    0.000000e+00   93.533487
# RNA_size_feelnc                        0.000000e+00   92.263279
# SS_score_k5_lncDC                      0.000000e+00   91.685912
# Hexamer_score_ORF_T2_lncDC             0.000000e+00   91.454965
# ir_gaps_mean_pct                       0.000000e+00   90.993072
# str_mean_length_pct                    0.000000e+00   90.300231
# te_count_per_kb                        0.000000e+00   90.069284
# global_rm_total_length_pct             0.000000e+00   88.452656
# CGA_plncpro                            0.000000e+00   87.759815
# TCG_plncpro                            0.000000e+00   87.297921
# mr_mean_length_pct                     0.000000e+00   87.066975
# dr_mean_length_pct                     0.000000e+00   85.681293
# global_gaps_max                        0.000000e+00   85.450346
# mr_gaps_mean_pct                       0.000000e+00   85.219400
# Fickett_score_lncDC                    0.000000e+00   84.988453
# str_max_length_pct                     0.000000e+00   84.295612
# gq_total_length                        0.000000e+00   83.833718
# te_ancient_count_per_kb                0.000000e+00   83.140878
# CGT_plncpro                            0.000000e+00   82.909931
# kmerScore_2mer_feelnc                  0.000000e+00   82.678984
# dr_gaps_mean_pct                       0.000000e+00   82.448037
# str_gaps_max_pct                       0.000000e+00   81.986143
# ir_max_length_pct                      0.000000e+00   81.755196
# lctr_gaps_max                          0.000000e+00   81.524249
# ACG_plncpro                            0.000000e+00   81.293303
# TCT_plncpro                           3.238980e-292   80.138568
# ORF_T0_PI_lncDC                       1.473836e-285   79.907621
# te_unique_families                     0.000000e+00   79.445727
# RCB_T1_lncDC                          3.773864e-270   78.983834
# Hexamer_score_ORF_T3_lncDC            1.262389e-269   78.752887
# apr_mean_length_pct                   2.065717e-262   77.829099
# te_max_divergence                     2.573159e-281   77.367206
# te_ltr_count_per_kb                    0.000000e+00   76.443418
# gq_max_length                         3.094455e-238   75.981524
# te_sum_hit_length                     6.095393e-264   75.750577
# ORF_T0_aromaticity_lncDC              3.405461e-234   75.288684
# gq_mean_length_pct                    8.266539e-229   74.826790
# total_nonb_count                      2.867041e-217   73.672055
# SS_score_k1_lncDC                     1.331478e-212   72.748268
# global_gaps_median                    3.585454e-201   72.055427
# TCA_plncpro                           3.381125e-200   71.824480
# ACA_plncpro                           6.187778e-198   71.362587
# te_max_perc_del                       1.292029e-223   70.669746
# tri_mean_length_pct                   1.671252e-190   70.438799
# CAA_plncpro                           1.164127e-180   69.284065
# ORF_T3_MW_lncDC                       6.636978e-175   68.591224
# te_max_perc_ins                       1.103594e-211   68.360277
# ACT_plncpro                           2.801953e-167   67.436490
# z_mean_length_pct                     2.114175e-163   66.281755
# CAT_plncpro                           8.773998e-157   65.127021
# z_hit_count                           6.429993e-153   64.434180
# CTA_plncpro                           6.510131e-144   63.279446
# te_max_hit_reference_coverage         3.058337e-178   62.124711
# ir_max_length                         8.654979e-134   61.893764
# tri_hit_count                         2.625471e-132   61.431871
# apr_gaps_mean                         2.560492e-131   61.200924
# z_gaps_max                            3.487415e-122   59.584296
# AAC_plncpro                           2.146147e-121   59.122402
# ir_gaps_min_pct                       4.175449e-124   58.891455
# TTC_plncpro                           2.219642e-115   58.429561
# te_line_count_per_kb                  2.795050e-215   58.198614
# gq_gaps_median_pct                    1.417661e-105   57.736721
# gq_gaps_mean_pct                      1.499966e-104   57.274827
# ir_gaps_max                           2.387047e-104   57.043880
# GTG_plncpro                           2.565528e-102   56.812933
# z_gaps_mean                            5.527337e-98   56.351039
# tri_gaps_max                           4.858292e-93   56.120092
# CTT_plncpro                            2.177143e-92   55.889145
# AGA_plncpro                            2.354445e-92   55.658199
# TAA_plncpro                            3.076840e-91   55.196305
# global_gaps_min                        4.754294e-92   54.503464
# all_nonb_gaps_min                      4.801052e-88   54.272517
# gq_gaps_max                            1.725555e-87   54.041570
# all_nonb_gaps_mean                     9.164266e-87   53.810624
# gq_gaps_min_pct                        1.265861e-85   53.348730
# mr_max_length                          1.421876e-84   53.117783
# mr_gaps_max                            2.525587e-84   52.886836
# te_sine_count_per_kb                  1.011831e-112   52.655889
# dr_max_length                          3.876540e-81   51.963048
# UP.PCT_lncfinder                       6.361749e-80   51.501155
# ATC_plncpro                            1.427595e-79   51.039261
# GGG_plncpro                            1.239184e-75   50.346420
# z_max_length                           3.475967e-75   50.115473
# te_gaps_median_pct                     8.882297e-84   49.884527
# gq_mean_length                         2.019261e-73   49.653580
# TGA_plncpro                            2.771490e-69   49.191686
# tri_max_length                         1.557057e-68   48.729792
# TGG_plncpro                            4.279691e-67   48.498845
# ATA_plncpro                            9.141814e-67   48.036952
# AGC_plncpro                            5.693477e-66   47.806005
# mr_gaps_min_pct                        1.410568e-65   47.575058
# dr_std_length_pct                      1.616394e-65   47.344111
# TAG_plncpro                            1.229519e-64   47.113164
# GGT_plncpro                            2.108182e-64   46.882217
# GCT_plncpro                            2.310339e-64   46.651270
# tri_std_length                         4.460542e-64   46.420323
# gq_total_length_pct                    2.013550e-62   46.189376
# AAG_plncpro                            3.080293e-61   45.727483
# apr_hit_count                          1.067094e-60   45.034642
# str_max_length                         8.713319e-59   44.341801
# str_gaps_min_pct                       6.777797e-69   44.110855
# motif_diversity                        1.563277e-51   43.648961
# ir_std_length                          9.546201e-51   42.494226
# TGC_plncpro                            4.835872e-50   42.263279
# CCC_plncpro                            1.099265e-46   41.801386
# te_min_perc_del                        2.760247e-69   41.339492
# dr_gaps_min_pct                        1.464526e-44   40.877598
# CAG_plncpro                            1.170181e-40   40.415704
# apr_max_length                         1.433363e-39   39.491917
# GGA_plncpro                            1.189468e-38   39.260970
# apr_std_length                         2.404090e-38   38.799076
# ORF_T3_coverage_lncDC                  1.907816e-36   38.568129
# GCA_plncpro                            6.453749e-35   37.413395
# ATT_plncpro                            8.181436e-33   36.720554
# GAC_plncpro                            1.718710e-26   35.796767
# ACC_plncpro                            2.452904e-24   35.334873
# GTC_plncpro                            6.480309e-24   34.872979
# lctr_low_complexity_count              2.372213e-50   34.642032
# ATG_plncpro                            4.877266e-23   34.411085
# te_fragmented_ratio                    4.114677e-93   34.180139
# dr_gaps_mean                           2.421376e-22   33.949192
# CAC_plncpro                            6.935444e-21   33.256351
# CTC_plncpro                            6.407014e-20   32.101617
# gq_std_length_pct                      2.119633e-18   31.639723
# apr_gaps_min_pct                       1.203641e-17   31.177829
# Seq.Dist.Ratio_lncfinder               5.012847e-15   30.484988
# mr_gaps_mean                           1.449670e-14   30.023095
# te_gaps_min_pct                        8.897491e-18   29.792148
# ORF_T1_instability_lncDC               7.943894e-14   29.561201
# str_gaps_median                        7.847945e-12   28.868360
# GAG_plncpro                            5.176297e-11   28.637413
# te_dna_count_per_kb                    1.031056e-23   28.175520
# te_min_perc_ins                        2.988348e-19   27.944573
# tri_gaps_min_pct                       1.067772e-10   27.713626
# te_min_hit_reference_coverage          3.301479e-25   27.251732
# ORF_T0_instability_lncDC               2.433511e-08   26.327945
# z_gaps_min                             5.092145e-07   25.173210
# TTG_plncpro                            2.468528e-06   24.711316
# total_nonb_coverage_pct                2.764797e-06   24.480370
# mr_mean_length                         4.568129e-06   24.249423
# CTG_plncpro                            5.237903e-06   24.018476
# TGT_plncpro                            1.260352e-02   21.478060
# ir_gaps_mean                           2.041629e-02   21.016166
# str_mean_length                        2.682611e-02   20.554273
# GTT_plncpro                            6.570123e-02   20.092379
# TCC_plncpro                            7.683792e-02   19.630485
# CCT_plncpro                            1.345382e-01   17.782910
# lctr_satellite_count_per_kb            1.212845e-23   17.321016
# CCA_plncpro                            2.251676e-01   16.859122
# AGG_plncpro                            2.548547e-01   16.397229
# AGT_plncpro                            2.679376e-01   16.166282
# te_young_count_per_kb                  3.914495e-03   15.935335
# GAT_plncpro                            3.000182e-01   15.704388
# pseudo_count_per_kb                    2.502668e-02   14.087760
# GTA_plncpro                            8.428358e-01    9.237875
# te_srprna_count_per_kb                 4.028128e-03    9.006928
# te_retroposon_count_per_kb             2.306671e-01    8.545035
# pseudo_snrna_count_per_kb              7.795321e-02    7.852194
# TAC_plncpro                            8.912763e-01    7.390300
# unknown_count_per_kb                   5.152775e-01    7.159353
# pseudo_trna_count_per_kb               1.386969e-01    4.618938
# pseudo_ancient_count_per_kb            5.138951e-02    4.157044
# pseudo_max_hit_reference_coverage      5.152775e-01    3.695150
# pseudo_mean_perc_ins                   3.869502e-01    3.002309
# pseudo_min_perc_del                    6.414064e-01    2.078522
# te_rc_count_per_kb                     4.191538e-01    1.616628
# pseudo_scrna_count_per_kb              7.898087e-01    0.808314
# pseudo_rrna_count_per_kb               7.898087e-01    0.808314
#
#                                              test       vda  \
# ORF_T0_MW_lncDC                    Mann-Whitney U  0.998757
# Fickett_l_cpat                     Mann-Whitney U  0.995709
# Hexamer_l_cpat                     Mann-Whitney U  0.995121
# Signal.Peak_lncfinder              Mann-Whitney U  0.994617
# Hexamer_score_ORF_T0_lncDC         Mann-Whitney U  0.993768
# kmerScore_12mer_feelnc             Mann-Whitney U  0.984166
# SS.Dist.Ratio_lncfinder            Mann-Whitney U  0.021514
# ORF_T0_coverage_lncDC              Mann-Whitney U  0.978271
# ORF.Max.Cov_lncfinder              Mann-Whitney U  0.977583
# ORF_T2_length_lncDC                Mann-Whitney U  0.968074
# RNA_size_feelnc                    Mann-Whitney U  0.956021
# SS_score_k5_lncDC                  Mann-Whitney U  0.942354
# Hexamer_score_ORF_T2_lncDC         Mann-Whitney U  0.940513
# ir_gaps_mean_pct                   Mann-Whitney U  0.067343
# str_mean_length_pct                Mann-Whitney U  0.084949
# te_count_per_kb                    Mann-Whitney U  0.100807
# global_rm_total_length_pct         Mann-Whitney U  0.129253
# CGA_plncpro                        Mann-Whitney U  0.866688
# TCG_plncpro                        Mann-Whitney U  0.858140
# mr_mean_length_pct                 Mann-Whitney U  0.145321
# dr_mean_length_pct                 Mann-Whitney U  0.163738
# global_gaps_max                    Mann-Whitney U  0.835603
# mr_gaps_mean_pct                   Mann-Whitney U  0.164668
# Fickett_score_lncDC                Mann-Whitney U  0.831488
# str_max_length_pct                 Mann-Whitney U  0.181701
# gq_total_length                    Mann-Whitney U  0.809942
# te_ancient_count_per_kb            Mann-Whitney U  0.202811
# CGT_plncpro                        Mann-Whitney U  0.795870
# kmerScore_2mer_feelnc              Mann-Whitney U  0.795686
# dr_gaps_mean_pct                   Mann-Whitney U  0.204501
# str_gaps_max_pct                   Mann-Whitney U  0.206986
# ir_max_length_pct                  Mann-Whitney U  0.207833
# lctr_gaps_max                      Mann-Whitney U  0.791491
# ACG_plncpro                        Mann-Whitney U  0.789625
# TCT_plncpro                        Mann-Whitney U  0.223184
# ORF_T0_PI_lncDC                    Mann-Whitney U  0.226376
# te_unique_families                 Mann-Whitney U  0.230820
# RCB_T1_lncDC                       Mann-Whitney U  0.233909
# Hexamer_score_ORF_T3_lncDC         Mann-Whitney U  0.765829
# apr_mean_length_pct                Mann-Whitney U  0.238329
# te_max_divergence                  Mann-Whitney U  0.242873
# te_ltr_count_per_kb                Mann-Whitney U  0.244582
# gq_max_length                      Mann-Whitney U  0.749554
# te_sum_hit_length                  Mann-Whitney U  0.250999
# ORF_T0_aromaticity_lncDC           Mann-Whitney U  0.252392
# gq_mean_length_pct                 Mann-Whitney U  0.255287
# total_nonb_count                   Mann-Whitney U  0.738424
# SS_score_k1_lncDC                  Mann-Whitney U  0.735823
# global_gaps_median                 Mann-Whitney U  0.728957
# TCA_plncpro                        Mann-Whitney U  0.271225
# ACA_plncpro                        Mann-Whitney U  0.272534
# te_max_perc_del                    Mann-Whitney U  0.276402
# tri_mean_length_pct                Mann-Whitney U  0.277083
# CAA_plncpro                        Mann-Whitney U  0.282785
# ORF_T3_MW_lncDC                    Mann-Whitney U  0.713687
# te_max_perc_ins                    Mann-Whitney U  0.286617
# ACT_plncpro                        Mann-Whitney U  0.291068
# z_mean_length_pct                  Mann-Whitney U  0.293624
# CAT_plncpro                        Mann-Whitney U  0.297815
# z_hit_count                        Mann-Whitney U  0.699415
# CTA_plncpro                        Mann-Whitney U  0.306391
# te_max_hit_reference_coverage      Mann-Whitney U  0.312455
# ir_max_length                      Mann-Whitney U  0.686473
# tri_hit_count                      Mann-Whitney U  0.685246
# apr_gaps_mean                      Mann-Whitney U  0.684444
# z_gaps_max                         Mann-Whitney U  0.678115
# AAC_plncpro                        Mann-Whitney U  0.322395
# ir_gaps_min_pct                    Mann-Whitney U  0.322676
# TTC_plncpro                        Mann-Whitney U  0.326916
# te_line_count_per_kb               Mann-Whitney U  0.330965
# gq_gaps_median_pct                 Mann-Whitney U  0.334553
# gq_gaps_mean_pct                   Mann-Whitney U  0.335373
# ir_gaps_max                        Mann-Whitney U  0.664469
# GTG_plncpro                        Mann-Whitney U  0.662834
# z_gaps_mean                        Mann-Whitney U  0.659224
# tri_gaps_max                       Mann-Whitney U  0.655013
# CTT_plncpro                        Mann-Whitney U  0.345405
# AGA_plncpro                        Mann-Whitney U  0.345436
# TAA_plncpro                        Mann-Whitney U  0.346396
# global_gaps_min                    Mann-Whitney U  0.651292
# all_nonb_gaps_min                  Mann-Whitney U  0.349163
# gq_gaps_max                        Mann-Whitney U  0.650345
# all_nonb_gaps_mean                 Mann-Whitney U  0.350286
# gq_gaps_min_pct                    Mann-Whitney U  0.351410
# mr_max_length                      Mann-Whitney U  0.647683
# mr_gaps_max                        Mann-Whitney U  0.647546
# te_sine_count_per_kb               Mann-Whitney U  0.352807
# dr_max_length                      Mann-Whitney U  0.644658
# UP.PCT_lncfinder                   Mann-Whitney U  0.643557
# ATC_plncpro                        Mann-Whitney U  0.356769
# GGG_plncpro                        Mann-Whitney U  0.639561
# z_max_length                       Mann-Whitney U  0.639038
# te_gaps_median_pct                 Mann-Whitney U  0.361084
# gq_mean_length                     Mann-Whitney U  0.637450
# TGA_plncpro                        Mann-Whitney U  0.366563
# tri_max_length                     Mann-Whitney U  0.632516
# TGG_plncpro                        Mann-Whitney U  0.631256
# ATA_plncpro                        Mann-Whitney U  0.369076
# AGC_plncpro                        Mann-Whitney U  0.630122
# mr_gaps_min_pct                    Mann-Whitney U  0.370352
# dr_std_length_pct                  Mann-Whitney U  0.370372
# TAG_plncpro                        Mann-Whitney U  0.371241
# GGT_plncpro                        Mann-Whitney U  0.628518
# GCT_plncpro                        Mann-Whitney U  0.628476
# tri_std_length                     Mann-Whitney U  0.627529
# gq_total_length_pct                Mann-Whitney U  0.626466
# AAG_plncpro                        Mann-Whitney U  0.374769
# apr_hit_count                      Mann-Whitney U  0.624322
# str_max_length                     Mann-Whitney U  0.622597
# str_gaps_min_pct                   Mann-Whitney U  0.379387
# motif_diversity                    Mann-Whitney U  0.614581
# ir_std_length                      Mann-Whitney U  0.613669
# TGC_plncpro                        Mann-Whitney U  0.612845
# CCC_plncpro                        Mann-Whitney U  0.608862
# te_min_perc_del                    Mann-Whitney U  0.391355
# dr_gaps_min_pct                    Mann-Whitney U  0.393961
# CAG_plncpro                        Mann-Whitney U  0.601327
# apr_max_length                     Mann-Whitney U  0.599523
# GGA_plncpro                        Mann-Whitney U  0.598687
# apr_std_length                     Mann-Whitney U  0.597206
# ORF_T3_coverage_lncDC              Mann-Whitney U  0.595703
# GCA_plncpro                        Mann-Whitney U  0.593574
# ATT_plncpro                        Mann-Whitney U  0.409423
# GAC_plncpro                        Mann-Whitney U  0.580916
# ACC_plncpro                        Mann-Whitney U  0.577347
# GTC_plncpro                        Mann-Whitney U  0.576629
# lctr_low_complexity_count          Mann-Whitney U  0.575946
# ATG_plncpro                        Mann-Whitney U  0.424890
# te_fragmented_ratio                Mann-Whitney U  0.425079
# dr_gaps_mean                       Mann-Whitney U  0.573881
# CAC_plncpro                        Mann-Whitney U  0.428740
# CTC_plncpro                        Mann-Whitney U  0.430540
# gq_std_length_pct                  Mann-Whitney U  0.433485
# apr_gaps_min_pct                   Mann-Whitney U  0.435112
# Seq.Dist.Ratio_lncfinder           Mann-Whitney U  0.440436
# mr_gaps_mean                       Mann-Whitney U  0.558544
# te_gaps_min_pct                    Mann-Whitney U  0.442308
# ORF_T1_instability_lncDC           Mann-Whitney U  0.556880
# str_gaps_median                    Mann-Whitney U  0.447870
# GAG_plncpro                        Mann-Whitney U  0.550052
# te_dna_count_per_kb                Mann-Whitney U  0.450302
# te_min_perc_ins                    Mann-Whitney U  0.450453
# tri_gaps_min_pct                   Mann-Whitney U  0.450838
# te_min_hit_reference_coverage      Mann-Whitney U  0.452021
# ORF_T0_instability_lncDC           Mann-Whitney U  0.457395
# z_gaps_min                         Mann-Whitney U  0.537471
# TTG_plncpro                        Mann-Whitney U  0.463924
# total_nonb_coverage_pct            Mann-Whitney U  0.535898
# mr_mean_length                     Mann-Whitney U  0.535116
# CTG_plncpro                        Mann-Whitney U  0.534897
# TGT_plncpro                        Mann-Whitney U  0.480513
# ir_gaps_mean                       Mann-Whitney U  0.518166
# str_mean_length                    Mann-Whitney U  0.517251
# GTT_plncpro                        Mann-Whitney U  0.514428
# TCC_plncpro                        Mann-Whitney U  0.513886
# CCT_plncpro                        Mann-Whitney U  0.511775
# lctr_satellite_count_per_kb        Mann-Whitney U  0.490198
# CCA_plncpro                        Mann-Whitney U  0.509647
# AGG_plncpro                        Mann-Whitney U  0.490941
# AGT_plncpro                        Mann-Whitney U  0.491179
# te_young_count_per_kb              Mann-Whitney U  0.491565
# GAT_plncpro                        Mann-Whitney U  0.491726
# pseudo_count_per_kb                Mann-Whitney U  0.497927
# GTA_plncpro                        Mann-Whitney U  0.498410
# te_srprna_count_per_kb             Mann-Whitney U  0.498492
# te_retroposon_count_per_kb         Mann-Whitney U  0.498573
# pseudo_snrna_count_per_kb          Mann-Whitney U  0.498782
# TAC_plncpro                        Mann-Whitney U  0.501091
# unknown_count_per_kb               Mann-Whitney U  0.498989
# pseudo_trna_count_per_kb           Mann-Whitney U  0.499312
# pseudo_ancient_count_per_kb        Mann-Whitney U  0.499339
# pseudo_max_hit_reference_coverage  Mann-Whitney U  0.499524
# pseudo_mean_perc_ins               Mann-Whitney U  0.499605
# pseudo_min_perc_del                Mann-Whitney U  0.499763
# te_rc_count_per_kb                 Mann-Whitney U  0.499815
# pseudo_scrna_count_per_kb          Mann-Whitney U  0.499921
# pseudo_rrna_count_per_kb           Mann-Whitney U  0.499921
#
#                                                                                  interpretation  \
# ORF_T0_MW_lncDC                               0.999 probability of being higher in lncRNA group
# Fickett_l_cpat                                0.996 probability of being higher in lncRNA group
# Hexamer_l_cpat                                0.995 probability of being higher in lncRNA group
# Signal.Peak_lncfinder                         0.995 probability of being higher in lncRNA group
# Hexamer_score_ORF_T0_lncDC                    0.994 probability of being higher in lncRNA group
# kmerScore_12mer_feelnc                        0.984 probability of being higher in lncRNA group
# SS.Dist.Ratio_lncfinder                       0.022 probability of being higher in lncRNA group
# ORF_T0_coverage_lncDC                         0.978 probability of being higher in lncRNA group
# ORF.Max.Cov_lncfinder                         0.978 probability of being higher in lncRNA group
# ORF_T2_length_lncDC                           0.968 probability of being higher in lncRNA group
# RNA_size_feelnc                               0.956 probability of being higher in lncRNA group
# SS_score_k5_lncDC                             0.942 probability of being higher in lncRNA group
# Hexamer_score_ORF_T2_lncDC                    0.941 probability of being higher in lncRNA group
# ir_gaps_mean_pct                              0.067 probability of being higher in lncRNA group
# str_mean_length_pct                           0.085 probability of being higher in lncRNA group
# te_count_per_kb                               0.101 probability of being higher in lncRNA group
# global_rm_total_length_pct                    0.129 probability of being higher in lncRNA group
# CGA_plncpro                                   0.867 probability of being higher in lncRNA group
# TCG_plncpro                                   0.858 probability of being higher in lncRNA group
# mr_mean_length_pct                            0.145 probability of being higher in lncRNA group
# dr_mean_length_pct                            0.164 probability of being higher in lncRNA group
# global_gaps_max                               0.836 probability of being higher in lncRNA group
# mr_gaps_mean_pct                              0.165 probability of being higher in lncRNA group
# Fickett_score_lncDC                           0.831 probability of being higher in lncRNA group
# str_max_length_pct                            0.182 probability of being higher in lncRNA group
# gq_total_length                               0.810 probability of being higher in lncRNA group
# te_ancient_count_per_kb                       0.203 probability of being higher in lncRNA group
# CGT_plncpro                                   0.796 probability of being higher in lncRNA group
# kmerScore_2mer_feelnc                         0.796 probability of being higher in lncRNA group
# dr_gaps_mean_pct                              0.205 probability of being higher in lncRNA group
# str_gaps_max_pct                              0.207 probability of being higher in lncRNA group
# ir_max_length_pct                             0.208 probability of being higher in lncRNA group
# lctr_gaps_max                                 0.791 probability of being higher in lncRNA group
# ACG_plncpro                                   0.790 probability of being higher in lncRNA group
# TCT_plncpro                                   0.223 probability of being higher in lncRNA group
# ORF_T0_PI_lncDC                               0.226 probability of being higher in lncRNA group
# te_unique_families                            0.231 probability of being higher in lncRNA group
# RCB_T1_lncDC                                  0.234 probability of being higher in lncRNA group
# Hexamer_score_ORF_T3_lncDC                    0.766 probability of being higher in lncRNA group
# apr_mean_length_pct                           0.238 probability of being higher in lncRNA group
# te_max_divergence                             0.243 probability of being higher in lncRNA group
# te_ltr_count_per_kb                           0.245 probability of being higher in lncRNA group
# gq_max_length                                 0.750 probability of being higher in lncRNA group
# te_sum_hit_length                             0.251 probability of being higher in lncRNA group
# ORF_T0_aromaticity_lncDC                      0.252 probability of being higher in lncRNA group
# gq_mean_length_pct                            0.255 probability of being higher in lncRNA group
# total_nonb_count                              0.738 probability of being higher in lncRNA group
# SS_score_k1_lncDC                             0.736 probability of being higher in lncRNA group
# global_gaps_median                            0.729 probability of being higher in lncRNA group
# TCA_plncpro                                   0.271 probability of being higher in lncRNA group
# ACA_plncpro                                   0.273 probability of being higher in lncRNA group
# te_max_perc_del                               0.276 probability of being higher in lncRNA group
# tri_mean_length_pct                           0.277 probability of being higher in lncRNA group
# CAA_plncpro                                   0.283 probability of being higher in lncRNA group
# ORF_T3_MW_lncDC                               0.714 probability of being higher in lncRNA group
# te_max_perc_ins                               0.287 probability of being higher in lncRNA group
# ACT_plncpro                                   0.291 probability of being higher in lncRNA group
# z_mean_length_pct                             0.294 probability of being higher in lncRNA group
# CAT_plncpro                                   0.298 probability of being higher in lncRNA group
# z_hit_count                                   0.699 probability of being higher in lncRNA group
# CTA_plncpro                                   0.306 probability of being higher in lncRNA group
# te_max_hit_reference_coverage                 0.312 probability of being higher in lncRNA group
# ir_max_length                                 0.686 probability of being higher in lncRNA group
# tri_hit_count                                 0.685 probability of being higher in lncRNA group
# apr_gaps_mean                                 0.684 probability of being higher in lncRNA group
# z_gaps_max                                    0.678 probability of being higher in lncRNA group
# AAC_plncpro                                   0.322 probability of being higher in lncRNA group
# ir_gaps_min_pct                               0.323 probability of being higher in lncRNA group
# TTC_plncpro                                   0.327 probability of being higher in lncRNA group
# te_line_count_per_kb                          0.331 probability of being higher in lncRNA group
# gq_gaps_median_pct                            0.335 probability of being higher in lncRNA group
# gq_gaps_mean_pct                              0.335 probability of being higher in lncRNA group
# ir_gaps_max                                   0.664 probability of being higher in lncRNA group
# GTG_plncpro                                   0.663 probability of being higher in lncRNA group
# z_gaps_mean                                   0.659 probability of being higher in lncRNA group
# tri_gaps_max                                  0.655 probability of being higher in lncRNA group
# CTT_plncpro                                   0.345 probability of being higher in lncRNA group
# AGA_plncpro                                   0.345 probability of being higher in lncRNA group
# TAA_plncpro                                   0.346 probability of being higher in lncRNA group
# global_gaps_min                               0.651 probability of being higher in lncRNA group
# all_nonb_gaps_min                             0.349 probability of being higher in lncRNA group
# gq_gaps_max                                   0.650 probability of being higher in lncRNA group
# all_nonb_gaps_mean                            0.350 probability of being higher in lncRNA group
# gq_gaps_min_pct                               0.351 probability of being higher in lncRNA group
# mr_max_length                                 0.648 probability of being higher in lncRNA group
# mr_gaps_max                                   0.648 probability of being higher in lncRNA group
# te_sine_count_per_kb                          0.353 probability of being higher in lncRNA group
# dr_max_length                                 0.645 probability of being higher in lncRNA group
# UP.PCT_lncfinder                              0.644 probability of being higher in lncRNA group
# ATC_plncpro                                   0.357 probability of being higher in lncRNA group
# GGG_plncpro                                   0.640 probability of being higher in lncRNA group
# z_max_length                                  0.639 probability of being higher in lncRNA group
# te_gaps_median_pct                            0.361 probability of being higher in lncRNA group
# gq_mean_length                                0.637 probability of being higher in lncRNA group
# TGA_plncpro                                   0.367 probability of being higher in lncRNA group
# tri_max_length                                0.633 probability of being higher in lncRNA group
# TGG_plncpro                                   0.631 probability of being higher in lncRNA group
# ATA_plncpro                                   0.369 probability of being higher in lncRNA group
# AGC_plncpro                                   0.630 probability of being higher in lncRNA group
# mr_gaps_min_pct                               0.370 probability of being higher in lncRNA group
# dr_std_length_pct                             0.370 probability of being higher in lncRNA group
# TAG_plncpro                                   0.371 probability of being higher in lncRNA group
# GGT_plncpro                                   0.629 probability of being higher in lncRNA group
# GCT_plncpro                                   0.628 probability of being higher in lncRNA group
# tri_std_length                                0.628 probability of being higher in lncRNA group
# gq_total_length_pct                           0.626 probability of being higher in lncRNA group
# AAG_plncpro                                   0.375 probability of being higher in lncRNA group
# apr_hit_count                                 0.624 probability of being higher in lncRNA group
# str_max_length                                0.623 probability of being higher in lncRNA group
# str_gaps_min_pct                              0.379 probability of being higher in lncRNA group
# motif_diversity                               0.615 probability of being higher in lncRNA group
# ir_std_length                                 0.614 probability of being higher in lncRNA group
# TGC_plncpro                                   0.613 probability of being higher in lncRNA group
# CCC_plncpro                                   0.609 probability of being higher in lncRNA group
# te_min_perc_del                               0.391 probability of being higher in lncRNA group
# dr_gaps_min_pct                               0.394 probability of being higher in lncRNA group
# CAG_plncpro                                   0.601 probability of being higher in lncRNA group
# apr_max_length                                0.600 probability of being higher in lncRNA group
# GGA_plncpro                                   0.599 probability of being higher in lncRNA group
# apr_std_length                                0.597 probability of being higher in lncRNA group
# ORF_T3_coverage_lncDC                         0.596 probability of being higher in lncRNA group
# GCA_plncpro                                   0.594 probability of being higher in lncRNA group
# ATT_plncpro                                   0.409 probability of being higher in lncRNA group
# GAC_plncpro                                   0.581 probability of being higher in lncRNA group
# ACC_plncpro                                   0.577 probability of being higher in lncRNA group
# GTC_plncpro                                   0.577 probability of being higher in lncRNA group
# lctr_low_complexity_count                     0.576 probability of being higher in lncRNA group
# ATG_plncpro                                   0.425 probability of being higher in lncRNA group
# te_fragmented_ratio                           0.425 probability of being higher in lncRNA group
# dr_gaps_mean                                  0.574 probability of being higher in lncRNA group
# CAC_plncpro                                   0.429 probability of being higher in lncRNA group
# CTC_plncpro                                   0.431 probability of being higher in lncRNA group
# gq_std_length_pct                             0.433 probability of being higher in lncRNA group
# apr_gaps_min_pct                              0.435 probability of being higher in lncRNA group
# Seq.Dist.Ratio_lncfinder                      0.440 probability of being higher in lncRNA group
# mr_gaps_mean                                  0.559 probability of being higher in lncRNA group
# te_gaps_min_pct                               0.442 probability of being higher in lncRNA group
# ORF_T1_instability_lncDC                      0.557 probability of being higher in lncRNA group
# str_gaps_median                               0.448 probability of being higher in lncRNA group
# GAG_plncpro                                   0.550 probability of being higher in lncRNA group
# te_dna_count_per_kb                           0.450 probability of being higher in lncRNA group
# te_min_perc_ins                               0.450 probability of being higher in lncRNA group
# tri_gaps_min_pct                              0.451 probability of being higher in lncRNA group
# te_min_hit_reference_coverage                 0.452 probability of being higher in lncRNA group
# ORF_T0_instability_lncDC                      0.457 probability of being higher in lncRNA group
# z_gaps_min                                    0.537 probability of being higher in lncRNA group
# TTG_plncpro                                   0.464 probability of being higher in lncRNA group
# total_nonb_coverage_pct                       0.536 probability of being higher in lncRNA group
# mr_mean_length                                0.535 probability of being higher in lncRNA group
# CTG_plncpro                                   0.535 probability of being higher in lncRNA group
# TGT_plncpro                        Result is not statistically significant after FDR correction
# ir_gaps_mean                       Result is not statistically significant after FDR correction
# str_mean_length                    Result is not statistically significant after FDR correction
# GTT_plncpro                        Result is not statistically significant after FDR correction
# TCC_plncpro                        Result is not statistically significant after FDR correction
# CCT_plncpro                        Result is not statistically significant after FDR correction
# lctr_satellite_count_per_kb                   0.490 probability of being higher in lncRNA group
# CCA_plncpro                        Result is not statistically significant after FDR correction
# AGG_plncpro                        Result is not statistically significant after FDR correction
# AGT_plncpro                        Result is not statistically significant after FDR correction
# te_young_count_per_kb                         0.492 probability of being higher in lncRNA group
# GAT_plncpro                        Result is not statistically significant after FDR correction
# pseudo_count_per_kb                Result is not statistically significant after FDR correction
# GTA_plncpro                        Result is not statistically significant after FDR correction
# te_srprna_count_per_kb                        0.498 probability of being higher in lncRNA group
# te_retroposon_count_per_kb         Result is not statistically significant after FDR correction
# pseudo_snrna_count_per_kb          Result is not statistically significant after FDR correction
# TAC_plncpro                        Result is not statistically significant after FDR correction
# unknown_count_per_kb               Result is not statistically significant after FDR correction
# pseudo_trna_count_per_kb           Result is not statistically significant after FDR correction
# pseudo_ancient_count_per_kb        Result is not statistically significant after FDR correction
# pseudo_max_hit_reference_coverage  Result is not statistically significant after FDR correction
# pseudo_mean_perc_ins               Result is not statistically significant after FDR correction
# pseudo_min_perc_del                Result is not statistically significant after FDR correction
# te_rc_count_per_kb                 Result is not statistically significant after FDR correction
# pseudo_scrna_count_per_kb          Result is not statistically significant after FDR correction
# pseudo_rrna_count_per_kb           Result is not statistically significant after FDR correction
#
#                                    significant   abs_vda  cluster_0.25
# ORF_T0_MW_lncDC                           True  0.498757          56.0
# Fickett_l_cpat                            True  0.495709         170.0
# Hexamer_l_cpat                            True  0.495121         167.0
# Signal.Peak_lncfinder                     True  0.494617          54.0
# Hexamer_score_ORF_T0_lncDC                True  0.493768         168.0
# kmerScore_12mer_feelnc                    True  0.484166         169.0
# SS.Dist.Ratio_lncfinder                   True  0.478486         172.0
# ORF_T0_coverage_lncDC                     True  0.478271         153.0
# ORF.Max.Cov_lncfinder                     True  0.477583         152.0
# ORF_T2_length_lncDC                       True  0.468074          55.0
# RNA_size_feelnc                           True  0.456021          60.0
# SS_score_k5_lncDC                         True  0.442354         175.0
# Hexamer_score_ORF_T2_lncDC                True  0.440513         173.0
# ir_gaps_mean_pct                          True  0.432657          59.0
# str_mean_length_pct                       True  0.415051          58.0
# te_count_per_kb                           True  0.399193         107.0
# global_rm_total_length_pct                True  0.370747         106.0
# CGA_plncpro                               True  0.366688         177.0
# TCG_plncpro                               True  0.358140         179.0
# mr_mean_length_pct                        True  0.354679          36.0
# dr_mean_length_pct                        True  0.336262          33.0
# global_gaps_max                           True  0.335603          62.0
# mr_gaps_mean_pct                          True  0.335332          37.0
# Fickett_score_lncDC                       True  0.331488         154.0
# str_max_length_pct                        True  0.318299          32.0
# gq_total_length                           True  0.309942          85.0
# te_ancient_count_per_kb                   True  0.297189         105.0
# CGT_plncpro                               True  0.295870         178.0
# kmerScore_2mer_feelnc                     True  0.295686         174.0
# dr_gaps_mean_pct                          True  0.295499          38.0
# str_gaps_max_pct                          True  0.293014          39.0
# ir_max_length_pct                         True  0.292167          35.0
# lctr_gaps_max                             True  0.291491          66.0
# ACG_plncpro                               True  0.289625         176.0
# TCT_plncpro                               True  0.276816         160.0
# ORF_T0_PI_lncDC                           True  0.273624          84.0
# te_unique_families                        True  0.269180         111.0
# RCB_T1_lncDC                              True  0.266091          61.0
# Hexamer_score_ORF_T3_lncDC                True  0.265829         133.0
# apr_mean_length_pct                       True  0.261671           6.0
# te_max_divergence                         True  0.257127         110.0
# te_ltr_count_per_kb                       True  0.255418          98.0
# gq_max_length                             True  0.249554          87.0
# te_sum_hit_length                         True  0.249001         108.0
# ORF_T0_aromaticity_lncDC                  True  0.247608          81.0
# gq_mean_length_pct                        True  0.244713          30.0
# total_nonb_count                          True  0.238424          21.0
# SS_score_k1_lncDC                         True  0.235823         137.0
# global_gaps_median                        True  0.228957          63.0
# TCA_plncpro                               True  0.228775         157.0
# ACA_plncpro                               True  0.227466         119.0
# te_max_perc_del                           True  0.223598         109.0
# tri_mean_length_pct                       True  0.222917          29.0
# CAA_plncpro                               True  0.217215         118.0
# ORF_T3_MW_lncDC                           True  0.213687         151.0
# te_max_perc_ins                           True  0.213383         103.0
# ACT_plncpro                               True  0.208932         166.0
# z_mean_length_pct                         True  0.206376          42.0
# CAT_plncpro                               True  0.202185         156.0
# z_hit_count                               True  0.199415          17.0
# CTA_plncpro                               True  0.193609         164.0
# te_max_hit_reference_coverage             True  0.187545          99.0
# ir_max_length                             True  0.186473          24.0
# tri_hit_count                             True  0.185246          12.0
# apr_gaps_mean                             True  0.184444           4.0
# z_gaps_max                                True  0.178115          22.0
# AAC_plncpro                               True  0.177605         117.0
# ir_gaps_min_pct                           True  0.177324          20.0
# TTC_plncpro                               True  0.173084         159.0
# te_line_count_per_kb                      True  0.169035         101.0
# gq_gaps_median_pct                        True  0.165447          44.0
# gq_gaps_mean_pct                          True  0.164627          45.0
# ir_gaps_max                               True  0.164469          27.0
# GTG_plncpro                               True  0.162834         114.0
# z_gaps_mean                               True  0.159224          41.0
# tri_gaps_max                              True  0.155013          25.0
# CTT_plncpro                               True  0.154595         158.0
# AGA_plncpro                               True  0.154564         116.0
# TAA_plncpro                               True  0.153604         136.0
# global_gaps_min                           True  0.151292          64.0
# all_nonb_gaps_min                         True  0.150837          23.0
# gq_gaps_max                               True  0.150345          46.0
# all_nonb_gaps_mean                        True  0.149714          91.0
# gq_gaps_min_pct                           True  0.148590          43.0
# mr_max_length                             True  0.147683          15.0
# mr_gaps_max                               True  0.147546          26.0
# te_sine_count_per_kb                      True  0.147193         102.0
# dr_max_length                             True  0.144658           7.0
# UP.PCT_lncfinder                          True  0.143557         140.0
# ATC_plncpro                               True  0.143231         155.0
# GGG_plncpro                               True  0.139561         138.0
# z_max_length                              True  0.139038          18.0
# te_gaps_median_pct                        True  0.138916          96.0
# gq_mean_length                            True  0.137450          88.0
# TGA_plncpro                               True  0.133437         122.0
# tri_max_length                            True  0.132516          13.0
# TGG_plncpro                               True  0.131256         113.0
# ATA_plncpro                               True  0.130924         134.0
# AGC_plncpro                               True  0.130122         141.0
# mr_gaps_min_pct                           True  0.129648          90.0
# dr_std_length_pct                         True  0.129628          34.0
# TAG_plncpro                               True  0.128759         148.0
# GGT_plncpro                               True  0.128518         112.0
# GCT_plncpro                               True  0.128476         131.0
# tri_std_length                            True  0.127529          14.0
# gq_total_length_pct                       True  0.126466          86.0
# AAG_plncpro                               True  0.125231         115.0
# apr_hit_count                             True  0.124322           1.0
# str_max_length                            True  0.122597           8.0
# str_gaps_min_pct                          True  0.120613          19.0
# motif_diversity                           True  0.114581          10.0
# ir_std_length                             True  0.113669          79.0
# TGC_plncpro                               True  0.112845         132.0
# CCC_plncpro                               True  0.108862         139.0
# te_min_perc_del                           True  0.108645          97.0
# dr_gaps_min_pct                           True  0.106039          89.0
# CAG_plncpro                               True  0.101327         142.0
# apr_max_length                            True  0.099523           3.0
# GGA_plncpro                               True  0.098687         162.0
# apr_std_length                            True  0.097206           2.0
# ORF_T3_coverage_lncDC                     True  0.095703          57.0
# GCA_plncpro                               True  0.093574         143.0
# ATT_plncpro                               True  0.090577         135.0
# GAC_plncpro                               True  0.080916         150.0
# ACC_plncpro                               True  0.077347         123.0
# GTC_plncpro                               True  0.076629         129.0
# lctr_low_complexity_count                 True  0.075946          65.0
# ATG_plncpro                               True  0.075110         120.0
# te_fragmented_ratio                       True  0.074921          68.0
# dr_gaps_mean                              True  0.073881          93.0
# CAC_plncpro                               True  0.071260         125.0
# CTC_plncpro                               True  0.069460         128.0
# gq_std_length_pct                         True  0.066515          31.0
# apr_gaps_min_pct                          True  0.064888           5.0
# Seq.Dist.Ratio_lncfinder                  True  0.059564         171.0
# mr_gaps_mean                              True  0.058544          94.0
# te_gaps_min_pct                           True  0.057692          95.0
# ORF_T1_instability_lncDC                  True  0.056880          83.0
# str_gaps_median                           True  0.052130          92.0
# GAG_plncpro                               True  0.050052         163.0
# te_dna_count_per_kb                       True  0.049698          69.0
# te_min_perc_ins                           True  0.049547         104.0
# tri_gaps_min_pct                          True  0.049162          28.0
# te_min_hit_reference_coverage             True  0.047979         100.0
# ORF_T0_instability_lncDC                  True  0.042605          82.0
# z_gaps_min                                True  0.037471          40.0
# TTG_plncpro                               True  0.036076         145.0
# total_nonb_coverage_pct                   True  0.035898          11.0
# mr_mean_length                            True  0.035116          16.0
# CTG_plncpro                               True  0.034897         130.0
# TGT_plncpro                              False  0.019487         146.0
# ir_gaps_mean                             False  0.018166          80.0
# str_mean_length                          False  0.017251           9.0
# GTT_plncpro                              False  0.014428         144.0
# TCC_plncpro                              False  0.013886         127.0
# CCT_plncpro                              False  0.011775         126.0
# lctr_satellite_count_per_kb               True  0.009802          78.0
# CCA_plncpro                              False  0.009647         124.0
# AGG_plncpro                              False  0.009059         161.0
# AGT_plncpro                              False  0.008821         149.0
# te_young_count_per_kb                     True  0.008435          71.0
# GAT_plncpro                              False  0.008274         121.0
# pseudo_count_per_kb                      False  0.002073          53.0
# GTA_plncpro                              False  0.001590         147.0
# te_srprna_count_per_kb                    True  0.001508          77.0
# te_retroposon_count_per_kb               False  0.001427          70.0
# pseudo_snrna_count_per_kb                False  0.001218          52.0
# TAC_plncpro                              False  0.001091         165.0
# unknown_count_per_kb                     False  0.001011          67.0
# pseudo_trna_count_per_kb                 False  0.000688          50.0
# pseudo_ancient_count_per_kb              False  0.000661          48.0
# pseudo_max_hit_reference_coverage        False  0.000476          51.0
# pseudo_mean_perc_ins                     False  0.000395          47.0
# pseudo_min_perc_del                      False  0.000237          49.0
# te_rc_count_per_kb                       False  0.000185          76.0
# pseudo_scrna_count_per_kb                False  0.000079          72.0
# pseudo_rrna_count_per_kb                 False  0.000079          73.0

# %%
mannu_dict = {
'ORF_T1_length_lncDC': 'ORF length (type 1)',
 'RNA_size_feelnc': 'Transcript length',
 'Signal.Min_lncfinder': 'Minimum frame signal',
 'SS.pct.dist_lncfinder': 'Log. distance to coding SS',
 'Signal.Q1_lncfinder': 'Q1 of frame signal',
 'Signal.Q2_lncfinder': 'Q2 of frame signal',
 'SS.lnc.dist_lncfinder': 'Log. distance to lncRNA SS',
 'MFE_lncfinder': 'Minimum free energy',
 'Signal.Max_lncfinder': 'Maximum frame signal',
 'Dot_pct.dist_lncfinder': 'Distance to coding SS (dot format)',
 'ORF_T0_MW_lncDC': 'ORF Mol. Weight (type 1)',
 'ORF_T0_length_lncDC': 'ORF length (type 0)',
 'ORF_l_cpat': 'ORF length (CPAT)',
 'ORF.Max.Len_lncfinder': 'Max. ORF length',
 'Seq.pct.Dist_lncfinder': 'Log. distance to coding seqs.',
 'Seq.lnc.Dist_lncfinder': 'Log. distance to lncRNA seqs.',
 'Fickett_l_cpat': 'Fickett score (CPAT)',
 'Hexamer_l_cpat': 'Hexamer score (CPAT)',
 'Signal.Peak_lncfinder': 'Peak frame signal',
 'RCB_T0_lncDC': 'ORF relative codon bias (type 0)',
 'global_gaps_max': 'Max gap length between rep. elements',
 'SS.Dist.Ratio_lncfinder': 'Distance ratio (lncRNA SS/coding SS)',
 'total_nonb_count': 'Total non-B DNA motifs',
 'ORF_T0_coverage_lncDC': 'ORF coverage (type 0)',
 'RCB_T1_lncDC': 'ORF relative codon bias (type 1)',
 'ORF_T2_MW_lncDC': 'ORF Mol. Weight (type 2)',
 'Hexamer_score_ORF_T0_lncDC': 'Hexamer score (ORF type 0)',
 'kmerScore_12mer_feelnc': '12-mer k-mer score',
 'ORF.Max.Cov_lncfinder': 'Max. ORF coverage',
 'ORF_T2_length_lncDC': 'ORF length (type 2)'
}

# %%
# Select top 10 categorical features by Cramér's V
top10 = clustered_mannu.head(10)
top10["vda_to_plot"] = top10["vda"] - 0.5  # Center around 0 for better color mapping

top10['label'] = top10.index.map(mannu_dict)
top10['label'] = top10['label'].fillna(top10.index.to_series())

# Colors
norm = plt.Normalize(0, 0.6)
cmap = sns.color_palette("crest")
#cmap = sns.color_palette('RdYlBu_r', as_cmap=True)
#cmap = plt.cm.Blues

fig_h_cm = 5
fig_w_cm = 9

# Plot
fig, ax = plt.subplots(figsize=(fig_w_cm / 2.54 , fig_h_cm/2.54), dpi=300)
bar = sns.barplot(x=top10['vda_to_plot'], y=top10.index[::-1], ax=ax, color=sns.color_palette("crest")[-2])

y_pos = np.arange(len(top10))[::-1]  # highest rank at top
ax.set_yticks(y_pos)
ax.set_yticklabels(top10['label'][::-1])
ax.set_ylabel("Continuous features", labelpad=5)
ax.set_xlabel("Effect size (VDA) - 0.5")
#ax.set_title("Top 10 Categorical Features with association to\ncoding vs lncRNA in low entropy group", pad=30)
ax.set_xlim(-0.55, 0.55)
ax.set_xticks([-0.5, -0.25, 0, 0.25, 0.5])
#ax.set_xticklabels(['0.0', '0.25', '0.5', '0.75', '1.0'])

#Add annotation on top of graph with direction
#Right is pc, left is lncRNA, 0 shows no association
ax.text(0.5, 1.02, 'coding →', ha='right', va='bottom', transform=ax.get_xaxis_transform())
ax.text(-0.5, 1.02, '← lncRNA', ha='left', va='bottom', transform=ax.get_xaxis_transform())
ax.text(0, 1.02, 'No association', ha='center', va='bottom', transform=ax.get_xaxis_transform())

plt.tight_layout()
plt.show()

# %%
import matplotlib.gridspec as gridspec

# Create combined grid plot with three graphs vertically aligned
# Use GridSpec to have explicit control over subplot widths
fig = plt.figure(figsize=(8.5 / 2.54, 15 / 2.54), dpi=300)
gs = gridspec.GridSpec(3, 2, figure=fig, width_ratios=[1, 0.05], wspace=0.05, hspace=0.5)

# Create main axes - all in the first column to ensure same width
ax0 = fig.add_subplot(gs[0, 0])
ax1 = fig.add_subplot(gs[1, 0])
ax2 = fig.add_subplot(gs[2, 0])

# Create colorbar axis only for middle plot
cax = fig.add_subplot(gs[1, 1])

# === Plot 1: Continuous variables after clustering ===
top10_cont = clustered_mannu.head(10)
top10_cont["vda_to_plot"] = top10_cont["vda"] - 0.5
top10_cont['label'] = top10_cont.index.map(mannu_dict)

sns.barplot(x=top10_cont['vda_to_plot'], y=top10_cont.index[::-1], ax=ax0, color=sns.color_palette("crest")[-2])
ax0.set_yticks(np.arange(len(top10_cont))[::-1])
ax0.set_yticklabels(top10_cont['label'][::-1], fontsize=6)
ax0.set_ylabel("", fontsize=6)
ax0.set_xlabel("Effect size (VDA) - 0.5", fontsize=6)
ax0.set_xlim(-0.55, 0.55)
ax0.set_xticks([-0.5, -0.25, 0, 0.25, 0.5])
ax0.text(0.53, 1.03, 'coding →', ha='right', va='bottom', transform=ax0.get_xaxis_transform(), fontsize=6)
ax0.text(-0.53, 1.03, '← lncRNA', ha='left', va='bottom', transform=ax0.get_xaxis_transform(), fontsize=6)
ax0.text(0, 1.03, 'No association', ha='center', va='bottom', transform=ax0.get_xaxis_transform(), fontsize=6)

# === Plot 2: Categorical variables ===
top10_cat = chi2_df.sort_values('cramers_v', ascending=False).head(10).copy()
top10_cat['label'] = top10_cat.index.map(chi2_label_dict)
top10_cat["log10_odds_ratio"] = np.log10(top10_cat["odds_ratio"].replace(0, np.nan))

norm_cat = plt.Normalize(0, 0.6)
cmap_cat = sns.color_palette("crest", as_cmap=True)

sns.barplot(x=top10_cat['log10_odds_ratio'], y=top10_cat.index[::-1], hue=top10_cat['cramers_v'], 
            palette=cmap_cat, hue_norm=norm_cat, ax=ax1)

ax1.set_yticks(np.arange(len(top10_cat))[::-1])
ax1.set_yticklabels(top10_cat['label'][::-1], fontsize=6)
ax1.set_ylabel("", fontsize=6)
ax1.set_xlabel("log10 odds ratio", fontsize=6)
ax1.set_xlim(-1.3, 1.3)
ax1.text(1.25, 1.03, 'coding →', ha='right', va='bottom', transform=ax1.get_xaxis_transform(), fontsize=6)
ax1.text(-1.25, 1.03, '← lncRNA', ha='left', va='bottom', transform=ax1.get_xaxis_transform(), fontsize=6)
ax1.text(0, 1.03, 'No association', ha='center', va='bottom', transform=ax1.get_xaxis_transform(), fontsize=6)
ax1.get_legend().remove()

# Colorbar for categorical plot in separate axis
sm = plt.cm.ScalarMappable(cmap=cmap_cat, norm=norm_cat)
cbar1 = plt.colorbar(sm, cax=cax)
cbar1.set_label("Cramér's V", fontsize=6)
cbar1.set_ticks([0, 0.2, 0.4, 0.6])
cbar1.ax.tick_params(labelsize=6)

# === Plot 3: Proportions ===
freq_df_plot = freq_df[['label', 'lncRNA', 'Coding']].loc[top10_cat.index]

x_pos = np.arange(len(freq_df_plot))
width = 0.35

ax2.barh(x_pos - width/2, freq_df_plot['lncRNA'], width, label='lncRNA', color='#9467bd')
ax2.barh(x_pos + width/2, freq_df_plot['Coding'], width, label='Coding', color='#d95f02')

ax2.set_yticks(x_pos)
ax2.set_yticklabels(freq_df_plot['label'], fontsize=6)
ax2.invert_yaxis()
ax2.set_xlabel("Transcripts with feature (%)", fontsize=6)
ax2.set_ylabel("", fontsize=6)
ax2.legend(title="", loc='upper center', bbox_to_anchor=(0.5, 1.17), ncol=2, frameon=False, fontsize=6)

# 
fig.subplots_adjust(left=0.35, right=0.88, top=0.93, bottom=0.07, hspace=0.4)
# plt.savefig(os.path.join(FIGURE_DIR, "low_entropy_pc_v_lnc_statistical_tests_results.pdf"),
#             dpi=300,
#             format='pdf',
#             bbox_inches='tight')
plt.show()
